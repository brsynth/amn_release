# %% [markdown]
# # Create and Train Mechanistic Neural or AMN models
#
# This notebook creates and trains Artificial Metabolic Networks (**AMNs**) that reproduce the behavior of strain models based on simulations or experimental data. The networks compute reaction rates (fluxes) at steady state for either all reactions (fluxes) or a predefined of set experimentally measured or simulated fluxes. Various encoding are proposed composed of a trainable ANN and/or non trainable mechanistic layer:
#
# (1) MM_QP: Use a non trainable mechanistic layer (a gradient descent that minimize the difference between measured and predicted fluxes and minimizes constraints)
#
# (2) ANN_Dense: Use a black box trainable standard ANN to reproduce measured fluxes
#
# (3) AMNs: three models are provided
# - AMN_QP: Use trainable ANN and non trainable mechanistic layerto enforce SV = 0 and minimize the different between measured and predicted fluxes. The trainablme layer compute an initial flux vector, fed to teh mechanistci layer. Two programs are available: for extact intake medium fluxes (EB program), and for upper values for intake medium fluxes (UB program)
# - AMN_LP: Similar to AMN_QP but using an RNN method found in Y. Yang et al. Mathematics and Computers in Simulation, 101 (2014) 103–112
# - AMN_Wt: Use a trainable RNN cell where reaction fluxes are computed with a weight matrix works only when upper values for intake medium fluxes (UB program) are provided
#
# (3) RC: The AMNs are used as non trainable reservoirs to find relationships between nutrient concentration and nutrient uptake fluxes.

# %% [markdown]
# # Install conda on your Colab environment

# %% [markdown]
# Ignore this first cell if you are running the notebook in a local environment.
#
# One can still run them locally but it will have no effect.

# %%
# Run this cell first - it will install a conda distribution (mamba)
# on your Drive then restart the kernel automatically 
# (don't worry about the crashing/restarting kernel messages)
# It HAS to be runned FIRST everytime you use the notebook in colab

import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    # !pip install -q condacolab
    import condacolab
    condacolab.install()

# %% [markdown]
# # Set up your Colab or local environment
# # Then import libraries

# %% [markdown]
# Run this cell in both cases of use (local or Colab)

# %%
import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    
    # Check everything is fine with conda in Colab
    import condacolab
    condacolab.check()
    
    # Mount your drive environment in the colab runtime
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    
    # Change this variable to your path on Google Drive to which the repo has been cloned
    # If you followed the colab notebook 'repo_cloning.ipynb', nothing to change here
    repo_path_in_drive = '/content/drive/My Drive/Github/amn_release/'
    # Change directory to your repo cloned in your drive
    DIRECTORY = repo_path_in_drive
    os.chdir(repo_path_in_drive)
    # Copy the environment given in the environment_amn.yml
    # !mamba env update -n base -f environment_amn.yml
    
    # This is one of the few Colab-compatible font
    font = 'Liberation Sans'
    
else:
    
    # In this case the local root of the repo is our working directory
    DIRECTORY = './'
    font = 'arial'

# printing the working directory files. One can check you see the same folders and files as in the git webpage.
print(os.listdir(DIRECTORY))

from Build_Model import *

# We declare this function here and not in the
# function-storing python file to modify it easily
# as it can change the printouts of the methods
def printout(V, Stats, model): 
    # printing Stats
    print("R2 = %.2f (+/- %.2f) Constraint = %.2f (+/- %.2f)" % \
          (Stats.train_objective[0], Stats.train_objective[1],
           Stats.train_loss[0], Stats.train_loss[1]))
    Vout = tf.convert_to_tensor(np.float32(model.Y))
    Loss_norm, dLoss = Loss_Vout(V, model.Pout, Vout)
    print('Loss Targets', np.mean(Loss_norm))
    Loss_norm, dLoss = Loss_SV(V, model.S)
    print('Loss SV', np.mean(Loss_norm))
    Vin = tf.convert_to_tensor(np.float32(model.X))
    Pin = tf.convert_to_tensor(np.float32(model.Pin))
    if Vin.shape[1] == model.S.shape[1]: # special case
        Vin  = tf.linalg.matmul(Vin, tf.transpose(Pin), b_is_sparse=True)
    Loss_norm, dLoss = Loss_Vin(V, model.Pin, Vin, model.mediumbound)
    print('Loss Vin bound', np.mean(Loss_norm))
    Loss_norm, dLoss = Loss_Vpos(V, model)
    print('Loss V positive', np.mean(Loss_norm))
# Out:
# ['README.md', 'Duplicate_Model.ipynb', 'Build_Model_Dense.ipynb', 'Build_Dataset.py', 'Dataset_experimental', '.ipynb_checkpoints', '.git', 'Build_Experimental.ipynb', 'Reservoir', 'Dataset_model', 'Figures.ipynb', 'Result', 'Figures', '.gitignore', 'Duplicate_Model.py', 'LICENSE', 'Build_Dataset.ipynb', 'Dataset_input', '__pycache__', 'Build_Experimental.py', 'old', 'environment_amn.yml', 'Build_Model.py', 'Build_Model.ipynb', '.DS_Store']

# %% [markdown]
# ## (1) Mechanistic Model: examples with non trainable mechanistic model with FBA simulated training sets or experimental datasets

# %%
# Run Mechanistic model (no training) QP (quadratic program) or LP (linear program)
# using tiny5 simulation training sets with EB (or UB) bounds

# What you can change
seed = 1
np.random.seed(seed=seed)  
trainname = 'tiny5_EB'
write_loss = False # Writes an output file containing loss history mean and std over timesteps
write_targets = False # Writes an output file containing true and predicted targets
# End of What you can change

# Create model and run GD
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['biomass'], 
              model_type = 'MM_LP',
              timestep = int(1.0e3), learn_rate = 1.0, decay_rate = 0.5)
model.printout()

loss_outname = DIRECTORY + "Result/" + model.model_type + "_Loss_" + trainname + ".csv" if write_loss else None
model.loss_outfile = loss_outname
targets_outname = DIRECTORY + "Result/" + model.model_type + "_Targets_" + trainname + ".csv" if write_targets else None
model.targets_outfile = targets_outname

if model.model_type is 'MM_QP':
    Ypred, Stats = MM_QP(model, verbose=True)
if model.model_type is 'MM_LP':
    Ypred, Stats = MM_LP(model, verbose=True)

# Printing results
printout(Ypred, Stats, model)
# Out:
# ./Dataset_model/tiny5_EB.npz
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: parameter file not found
# /home/lfaure/miniconda3/envs/AMN/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Run Mechanistic model (no training) QP (quadratic program) or LP (linear program)
# using E. coli core simulation training sets and EB (or UB) bounds

# What you can change
seed = 10
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB' # the training set file name
size = 10 # number of runs must be lower than the number of element in trainname
timestep = int(1.0e4) # LP 1.0e4 QP 1.0e5
learn_rate = 0.3 # LP 0.3 QP 1.0
decay_rate = 0.9 # only in QP, UB 0.333 EB 0.9
write_loss = False # Writes an output file containing loss history mean and std over timesteps
write_targets = False # Writes an output file containing true and predicted targets
# End of What you can change

# Create model and run GD for X and Y randomly drawn from trainingfile
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ecoli_core_w_GAM'], 
              model_type = 'MM_LP', 
              timestep = timestep, 
              learn_rate = learn_rate, 
              decay_rate = decay_rate)

# Select a random subset of the training set (of specified size)

ID = np.random.choice(model.X.shape[0], size, replace=False)
model.X, model.Y = model.X[ID,:], model.Y[ID,:]
if model.mediumbound == 'UB':
    model.b_ext = model.b_ext[ID,:]
if model.mediumbound == 'EB':
    model.b_int = model.b_int[ID,:]

# Prints a summary of the model before running

model.printout()

# Make names for output file (if 'write_' flag is set to true)

loss_outname = DIRECTORY + "Result/" + model.model_type + "_Loss_" + \
trainname + ".csv" if write_loss else None
model.loss_outfile = loss_outname
targets_outname = DIRECTORY + "Result/" + model.model_type + "_Targets_" + \
trainname + ".csv" if write_targets else None
model.targets_outfile = targets_outname

# Runs the appropriate method

if model.model_type is 'MM_QP':
    Ypred, Stats = MM_QP(model, verbose=True)
if model.model_type is 'MM_LP':
    Ypred, Stats = MM_LP(model, verbose=True)

# Printing results
printout(Ypred, Stats, model)
# Out:
# training file: ./Dataset_model/e_coli_core_UB
# model type: MM_LP
# model scaler: 0.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 10000
# training set size (10, 20) (10, 1)
# LP-Loss 1 0.25261024 0.06849076
# LP-Loss 10 0.2294474 0.06633821
# LP-Loss 100 0.0808966 0.03674851
# LP-Loss 1000 0.00023186656 0.0002091549
# LP-Loss 2000 3.8031656e-05 2.6454396e-05
# LP-Loss 3000 1.6315684e-05 1.6629287e-05
# LP-Loss 4000 9.442818e-06 1.449519e-05
# LP-Loss 5000 7.2193407e-06 1.2035626e-05
# LP-Loss 6000 5.5323576e-06 9.809663e-06
# LP-Loss 7000 4.2318406e-06 7.880076e-06
# LP-Loss 8000 3.2548737e-06 6.2515983e-06
# LP-Loss 9000 2.3623904e-06 4.757077e-06
# LP-Loss 10000 1.6831349e-06 3.5644443e-06
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 312)
# R2 = 1.00 (+/- 0.00) Constraint = 0.00 (+/- 0.00)
# Loss Targets 0.001244092
# Loss SV 8.0880665e-07
# Loss Vin bound 1.0041353e-05
# Loss V positive 2.924077e-06

# %%
# Run Mechanistic model (no training) QP (quadratic program) or LP (linear program)
# using E. coli core simulation training sets and EB (or UB) bounds

# What you can change
seed = 10
np.random.seed(seed=seed)  
trainname = 'e_coli_core_EB' # the training set file name
size = 10 # number of runs must be lower than the number of element in trainname
timestep = int(1.0e6) # LP 1.0e4 QP 1.0e5
learn_rate = 1.0 # LP 0.3 QP 1.0
decay_rate = 0.9 # only in QP, UB 0.333 EB 0.9
write_loss = False # Writes an output file containing loss history mean and std over timesteps
write_targets = False # Writes an output file containing true and predicted targets
# End of What you can change

# Create model and run GD for X and Y randomly drawn from trainingfile
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ecoli_core_w_GAM'], 
              model_type = 'MM_QP', 
              timestep = timestep, 
              learn_rate = learn_rate, 
              decay_rate = decay_rate)

# Select a random subset of the training set (of specified size)
ID = np.random.choice(model.X.shape[0], size, replace=False)
model.X, model.Y = model.X[ID,:], model.Y[ID,:]
if model.mediumbound == 'UB':
    model.b_ext = model.b_ext[ID,:]
if model.mediumbound == 'EB':
    model.b_int = model.b_int[ID,:]

# Prints a summary of the model before running
model.printout()

# Make names for output file (if 'write_' flag is set to true)
loss_outname = DIRECTORY + "Result/" + model.model_type + "_Loss_" \
+ trainname + ".csv" if write_loss else None
model.loss_outfile = loss_outname
targets_outname = DIRECTORY + "Result/" + model.model_type + "_Targets_" \
+ trainname + ".csv" if write_targets else None
model.targets_outfile = targets_outname

# Runs the appropriate method
if model.model_type is 'MM_QP':
    Ypred, Stats = MM_QP(model, loss_outfile=loss_outname, 
                         targets_outfile= targets_outname,
                         verbose=True)
if model.model_type is 'MM_LP':
    Ypred, Stats = MM_LP(model, loss_outfile=loss_outname, 
                         targets_outfile= targets_outname,
                         verbose=True)
# Printing results
printout(Ypred, Stats, model)

# %%
# Run Mechanistic model (no training) QP (quadratic program) or LP (linear program)
# using E. coli core simulation training sets
# with initial X close to solution Y and EB (or UB) bounds

# What you can change
seed = 10
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB' # the training set file name (EB or UB)
size = 10 # number of runs must be lower than the number of element in trainname
timestep = int(1.0e4) # LP 1.0e4 QP 1.0e5
learn_rate = 1.0 # LP 0.3 QP 1.0
decay_rate = 0.9 # only in QP, UB 0.333 EB 0.9 # try 0.5
write_loss = False # Writes an output file containing loss history mean and std over timesteps
write_targets = False # Writes an output file containing true and predicted targets
model_type = 'MM_QP'
# End of What you can change

# Draw X and Y randomly drawn from trainingfile
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ecoli_core_w_GAM'], 
              model_type = model_type, 
              timestep = timestep,
              learn_rate = learn_rate,
              decay_rate = decay_rate)
ID = np.random.choice(model.X.shape[0], size, replace=False)
model.X, model.Y, model.Yall = model.X[ID,:], model.Y[ID,:],  model.Yall[ID,:]
if model.mediumbound == 'UB':
    model.b_ext = model.b_ext[ID,:]
if model.mediumbound == 'EB':
    model.b_int = model.b_int[ID,:]
model.printout()

# Create model and run GD X = normal distribution around solution
Ypred, Stats = {}, {}
noise_set = [0.5, 0.1, 0.01, 0.005, 0.001, 0.0005]
for noise in noise_set:
    
    loss_outname = DIRECTORY + "Result/" + str(noise) + "_noise_" + \
    model.model_type + "_Loss_" + trainname + ".csv" if write_loss else None
    model.loss_outfile = loss_outname
    targets_outname = DIRECTORY + "Result/" + str(noise) + "_noise_" \
    + model.model_type + "_Targets_" + trainname + ".csv" if write_targets else None
    model.targets_outfile = targets_outname
    
    
    model.X = np.random.normal(model.Yall, noise*model.Yall)
    print('noise', noise)
    if model.model_type is 'MM_QP':
        Ypred[noise], Stats[noise] = MM_QP(model, verbose=True)
    if model.model_type is 'MM_LP':
        Ypred[noise], Stats[noise] = MM_LP(model, verbose=True)
    
    printout(Ypred[noise], Stats[noise], model)
# Out:
# training file: ./Dataset_model/e_coli_core_UB
# model type: MM_QP
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 10000
# training set size (10, 20) (10, 1)
# noise 0.5
# GD-Loss 1 2.3497357 0.58461136
# GD-Loss 10 2.1286168 0.66098446
# GD-Loss 100 0.68807036 0.15949886
# GD-Loss 1000 0.17094067 0.048883222
# GD-Loss 2000 0.112243116 0.03465901
# GD-Loss 3000 0.08686058 0.028503802
# GD-Loss 4000 0.071525335 0.024566654
# GD-Loss 5000 0.061294593 0.021584878
# GD-Loss 6000 0.05490441 0.019376915
# GD-Loss 7000 0.048432 0.01873374
# GD-Loss 8000 0.044350315 0.016383402
# GD-Loss 9000 0.040097177 0.015305694
# GD-Loss 10000 0.037610233 0.014153577
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.10 (+/- 0.03)
# Loss Targets 0.001111585
# Loss SV 0.034170542
# Loss Vin bound 0.20221159
# Loss V positive 0.0014855479
# noise 0.1
# GD-Loss 1 0.47501326 0.122467846
# GD-Loss 10 0.38130006 0.13565588
# GD-Loss 100 0.14615281 0.038775574
# GD-Loss 1000 0.038021643 0.006168148
# GD-Loss 2000 0.025946546 0.004666064
# GD-Loss 3000 0.021394977 0.0041978653
# GD-Loss 4000 0.017953537 0.00272975
# GD-Loss 5000 0.01612002 0.0028774827
# GD-Loss 6000 0.015315657 0.0029070498
# GD-Loss 7000 0.013041636 0.0025741286
# GD-Loss 8000 0.013403009 0.002066524
# GD-Loss 9000 0.011851001 0.0022821575
# GD-Loss 10000 0.011421064 0.0022575574
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.02 (+/- 0.00)
# Loss Targets 0.00015246868
# Loss SV 0.008754591
# Loss Vin bound 0.051730078
# Loss V positive 0.0019883483
# noise 0.01
# GD-Loss 1 0.040302765 0.014929651
# GD-Loss 10 0.043605242 0.013471308
# GD-Loss 100 0.021551762 0.0032731437
# GD-Loss 1000 0.01295577 0.0017855599
# GD-Loss 2000 0.010832848 0.0016335463
# GD-Loss 3000 0.008723472 0.0016224716
# GD-Loss 4000 0.008132329 0.0009123578
# GD-Loss 5000 0.0072778994 0.0015002643
# GD-Loss 6000 0.007845091 0.0021509256
# GD-Loss 7000 0.006908455 0.0016581449
# GD-Loss 8000 0.008498592 0.0026306417
# GD-Loss 9000 0.0077577992 0.0018715493
# GD-Loss 10000 0.008554951 0.0017394741
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.01 (+/- 0.00)
# Loss Targets 9.040833e-05
# Loss SV 0.0058964994
# Loss Vin bound 0.004235261
# Loss V positive 0.002181348
# noise 0.005
# GD-Loss 1 0.024253327 0.0059220474
# GD-Loss 10 0.03250984 0.004300114
# GD-Loss 100 0.018217592 0.003167705
# GD-Loss 1000 0.011417119 0.0020049766
# GD-Loss 2000 0.0108707 0.0014336328
# GD-Loss 3000 0.008328514 0.0009994135
# GD-Loss 4000 0.008278303 0.0010883384
# GD-Loss 5000 0.008122034 0.0013093418
# GD-Loss 6000 0.007606554 0.0014840455
# GD-Loss 7000 0.007715703 0.0018213415
# GD-Loss 8000 0.008206511 0.002801673
# GD-Loss 9000 0.008397089 0.0014200081
# GD-Loss 10000 0.007852854 0.0015739804
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.01 (+/- 0.00)
# Loss Targets 6.784797e-05
# Loss SV 0.0049803955
# Loss Vin bound 0.0010250926
# Loss V positive 0.0020745764
# noise 0.001
# GD-Loss 1 0.0041959966 0.0010934836
# GD-Loss 10 0.02083666 0.0021951175
# GD-Loss 100 0.01662457 0.0021410235
# GD-Loss 1000 0.010959156 0.0011250868
# GD-Loss 2000 0.0087936465 0.0016638449
# GD-Loss 3000 0.007834716 0.001145806
# GD-Loss 4000 0.0072384886 0.0015619427
# GD-Loss 5000 0.0068340697 0.0013210452
# GD-Loss 6000 0.008129437 0.0010174217
# GD-Loss 7000 0.006918711 0.0016620548
# GD-Loss 8000 0.009609154 0.0019210249
# GD-Loss 9000 0.009119338 0.002681185
# GD-Loss 10000 0.008323199 0.0011043978
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.01 (+/- 0.00)
# Loss Targets 3.9839746e-05
# Loss SV 0.005228163
# Loss Vin bound 0.00061310746
# Loss V positive 0.0018657271
# noise 0.0005
# GD-Loss 1 0.0020922383 0.0004410707
# GD-Loss 10 0.020746708 0.0021030954
# GD-Loss 100 0.017589122 0.0018442634
# GD-Loss 1000 0.01110733 0.0010261724
# GD-Loss 2000 0.009151478 0.0015694118
# GD-Loss 3000 0.008169463 0.0012640703
# GD-Loss 4000 0.007180904 0.0015753557
# GD-Loss 5000 0.0069270106 0.0010407487
# GD-Loss 6000 0.0072330995 0.0012335064
# GD-Loss 7000 0.0072893486 0.0016440472
# GD-Loss 8000 0.0071456567 0.002402433
# GD-Loss 9000 0.007952329 0.0016927785
# GD-Loss 10000 0.008301066 0.0017014496
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (10, 1) (10, 1) (10, 1) (10, 1) (10, 154) (10, 158)
# R2 = 1.00 (+/- 0.00) Constraint = 0.01 (+/- 0.00)
# Loss Targets 5.74708e-05
# Loss SV 0.0054720957
# Loss Vin bound 0.0005503584
# Loss V positive 0.0019266801

# %% [markdown]
# ## (2) Neural model: examples of trainable ANN model (neural only) with FBA simulated training set or experimental datasets

# %%
# Run this cell first
import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    DIRECTORY = '/content/drive/My Drive/AMN-Colab/'
    sys.path.append('/content/drive/My Drive/amn')
    ! pip install cobra
    ! pip install silence_tensorflow
else:
    DIRECTORY = './'
print(os.listdir(DIRECTORY))
    
from Build_Model import *

def printout(filename, Stats, model, time): 
    # printing Stats
    print('Stats for %s CPU-time %.4f' % (filename, time))
    print('R2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.train_objective[0], Stats.train_objective[1],
           Stats.train_loss[0], Stats.train_loss[1]))
    print('Q2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.test_objective[0], Stats.test_objective[1],
           Stats.test_loss[0], Stats.test_loss[1]))
# Out:
# ['Result', '.DS_Store', 'Dataset_model', 'Reservoir', 'old', '__pycache__', 'README.md', '.gitignore', 'Build_Dataset.ipynb', 'Build_Model.py', '.ipynb_checkpoints', 'Dataset_input', 'Build_Dataset.py', '.git', 'Build_Model.ipynb']

# %% [markdown]
# ### FBA simulated training set

# %%
# Create, train and evaluate ANN models with FBA simulated training set for E. coli core

# What you can change 
seed = 10
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB'
# End of What you can change

# Create model
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ecoli_core_w_GAM'], 
              model_type = 'ANN_Dense',
              n_hidden = 1, hidden_dim = 50, 
              epochs = 500, xfold = 5)
ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0) 
model.printout()

# Train and evaluate
reservoirname = trainname +'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y = Xtrain, Ytrain
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=False)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
reservoir.save(reservoirfile)
reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    X, Y = model_input(reservoir,verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
"""
Stats for e_coli_core_UB_ANN_Dense CPU-time 149.2822
R2 = 0.9587 (+/- 0.0329) Constraint = -1.0000 (+/- 0.0000)
Q2 = 0.9582 (+/- 0.0327) Constraint = -1.0000 (+/- 0.0000)
Stats for Test set CPU-time 0.0347
R2 = 0.9104 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
"""
# Out:
# training file: ./Dataset_model/e_coli_core_UB
# model type: ANN_Dense
# model scaler: 0.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 0
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# nbr parameters: 1101
# 23/23 [==============================] - 0s 293us/step
# 6/6 [==============================] - 0s 384us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 23/23 [==============================] - 0s 322us/step
# 6/6 [==============================] - 0s 443us/step
# train = 0.93 test = 0.93 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 23/23 [==============================] - 0s 271us/step
# 6/6 [==============================] - 0s 362us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 23/23 [==============================] - 0s 271us/step
# 6/6 [==============================] - 0s 323us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 23/23 [==============================] - 0s 261us/step
# 6/6 [==============================] - 0s 348us/step
# train = 0.91 test = 0.91 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 29/29 [==============================] - 0s 270us/step
# Stats for e_coli_core_UB_ANN_Dense CPU-time 149.2822
# R2 = 0.9587 (+/- 0.0329) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9582 (+/- 0.0327) Constraint = -1.0000 (+/- 0.0000)
# ./Reservoir/e_coli_core_UB_ANN_Dense_param.csv
# training file: ./Dataset_model/e_coli_core_UB
# model type: ANN_Dense
# model scaler: 0.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 0
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 4/4 [==============================] - 0s 458us/step
# Stats for Test set CPU-time 0.0347
# R2 = 0.9104 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9104 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)

# %%
# Create, train and evaluate ANN models with FBA simulated training set for E. coli core

# What you can change 
seed = 10
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB_5000'
# End of What you can change

# Create model
trainingfile = DIRECTORY+'Dataset_model/'+trainname
cobramodel = cobra.io.read_sbml_model(trainingfile+'.xml')
OBJ = [r.id for r in cobramodel.reactions]
parameter = TrainingSet()
parameter.load(trainingfile)
Y, i = {}, 0
for obj in OBJ:
    objective = [obj]
    print(objective)
    model = Neural_Model(trainingfile = trainingfile, 
                         objective=objective, 
                         model_type = 'ANN_Dense',
                         n_hidden = 1, hidden_dim = 50, 
                         epochs = 500, xfold = 5)
        
    # Train and evaluate
    start_time = time.time()
    try:
        reservoir, pred, stats, _ = train_evaluate_model(model, verbose=False)
    except:
        pred = 0 * parameter.Y # zero vector
    delta_time = time.time() - start_time

    # Printing cross-validation results
    print(objective,'----------------------------------------------------------------------', i)
    printout(objective, stats, reservoir, delta_time)
    Y[i] = pred[:,0]
    i = i+1

# Collate all predicted Y and get stats and constraints
Y = np.transpose(np.asarray(list(Y.values())))
print(Y.shape, parameter.Y.shape)
print('Q2=', r2_score(parameter.Y, Y, multioutput='variance_weighted'))
X = tf.convert_to_tensor(np.float32(model.X)) # Loss computed of tf tensors
Y = tf.convert_to_tensor(np.float32(Y))
L2, _ = Loss_SV(Y, model.S)
L2 = np.mean(L2.numpy())
print('Loss_SV =', L2)
L3, _ = Loss_Vin(Y, model.Pin, X, 'UB')
L3 = np.mean(L3.numpy())
print('Loss_Vin =', L3)
L = (L2+L3)/2
print('Constraints =', L)

"""
size 10
hidden_dim = 50 no scaler
(10, 154) (10, 154)
Q2= -0.07538283773845325
Loss_SV 0.48731223
Loss_Vin 0.2028226
Loss_cst 0.34506741166114807
hidden_dim = 50 with scaler : no better
Q2= -0.04873539601415515
Loss_SV = 0.45491654
Loss_Vin = 0.20206484
Constraints = 0.328490674495697

size 100
hidden_dim = 50 no scaler
(100, 154) (100, 154)
Q2= 0.8483248084564434
Loss_SV 0.36500132
Loss_Vin 0.019197455
Loss_cst 0.19209939241409302
hidden_dim = 100 : no better
(100, 154) (100, 154)
Q2= 0.7824626824411614
Loss_SV 0.46771127
Loss_Vin 0.02226068
Loss_cst 0.24498596787452698

size 500 no scaler

size 1000 no scaler
(1000, 154) (1000, 154)
Q2= 0.9507007593125759
Loss_SV 0.19790417
Loss_Vin 0.013121797
Loss_cst 0.10551298409700394

size 10000 no scaler

"""
# Out:
# ['PFK']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 266us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 236us/step
# 32/32 [==============================] - 0s 247us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 246us/step
# 32/32 [==============================] - 0s 285us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 271us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 225us/step
# ['PFK'] ---------------------------------------------------------------------- 0
# Stats for ['PFK'] CPU-time 720.0392
# R2 = 0.9976 (+/- 0.0007) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9976 (+/- 0.0009) Constraint = -1.0000 (+/- 0.0000)
# ['PFL']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 253us/step
# train = 0.93 test = 0.93 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 254us/step
# train = 0.93 test = 0.92 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 259us/step
# train = 0.92 test = 0.92 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 261us/step
# train = 0.93 test = 0.92 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 243us/step
# 32/32 [==============================] - 0s 264us/step
# train = 0.94 test = 0.93 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 233us/step
# ['PFL'] ---------------------------------------------------------------------- 1
# Stats for ['PFL'] CPU-time 715.6904
# R2 = 0.9288 (+/- 0.0036) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9251 (+/- 0.0036) Constraint = -1.0000 (+/- 0.0000)
# ['PGI_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# 32/32 [==============================] - 0s 272us/step
# train = 0.88 test = 0.73 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 242us/step
# 32/32 [==============================] - 0s 270us/step
# train = 0.94 test = 0.92 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 240us/step
# 32/32 [==============================] - 0s 571us/step
# train = 0.95 test = 0.81 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 250us/step
# 32/32 [==============================] - 0s 279us/step
# train = 0.91 test = 0.90 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 236us/step
# looping bad training iter=0 r2=0.0931
# 32/32 [==============================] - 0s 281us/step
# train = 0.09 test = 0.07 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 225us/step
# ['PGI_for'] ---------------------------------------------------------------------- 2
# Stats for ['PGI_for'] CPU-time 709.0745
# R2 = 0.7546 (+/- 0.3315) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.6852 (+/- 0.3168) Constraint = -1.0000 (+/- 0.0000)
# ['PGK_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 251us/step
# 32/32 [==============================] - 0s 291us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 235us/step
# 32/32 [==============================] - 0s 262us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# 32/32 [==============================] - 0s 289us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# 32/32 [==============================] - 0s 272us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 221us/step
# ['PGK_for'] ---------------------------------------------------------------------- 3
# Stats for ['PGK_for'] CPU-time 708.1169
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['PGL']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 242us/step
# looping bad training iter=0 r2=-0.0119
# 32/32 [==============================] - 0s 271us/step
# train = -0.01 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# looping bad training iter=0 r2=-0.0128
# 32/32 [==============================] - 0s 275us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# looping bad training iter=0 r2=-0.0135
# 32/32 [==============================] - 0s 255us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 248us/step
# looping bad training iter=0 r2=-0.0130
# 32/32 [==============================] - 0s 291us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0126
# 32/32 [==============================] - 0s 265us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 225us/step
# ['PGL'] ---------------------------------------------------------------------- 4
# Stats for ['PGL'] CPU-time 713.3433
# R2 = -0.0128 (+/- 0.0005) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0129 (+/- 0.0023) Constraint = -1.0000 (+/- 0.0000)
# ['ACALD_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.0893
# 32/32 [==============================] - 0s 250us/step
# train = -0.09 test = -0.09 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 257us/step
# train = 0.97 test = 0.97 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 0.97 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0898
# 32/32 [==============================] - 0s 254us/step
# train = -0.09 test = -0.09 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# looping bad training iter=0 r2=-0.0877
# 32/32 [==============================] - 0s 251us/step
# train = -0.09 test = -0.10 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['ACALD_for'] ---------------------------------------------------------------------- 5
# Stats for ['ACALD_for'] CPU-time 716.4769
# R2 = 0.3348 (+/- 0.5189) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.3268 (+/- 0.5170) Constraint = -1.0000 (+/- 0.0000)
# ['AKGt2r_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=-0.7068
# 32/32 [==============================] - 0s 252us/step
# train = -0.71 test = -0.71 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 247us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 239us/step
# ['AKGt2r_i'] ---------------------------------------------------------------------- 6
# Stats for ['AKGt2r_i'] CPU-time 715.1658
# R2 = 0.6575 (+/- 0.6822) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.6571 (+/- 0.6830) Constraint = -1.0000 (+/- 0.0000)
# ['PGM_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 250us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 258us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 280us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['PGM_for'] ---------------------------------------------------------------------- 7
# Stats for ['PGM_for'] CPU-time 709.9784
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['PIt2r_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 235us/step
# 32/32 [==============================] - 0s 266us/step
# train = 0.96 test = 0.96 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 252us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 266us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 254us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 307us/step
# ['PIt2r_i'] ---------------------------------------------------------------------- 8
# Stats for ['PIt2r_i'] CPU-time 710.7034
# R2 = 0.9815 (+/- 0.0117) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9815 (+/- 0.0105) Constraint = -1.0000 (+/- 0.0000)
# ['ALCD2x_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# looping bad training iter=0 r2=-0.0163
# 32/32 [==============================] - 0s 255us/step
# train = -0.02 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# looping bad training iter=0 r2=-0.0161
# 32/32 [==============================] - 0s 253us/step
# train = -0.02 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=-0.0157
# 32/32 [==============================] - 0s 249us/step
# train = -0.02 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0152
# 32/32 [==============================] - 0s 248us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# looping bad training iter=0 r2=-0.0132
# 32/32 [==============================] - 0s 253us/step
# train = -0.01 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 223us/step
# ['ALCD2x_for'] ---------------------------------------------------------------------- 9
# Stats for ['ALCD2x_for'] CPU-time 715.1747
# R2 = -0.0153 (+/- 0.0011) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0154 (+/- 0.0044) Constraint = -1.0000 (+/- 0.0000)
# ['ACALDt_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 290us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 234us/step
# 32/32 [==============================] - 0s 261us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 248us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['ACALDt_i'] ---------------------------------------------------------------------- 10
# Stats for ['ACALDt_i'] CPU-time 721.6850
# R2 = 0.9976 (+/- 0.0020) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9976 (+/- 0.0020) Constraint = -1.0000 (+/- 0.0000)
# ['ACKr_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 254us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 249us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 249us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 265us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 232us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 200us/step
# ['ACKr_for'] ---------------------------------------------------------------------- 11
# Stats for ['ACKr_for'] CPU-time 715.2224
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['PPC']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# looping bad training iter=0 r2=-0.0224
# 32/32 [==============================] - 0s 248us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# looping bad training iter=0 r2=-0.0235
# 32/32 [==============================] - 0s 255us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.0212
# 32/32 [==============================] - 0s 255us/step
# train = -0.02 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=-0.0216
# 32/32 [==============================] - 0s 251us/step
# train = -0.02 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.0226
# 32/32 [==============================] - 0s 251us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 223us/step
# ['PPC'] ---------------------------------------------------------------------- 12
# Stats for ['PPC'] CPU-time 729.3311
# R2 = -0.0222 (+/- 0.0008) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0223 (+/- 0.0032) Constraint = -1.0000 (+/- 0.0000)
# ['ACONTa_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# looping bad training iter=0 r2=-0.1401
# 32/32 [==============================] - 0s 257us/step
# train = -0.14 test = -0.13 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.1364
# 32/32 [==============================] - 0s 257us/step
# train = -0.14 test = -0.14 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.1323
# 32/32 [==============================] - 0s 248us/step
# train = -0.13 test = -0.16 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.1414
# 32/32 [==============================] - 0s 258us/step
# train = -0.14 test = -0.12 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['ACONTa_for'] ---------------------------------------------------------------------- 13
# Stats for ['ACONTa_for'] CPU-time 739.4812
# R2 = 0.0890 (+/- 0.4531) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.0891 (+/- 0.4532) Constraint = -1.0000 (+/- 0.0000)
# ['ACONTb_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.1331
# 32/32 [==============================] - 0s 256us/step
# train = -0.13 test = -0.16 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=-0.1360
# 32/32 [==============================] - 0s 253us/step
# train = -0.14 test = -0.14 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 249us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 257us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.1361
# 32/32 [==============================] - 0s 262us/step
# train = -0.14 test = -0.14 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['ACONTb_for'] ---------------------------------------------------------------------- 14
# Stats for ['ACONTb_for'] CPU-time 743.0143
# R2 = 0.3183 (+/- 0.5553) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.3109 (+/- 0.5613) Constraint = -1.0000 (+/- 0.0000)
# ['ATPM']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 250us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 256us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 251us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 266us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 250us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 223us/step
# ['ATPM'] ---------------------------------------------------------------------- 15
# Stats for ['ATPM'] CPU-time 738.7742
# R2 = 0.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['PPCK']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 224us/step
# ['PPCK'] ---------------------------------------------------------------------- 16
# Stats for ['PPCK'] CPU-time 736.5952
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['ACt2r_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 256us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 249us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 224us/step
# ['ACt2r_i'] ---------------------------------------------------------------------- 17
# Stats for ['ACt2r_i'] CPU-time 740.9451
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['PPS']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 250us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 249us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 245us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 223us/step
# ['PPS'] ---------------------------------------------------------------------- 18
# Stats for ['PPS'] CPU-time 735.4273
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['ADK1_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 262us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 236us/step
# 32/32 [==============================] - 0s 283us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 256us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 222us/step
# ['ADK1_for'] ---------------------------------------------------------------------- 19
# Stats for ['ADK1_for'] CPU-time 737.2962
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['AKGDH']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 252us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 251us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 255us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 251us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 256us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 221us/step
# ['AKGDH'] ---------------------------------------------------------------------- 20
# Stats for ['AKGDH'] CPU-time 734.2829
# R2 = 0.9838 (+/- 0.0031) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9837 (+/- 0.0034) Constraint = -1.0000 (+/- 0.0000)
# ['ATPS4r_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 257us/step
# train = 0.95 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 253us/step
# train = 0.92 test = 0.92 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 258us/step
# train = 0.95 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 269us/step
# train = 0.90 test = 0.91 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 273us/step
# train = 0.92 test = 0.91 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 228us/step
# ['ATPS4r_i'] ---------------------------------------------------------------------- 21
# Stats for ['ATPS4r_i'] CPU-time 721.6258
# R2 = 0.9293 (+/- 0.0203) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9276 (+/- 0.0166) Constraint = -1.0000 (+/- 0.0000)
# ['PTAr_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 262us/step
# train = 0.94 test = 0.94 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 249us/step
# train = 0.89 test = 0.89 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 252us/step
# train = 0.95 test = 0.94 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 250us/step
# train = 0.96 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 257us/step
# train = 0.95 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 224us/step
# ['PTAr_for'] ---------------------------------------------------------------------- 22
# Stats for ['PTAr_for'] CPU-time 717.2850
# R2 = 0.9376 (+/- 0.0225) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9338 (+/- 0.0223) Constraint = -1.0000 (+/- 0.0000)
# ['PYK']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 254us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 250us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 235us/step
# 32/32 [==============================] - 0s 258us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 256us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 266us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 234us/step
# ['PYK'] ---------------------------------------------------------------------- 23
# Stats for ['PYK'] CPU-time 721.4871
# R2 = 0.9906 (+/- 0.0034) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9904 (+/- 0.0034) Constraint = -1.0000 (+/- 0.0000)
# ['BIOMASS_Ecoli_core_w_GAM']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 252us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 259us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 256us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 237us/step
# 32/32 [==============================] - 0s 259us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 258us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 226us/step
# ['BIOMASS_Ecoli_core_w_GAM'] ---------------------------------------------------------------------- 24
# Stats for ['BIOMASS_Ecoli_core_w_GAM'] CPU-time 719.9513
# R2 = 0.9829 (+/- 0.0029) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9823 (+/- 0.0035) Constraint = -1.0000 (+/- 0.0000)
# ['PYRt2_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 246us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 226us/step
# ['PYRt2_i'] ---------------------------------------------------------------------- 25
# Stats for ['PYRt2_i'] CPU-time 721.4824
# R2 = 0.9991 (+/- 0.0002) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9991 (+/- 0.0003) Constraint = -1.0000 (+/- 0.0000)
# ['CO2t_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.0135
# 32/32 [==============================] - 0s 249us/step
# train = -0.01 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.0146
# 32/32 [==============================] - 0s 253us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# looping bad training iter=0 r2=-0.0141
# 32/32 [==============================] - 0s 255us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.0134
# 32/32 [==============================] - 0s 252us/step
# train = -0.01 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# looping bad training iter=0 r2=-0.0136
# 32/32 [==============================] - 0s 255us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 225us/step
# ['CO2t_i'] ---------------------------------------------------------------------- 26
# Stats for ['CO2t_i'] CPU-time 730.2839
# R2 = -0.0138 (+/- 0.0005) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0139 (+/- 0.0018) Constraint = -1.0000 (+/- 0.0000)
# ['RPE_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 223us/step
# looping bad training iter=0 r2=-0.0080
# 32/32 [==============================] - 0s 253us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 234us/step
# looping bad training iter=0 r2=-0.0077
# 32/32 [==============================] - 0s 247us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# looping bad training iter=0 r2=-0.0086
# 32/32 [==============================] - 0s 246us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# looping bad training iter=0 r2=-0.0083
# 32/32 [==============================] - 0s 253us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# looping bad training iter=0 r2=-0.0076
# 32/32 [==============================] - 0s 251us/step
# train = -0.01 test = -0.01 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 225us/step
# ['RPE_for'] ---------------------------------------------------------------------- 27
# Stats for ['RPE_for'] CPU-time 741.6976
# R2 = -0.0080 (+/- 0.0004) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0081 (+/- 0.0015) Constraint = -1.0000 (+/- 0.0000)
# ['CS']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# looping bad training iter=0 r2=-0.1386
# 32/32 [==============================] - 0s 254us/step
# train = -0.14 test = -0.13 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.1352
# 32/32 [==============================] - 0s 252us/step
# train = -0.14 test = -0.15 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.1366
# 32/32 [==============================] - 0s 250us/step
# train = -0.14 test = -0.14 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# looping bad training iter=0 r2=-0.1398
# 32/32 [==============================] - 0s 254us/step
# train = -0.14 test = -0.13 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 247us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 228us/step
# ['CS'] ---------------------------------------------------------------------- 28
# Stats for ['CS'] CPU-time 737.3088
# R2 = 0.0898 (+/- 0.4546) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.0900 (+/- 0.4546) Constraint = -1.0000 (+/- 0.0000)
# ['RPI_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 256us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 260us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 224us/step
# ['RPI_for'] ---------------------------------------------------------------------- 29
# Stats for ['RPI_for'] CPU-time 747.7523
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['SUCCt2_2']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0176
# 32/32 [==============================] - 0s 254us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0195
# 32/32 [==============================] - 0s 261us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.0187
# 32/32 [==============================] - 0s 254us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# looping bad training iter=0 r2=-0.0184
# 32/32 [==============================] - 0s 256us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# looping bad training iter=0 r2=-0.0194
# 32/32 [==============================] - 0s 261us/step
# train = -0.02 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 229us/step
# ['SUCCt2_2'] ---------------------------------------------------------------------- 30
# Stats for ['SUCCt2_2'] CPU-time 733.6295
# R2 = -0.0187 (+/- 0.0007) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0188 (+/- 0.0028) Constraint = -1.0000 (+/- 0.0000)
# ['CYTBD']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 237us/step
# 32/32 [==============================] - 0s 248us/step
# train = 1.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 261us/step
# train = 1.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# looping bad training iter=0 r2=0.0000
# 32/32 [==============================] - 0s 251us/step
# train = 0.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 248us/step
# train = 1.00 test = 0.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 227us/step
# ['CYTBD'] ---------------------------------------------------------------------- 31
# Stats for ['CYTBD'] CPU-time 728.2437
# R2 = 0.8000 (+/- 0.4000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.2000 (+/- 0.4000) Constraint = -1.0000 (+/- 0.0000)
# ['D_LACt2_i']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 235us/step
# 32/32 [==============================] - 0s 261us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 265us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 252us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 251us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 237us/step
# 32/32 [==============================] - 0s 274us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 241us/step
# ['D_LACt2_i'] ---------------------------------------------------------------------- 32
# Stats for ['D_LACt2_i'] CPU-time 724.5609
# R2 = 0.9978 (+/- 0.0008) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9977 (+/- 0.0009) Constraint = -1.0000 (+/- 0.0000)
# ['ENO_for']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 255us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 256us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 253us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# ...
# 32/32 [==============================] - 0s 294us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 296us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 283us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 268us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 241us/step
# ['FUM_rev'] ---------------------------------------------------------------------- 143
# Stats for ['FUM_rev'] CPU-time 737.2613
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['G6PDH2r_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 290us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 283us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 290us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 284us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# 32/32 [==============================] - 0s 287us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 239us/step
# ['G6PDH2r_rev'] ---------------------------------------------------------------------- 144
# Stats for ['G6PDH2r_rev'] CPU-time 736.9511
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['GAPD_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 313us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 237us/step
# 32/32 [==============================] - 0s 287us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 265us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 225us/step
# 32/32 [==============================] - 0s 275us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 280us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 233us/step
# ['GAPD_rev'] ---------------------------------------------------------------------- 145
# Stats for ['GAPD_rev'] CPU-time 733.9292
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['GLUDy_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 301us/step
# train = 0.96 test = 0.96 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 278us/step
# train = 0.96 test = 0.96 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 311us/step
# train = 0.96 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 283us/step
# train = 0.96 test = 0.97 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 311us/step
# train = 0.95 test = 0.95 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 245us/step
# ['GLUDy_rev'] ---------------------------------------------------------------------- 146
# Stats for ['GLUDy_rev'] CPU-time 735.6616
# R2 = 0.9606 (+/- 0.0036) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.9577 (+/- 0.0051) Constraint = -1.0000 (+/- 0.0000)
# ['GLUt2r_o']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 276us/step
# train = 0.99 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 300us/step
# train = 0.99 test = 0.99 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 276us/step
# train = 0.98 test = 0.98 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# looping bad training iter=0 r2=-0.0594
# 32/32 [==============================] - 0s 288us/step
# train = -0.06 test = -0.05 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 224us/step
# looping bad training iter=0 r2=-0.0573
# 32/32 [==============================] - 0s 299us/step
# train = -0.06 test = -0.06 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 238us/step
# ['GLUt2r_o'] ---------------------------------------------------------------------- 147
# Stats for ['GLUt2r_o'] CPU-time 734.4582
# R2 = 0.5693 (+/- 0.5125) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.5680 (+/- 0.5102) Constraint = -1.0000 (+/- 0.0000)
# ['H2Ot_o']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# looping bad training iter=0 r2=-0.0273
# 32/32 [==============================] - 0s 271us/step
# train = -0.03 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 624us/step
# looping bad training iter=0 r2=-0.0284
# 32/32 [==============================] - 0s 269us/step
# train = -0.03 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# looping bad training iter=0 r2=-0.0276
# 32/32 [==============================] - 0s 300us/step
# train = -0.03 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# looping bad training iter=0 r2=-0.0276
# 32/32 [==============================] - 0s 283us/step
# train = -0.03 test = -0.03 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# looping bad training iter=0 r2=-0.0294
# 32/32 [==============================] - 0s 293us/step
# train = -0.03 test = -0.02 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 236us/step
# ['H2Ot_o'] ---------------------------------------------------------------------- 148
# Stats for ['H2Ot_o'] CPU-time 735.3981
# R2 = -0.0280 (+/- 0.0008) Constraint = -1.0000 (+/- 0.0000)
# Q2 = -0.0282 (+/- 0.0030) Constraint = -1.0000 (+/- 0.0000)
# ['ICDHyr_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 311us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 278us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 285us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 227us/step
# 32/32 [==============================] - 0s 284us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 291us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 238us/step
# ['ICDHyr_rev'] ---------------------------------------------------------------------- 149
# Stats for ['ICDHyr_rev'] CPU-time 734.9081
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['LDH_D_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 290us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 282us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 296us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 300us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 304us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 240us/step
# ['LDH_D_rev'] ---------------------------------------------------------------------- 150
# Stats for ['LDH_D_rev'] CPU-time 735.4310
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['MDH_rev']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 281us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 232us/step
# 32/32 [==============================] - 0s 282us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 284us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 242us/step
# 32/32 [==============================] - 0s 293us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 231us/step
# 32/32 [==============================] - 0s 304us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 243us/step
# ['MDH_rev'] ---------------------------------------------------------------------- 151
# Stats for ['MDH_rev'] CPU-time 737.1771
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# ['NH4t_o']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 238us/step
# 32/32 [==============================] - 0s 296us/step
# train = 0.94 test = 0.96 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 286us/step
# train = 0.95 test = 0.93 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 244us/step
# 32/32 [==============================] - 0s 312us/step
# train = 0.95 test = 0.94 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 233us/step
# 32/32 [==============================] - 0s 265us/step
# train = 0.95 test = 0.97 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# looping bad training iter=0 r2=-0.1314
# 32/32 [==============================] - 0s 274us/step
# train = -0.13 test = -0.14 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 234us/step
# ['NH4t_o'] ---------------------------------------------------------------------- 152
# Stats for ['NH4t_o'] CPU-time 736.2523
# R2 = 0.7308 (+/- 0.4311) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 0.7310 (+/- 0.4356) Constraint = -1.0000 (+/- 0.0000)
# ['O2t_o']
# nbr parameters: 1101
# 125/125 [==============================] - 0s 226us/step
# 32/32 [==============================] - 0s 281us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 228us/step
# 32/32 [==============================] - 0s 300us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 236us/step
# 32/32 [==============================] - 0s 268us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 229us/step
# 32/32 [==============================] - 0s 304us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# nbr parameters: 1101
# 125/125 [==============================] - 0s 230us/step
# 32/32 [==============================] - 0s 273us/step
# train = 1.00 test = 1.00 loss-train = -1.000000 loss-test = -1.000000 iter=0
# 157/157 [==============================] - 0s 238us/step
# ['O2t_o'] ---------------------------------------------------------------------- 153
# Stats for ['O2t_o'] CPU-time 735.9696
# R2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = -1.0000 (+/- 0.0000)
# (5000, 154) (5000, 154)
# Q2= 0.96664035456977
# Loss_SV = 0.15700944
# Loss_Vin = 0.012584201
# Constraints = 0.08479681611061096
# '\nsize 10\nhidden_dim = 50 no scaler\n(10, 154) (10, 154)\nQ2= -0.07538283773845325\nLoss_SV 0.48731223\nLoss_Vin 0.2028226\nLoss_cst 0.34506741166114807\nhidden_dim = 50 with scaler : no better\nQ2= -0.04873539601415515\nLoss_SV = 0.45491654\nLoss_Vin = 0.20206484\nConstraints = 0.328490674495697\n\nsize 100\nhidden_dim = 50 no scaler\n(100, 154) (100, 154)\nQ2= 0.8483248084564434\nLoss_SV 0.36500132\nLoss_Vin 0.019197455\nLoss_cst 0.19209939241409302\nhidden_dim = 100 : no better\n(100, 154) (100, 154)\nQ2= 0.7824626824411614\nLoss_SV 0.46771127\nLoss_Vin 0.02226068\nLoss_cst 0.24498596787452698\n\nsize 500 no scaler\n\nsize 1000 no scaler\n(1000, 154) (1000, 154)\nQ2= 0.9507007593125759\nLoss_SV 0.19790417\nLoss_Vin 0.013121797\nLoss_cst 0.10551298409700394\n\nsize 10000 no scaler\n\n'

# %% [markdown]
# ## (3) Hybrid model: examples of trainable AMN model (neural and mechanistic) with FBA simulated training sets or experimental datasets

# %%
# Run this cell first
import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    DIRECTORY = '/content/drive/My Drive/AMN-Colab/'
    sys.path.append('/content/drive/My Drive/amn')
    ! pip install cobra
    ! pip install silence_tensorflow
else:
    DIRECTORY = './'
print(os.listdir(DIRECTORY))
    
from Build_Model import *

def printout(filename, Stats, model, time): 
    # printing Stats
    print('Stats for %s CPU-time %.4f' % (filename, time))
    print('R2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.train_objective[0], Stats.train_objective[1],
           Stats.train_loss[0], Stats.train_loss[1]))
    print('Q2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.test_objective[0], Stats.test_objective[1],
           Stats.test_loss[0], Stats.test_loss[1]))
# Out:
# ['Result', '.DS_Store', 'Dataset_model', 'Reservoir', 'old', '__pycache__', 'README.md', '.gitignore', 'Build_Dataset.ipynb', 'Build_Model.py', '.ipynb_checkpoints', 'Dataset_input', 'Build_Dataset.py', '.git', 'Build_Model.ipynb']

# %% [markdown]
# ### AMN LP or QP Neural + Mechanistic programs

# %%
# Create, train and evaluate AMN_QP o models with FBA simulated training set for E. coli core
# with EB or UB with a mechanistic layer

# What you can change 
seed = 10
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB' # can change EB by UB
timestep = 4
# End of What you can change
  
# Create model 90% for training 10% for testing
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
                     objective=['BIOMASS_Ecoli_core_w_GAM'],  
                     model_type='AMN_QP', 
                     timestep = timestep, learn_rate=0.01,
                     scaler=True,
                     n_hidden = 1, hidden_dim = 50,
                     epochs=500, xfold=5,
                     verbose=True)
ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0)
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y = Xtrain, Ytrain
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=False)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
reservoir.save(reservoirfile)
reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    X, Y = model_input(reservoir, verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  154 154
# number of metabolites:  72
# filtered measurements size:  1
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_QP
# model scaler: 1.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# gradient learn rate: 0.01
# gradient decay rate: 0.9
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# nbr parameters: 8904
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.97 test = 0.97 loss-train = 0.002241 loss-test = 0.002233 iter=0
# nbr parameters: 8904
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.003301 loss-test = 0.003456 iter=0
# nbr parameters: 8904
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.96 test = 0.96 loss-train = 0.003246 loss-test = 0.003244 iter=0
# nbr parameters: 8904
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.96 test = 0.95 loss-train = 0.001853 loss-test = 0.001889 iter=0
# nbr parameters: 8904
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.97 test = 0.97 loss-train = 0.001946 loss-test = 0.001820 iter=0
# 29/29 [==============================] - 0s 2ms/step
# Stats for e_coli_core_UB_AMN_QP CPU-time 1552.1402
# R2 = 0.9703 (+/- 0.0099) Constraint = 0.0025 (+/- 0.0006)
# Q2 = 0.9683 (+/- 0.0132) Constraint = 0.0025 (+/- 0.0007)
# ./Reservoir/e_coli_core_UB_AMN_QP_param.csv
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_QP
# model scaler: 10.0
# model input dim: 20
# model output dim: 312
# model medium bound: UB
# timestep: 4
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# gradient learn rate: 0.01
# gradient decay rate: 0.9
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 4/4 [==============================] - 0s 2ms/step
# Stats for Test set CPU-time 0.3070
# R2 = 0.9705 (+/- 0.0000) Constraint = 0.0020 (+/- 0.0000)
# Q2 = 0.9705 (+/- 0.0000) Constraint = 0.0020 (+/- 0.0000)

# %%
# Create, train and evaluate AMN_LP models with FBA simulated training set for E. coli core
# with UB with a mechanistic layer

# What you can change 
seed = 10
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB' # can change EB by UB
timestep = 4
# End of What you can change
  
# Create model 90% for training 10% for testing
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
                     objective=['BIOMASS_Ecoli_core_w_GAM'],  
                     model_type='AMN_LP', 
                     timestep = timestep, learn_rate=1.0e-6,
                     scaler=True,
                     n_hidden = 1, hidden_dim = 50,
                     epochs= 500, xfold=5,
                     verbose=True)
ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), 
                      replace=False)
# LP keeps track of boundary fluxes in b_int and b_ext
# and these are different in EB or UB modes
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
btest = model.b_ext[ID,:] if model.mediumbound == 'UB' else model.b_int[ID,:]
bint  = model.b_int if model.mediumbound == 'UB' else model.b_ext
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0)
btrain = np.delete(model.b_ext, ID, axis=0) if model.mediumbound == 'UB' \
else np.delete(model.b_int, ID, axis=0)
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y, model.b_ext, model.b_int = Xtrain, Ytrain, btrain, bint
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=False)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
reservoir.save(reservoirfile)
reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    reservoir.b_ext, reservoir.b_int =  btest, bint
    X, Y = model_input(reservoir,verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  154 154
# number of metabolites:  72
# filtered measurements size:  1
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_LP
# model scaler: 1.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# nbr parameters: 25152
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.96 test = 0.96 loss-train = 0.002815 loss-test = 0.002802 iter=0
# nbr parameters: 25152
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.97 test = 0.98 loss-train = 0.002668 loss-test = 0.002781 iter=0
# nbr parameters: 25152
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.97 test = 0.97 loss-train = 0.002129 loss-test = 0.002127 iter=0
# nbr parameters: 25152
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.001967 loss-test = 0.002012 iter=0
# nbr parameters: 25152
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.98 test = 0.98 loss-train = 0.003014 loss-test = 0.002824 iter=0
# 29/29 [==============================] - 0s 2ms/step
# Stats for e_coli_core_UB_AMN_LP CPU-time 848.4390
# R2 = 0.9751 (+/- 0.0097) Constraint = 0.0025 (+/- 0.0004)
# Q2 = 0.9742 (+/- 0.0101) Constraint = 0.0025 (+/- 0.0004)
# ./Reservoir/e_coli_core_UB_AMN_LP_param.csv
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_LP
# model scaler: 10.0
# model input dim: 20
# model output dim: 312
# model medium bound: UB
# timestep: 4
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 4/4 [==============================] - 307s 669ms/step
# Stats for Test set CPU-time 306.8436
# R2 = 0.9787 (+/- 0.0000) Constraint = 0.0031 (+/- 0.0000)
# Q2 = 0.9787 (+/- 0.0000) Constraint = 0.0031 (+/- 0.0000)

# %%
# Create, train and evaluate AMN_QP models with FBA simulated training set for iML1515
# with EB or UB with a mechanistic layer 
# This cell takes several hours to execute

# What you can change 
seed = 1
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'iML1515_UB'
timestep = 4
# End of What you can change
  
# Create model 
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_QP',
              scaler = True,
              timestep = timestep, learn_rate=0.01,
              n_hidden = 1, hidden_dim = 500,
              epochs = 25, xfold = 5, 
              verbose=True) 
ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0)
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y = Xtrain, Ytrain
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=2)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
#reservoir.save(reservoirfile)
#reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    X, Y = model_input(reservoir, verbose=False)
    reservoir.model.b_ext = btest
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_QP
# model scaler: 1.0
# model input dim: 38
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# gradient learn rate: 0.01
# gradient decay rate: 0.9
# training epochs: 25
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# AMN scaler 11.0
# QP input shape (9900, 38) (9900, 4)
# -------train [   0    1    3 ... 9897 9898 9899]
# -------test  [   2    4    6 ... 9883 9891 9893]
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 550 relu True
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Model: "model_95"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_96 (InputLayer)          [(None, 38)]         0           []
#
#  dense_372 (Dense)              (None, 500)          19500       ['input_96[0][0]']
#
#  dropout_186 (Dropout)          (None, 500)          0           ['dense_372[0][0]']
#
#  dense_373 (Dense)              (None, 550)          275550      ['dropout_186[0][0]']
#
#  tf.linalg.matmul_448 (TFOpLamb  (None, 550)         0           ['input_96[0][0]']
#  da)
#
#  tf.math.subtract_320 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_448[0][0]',
#  da)                                                              'dense_373[0][0]']
#
#  tf.nn.relu_320 (TFOpLambda)    (None, 550)          0           ['tf.math.subtract_320[0][0]']
#
#  tf.math.divide_no_nan_235 (TFO  (None, 550)         0           ['tf.nn.relu_320[0][0]',
#  pLambda)                                                         'tf.nn.relu_320[0][0]']
#
#  tf.math.subtract_321 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_235[0][0]
#  da)                                                             ']
#
#  tf.math.multiply_839 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_235[0][0]
#  da)                                                             ',
#                                                                   'dense_373[0][0]']
#
#  tf.math.multiply_840 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_321[0][0]',
#  da)                                                              'tf.linalg.matmul_448[0][0]']
#
#  tf.math.multiply_841 (TFOpLamb  (None, 550)         0           ['dense_373[0][0]']
#  da)
#
#  tf.__operators__.add_240 (TFOp  (None, 550)         0           ['tf.math.multiply_839[0][0]',
#  Lambda)                                                          'tf.math.multiply_840[0][0]']
#
#  tf.__operators__.add_241 (TFOp  (None, 550)         0           ['tf.math.multiply_841[0][0]',
#  Lambda)                                                          'tf.__operators__.add_240[0][0]'
#                                                                  ]
#
#  tf.linalg.matmul_451 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_241[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_322 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_451[0][0]',
#  da)                                                              'input_96[0][0]']
#
#  tf.nn.relu_321 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_322[0][0]']
#
#  tf.math.negative_128 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_241[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_449 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_241[0][0]'
#  da)                                                             ]
#
#  tf.math.divide_no_nan_236 (TFO  (None, 38)          0           ['tf.nn.relu_321[0][0]',
#  pLambda)                                                         'tf.nn.relu_321[0][0]']
#
#  tf.nn.relu_322 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_128[0][0]']
#
#  tf.linalg.matmul_450 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_449[0][0]']
#  da)
#
#  tf.math.multiply_843 (TFOpLamb  (None, 38)          0           ['tf.nn.relu_321[0][0]',
#  da)                                                              'tf.math.divide_no_nan_236[0][0]
#                                                                  ']
#
#  tf.math.divide_no_nan_237 (TFO  (None, 550)         0           ['tf.nn.relu_322[0][0]',
#  pLambda)                                                         'tf.nn.relu_322[0][0]']
#
#  tf.math.truediv_492 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_450[0][0]']
#  a)
#
#  tf.linalg.matmul_452 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_843[0][0]']
#  da)
#
#  tf.math.negative_129 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_237[0][0]
#  da)                                                             ']
#
#  tf.math.truediv_493 (TFOpLambd  (None, 550)         0           ['tf.math.truediv_492[0][0]']
#  a)
#
#  tf.math.truediv_495 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_452[0][0]']
#  a)
#
#  tf.math.multiply_844 (TFOpLamb  (None, 550)         0           ['tf.nn.relu_322[0][0]',
#  da)                                                              'tf.math.negative_129[0][0]']
#
#  tf.__operators__.add_242 (TFOp  (None, 550)         0           ['tf.math.truediv_493[0][0]',
#  Lambda)                                                          'tf.math.truediv_495[0][0]']
#
#  tf.math.truediv_497 (TFOpLambd  (None, 550)         0           ['tf.math.multiply_844[0][0]']
#  a)
#
#  tf.__operators__.add_243 (TFOp  (None, 550)         0           ['tf.__operators__.add_242[0][0]'
#  Lambda)                                                         , 'tf.math.truediv_497[0][0]']
#
#  tf.math.multiply_842 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_241[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_845 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_243[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_846 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_842[0][0]']
#  da)
#
#  tf.math.multiply_847 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_845[0][0]']
#  da)
#
#  tf.math.subtract_323 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_846[0][0]',
#  da)                                                              'tf.math.multiply_847[0][0]']
#
#  tf.__operators__.add_244 (TFOp  (None, 550)         0           ['tf.__operators__.add_241[0][0]'
#  Lambda)                                                         , 'tf.math.subtract_323[0][0]']
#
#  tf.linalg.matmul_455 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_244[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_324 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_455[0][0]',
#  da)                                                              'input_96[0][0]']
#
#  tf.nn.relu_323 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_324[0][0]']
#
#  tf.math.negative_130 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_244[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_453 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_244[0][0]'
#  da)                                                             ]
#
#  tf.math.divide_no_nan_239 (TFO  (None, 38)          0           ['tf.nn.relu_323[0][0]',
#  pLambda)                                                         'tf.nn.relu_323[0][0]']
#
#  tf.nn.relu_324 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_130[0][0]']
#
#  tf.linalg.matmul_454 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_453[0][0]']
#  da)
#
#  tf.math.multiply_848 (TFOpLamb  (None, 38)          0           ['tf.nn.relu_323[0][0]',
#  da)                                                              'tf.math.divide_no_nan_239[0][0]
#                                                                  ']
#
#  tf.math.divide_no_nan_240 (TFO  (None, 550)         0           ['tf.nn.relu_324[0][0]',
#  pLambda)                                                         'tf.nn.relu_324[0][0]']
#
#  tf.math.truediv_499 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_454[0][0]']
#  a)
#
#  tf.linalg.matmul_456 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_848[0][0]']
#  da)
#
#  tf.math.negative_131 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_240[0][0]
#  da)                                                             ']
#
#  tf.math.truediv_500 (TFOpLambd  (None, 550)         0           ['tf.math.truediv_499[0][0]']
#  a)
#
#  tf.math.truediv_502 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_456[0][0]']
#  a)
#
#  tf.math.multiply_849 (TFOpLamb  (None, 550)         0           ['tf.nn.relu_324[0][0]',
#  da)                                                              'tf.math.negative_131[0][0]']
#
#  tf.__operators__.add_245 (TFOp  (None, 550)         0           ['tf.math.truediv_500[0][0]',
#  Lambda)                                                          'tf.math.truediv_502[0][0]']
#
#  tf.math.truediv_504 (TFOpLambd  (None, 550)         0           ['tf.math.multiply_849[0][0]']
#  a)
#
#  tf.__operators__.add_246 (TFOp  (None, 550)         0           ['tf.__operators__.add_245[0][0]'
#  Lambda)                                                         , 'tf.math.truediv_504[0][0]']
#
#  tf.math.multiply_850 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_246[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_851 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_323[0][0]']
#  da)
#
#  tf.math.multiply_852 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_850[0][0]']
#  da)
#
#  tf.math.subtract_325 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_851[0][0]',
#  da)                                                              'tf.math.multiply_852[0][0]']
#
#  tf.__operators__.add_247 (TFOp  (None, 550)         0           ['tf.__operators__.add_244[0][0]'
#  Lambda)                                                         , 'tf.math.subtract_325[0][0]']
#
#  tf.linalg.matmul_459 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_247[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_326 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_459[0][0]',
#  da)                                                              'input_96[0][0]']
#
#  tf.nn.relu_325 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_326[0][0]']
#
#  tf.math.negative_132 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_247[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_457 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_247[0][0]'
#  da)                                                             ]
#
#  tf.math.divide_no_nan_242 (TFO  (None, 38)          0           ['tf.nn.relu_325[0][0]',
#  pLambda)                                                         'tf.nn.relu_325[0][0]']
#
#  tf.nn.relu_326 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_132[0][0]']
#
#  tf.linalg.matmul_458 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_457[0][0]']
#  da)
#
#  tf.math.multiply_853 (TFOpLamb  (None, 38)          0           ['tf.nn.relu_325[0][0]',
#  da)                                                              'tf.math.divide_no_nan_242[0][0]
#                                                                  ']
#
#  tf.math.divide_no_nan_243 (TFO  (None, 550)         0           ['tf.nn.relu_326[0][0]',
#  pLambda)                                                         'tf.nn.relu_326[0][0]']
#
#  tf.math.truediv_506 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_458[0][0]']
#  a)
#
#  tf.linalg.matmul_460 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_853[0][0]']
#  da)
#
#  tf.math.negative_133 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_243[0][0]
#  da)                                                             ']
#
#  tf.math.truediv_507 (TFOpLambd  (None, 550)         0           ['tf.math.truediv_506[0][0]']
#  a)
#
#  tf.math.truediv_509 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_460[0][0]']
#  a)
#
#  tf.math.multiply_854 (TFOpLamb  (None, 550)         0           ['tf.nn.relu_326[0][0]',
#  da)                                                              'tf.math.negative_133[0][0]']
#
#  tf.__operators__.add_248 (TFOp  (None, 550)         0           ['tf.math.truediv_507[0][0]',
#  Lambda)                                                          'tf.math.truediv_509[0][0]']
#
#  tf.math.truediv_511 (TFOpLambd  (None, 550)         0           ['tf.math.multiply_854[0][0]']
#  a)
#
#  tf.__operators__.add_249 (TFOp  (None, 550)         0           ['tf.__operators__.add_248[0][0]'
#  Lambda)                                                         , 'tf.math.truediv_511[0][0]']
#
#  tf.math.multiply_855 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_249[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_856 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_325[0][0]']
#  da)
#
#  tf.math.multiply_857 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_855[0][0]']
#  da)
#
#  tf.math.subtract_327 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_856[0][0]',
#  da)                                                              'tf.math.multiply_857[0][0]']
#
#  tf.__operators__.add_250 (TFOp  (None, 550)         0           ['tf.__operators__.add_247[0][0]'
#  Lambda)                                                         , 'tf.math.subtract_327[0][0]']
#
#  tf.linalg.matmul_463 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_250[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_328 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_463[0][0]',
#  da)                                                              'input_96[0][0]']
#
#  tf.nn.relu_327 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_328[0][0]']
#
#  tf.math.negative_134 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_250[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_461 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_250[0][0]'
#  da)                                                             ]
#
#  tf.math.divide_no_nan_245 (TFO  (None, 38)          0           ['tf.nn.relu_327[0][0]',
#  pLambda)                                                         'tf.nn.relu_327[0][0]']
#
#  tf.nn.relu_328 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_134[0][0]']
#
#  tf.linalg.matmul_462 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_461[0][0]']
#  da)
#
#  tf.math.multiply_858 (TFOpLamb  (None, 38)          0           ['tf.nn.relu_327[0][0]',
#  da)                                                              'tf.math.divide_no_nan_245[0][0]
#                                                                  ']
#
#  tf.math.divide_no_nan_246 (TFO  (None, 550)         0           ['tf.nn.relu_328[0][0]',
#  pLambda)                                                         'tf.nn.relu_328[0][0]']
#
#  tf.math.truediv_513 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_462[0][0]']
#  a)
#
#  tf.linalg.matmul_464 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_858[0][0]']
#  da)
#
#  tf.math.negative_135 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_246[0][0]
#  da)                                                             ']
#
#  tf.math.truediv_514 (TFOpLambd  (None, 550)         0           ['tf.math.truediv_513[0][0]']
#  a)
#
#  tf.math.truediv_516 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_464[0][0]']
#  a)
#
#  tf.math.multiply_859 (TFOpLamb  (None, 550)         0           ['tf.nn.relu_328[0][0]',
#  da)                                                              'tf.math.negative_135[0][0]']
#
#  tf.__operators__.add_251 (TFOp  (None, 550)         0           ['tf.math.truediv_514[0][0]',
#  Lambda)                                                          'tf.math.truediv_516[0][0]']
#
#  tf.math.truediv_518 (TFOpLambd  (None, 550)         0           ['tf.math.multiply_859[0][0]']
#  a)
#
#  tf.__operators__.add_252 (TFOp  (None, 550)         0           ['tf.__operators__.add_251[0][0]'
#  Lambda)                                                         , 'tf.math.truediv_518[0][0]']
#
#  tf.math.multiply_860 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_252[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_861 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_327[0][0]']
#  da)
#
#  tf.math.multiply_862 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_860[0][0]']
#  da)
#
#  tf.math.subtract_329 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_861[0][0]',
#  da)                                                              'tf.math.multiply_862[0][0]']
#
#  tf.__operators__.add_253 (TFOp  (None, 550)         0           ['tf.__operators__.add_250[0][0]'
#  Lambda)                                                         , 'tf.math.subtract_329[0][0]']
#
#  tf.linalg.matmul_467 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_253[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_330 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_467[0][0]',
#  da)                                                              'input_96[0][0]']
#
#  tf.math.negative_136 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_253[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_466 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_253[0][0]'
#  da)                                                             ]
#
#  tf.nn.relu_329 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_330[0][0]']
#
#  tf.nn.relu_330 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_136[0][0]']
#
#  tf.compat.v1.norm_348 (TFOpLam  (None, 1)           0           ['tf.linalg.matmul_466[0][0]']
#  bda)
#
#  tf.compat.v1.norm_349 (TFOpLam  (None, 1)           0           ['tf.nn.relu_329[0][0]']
#  bda)
#
#  tf.compat.v1.norm_350 (TFOpLam  (None, 1)           0           ['tf.nn.relu_330[0][0]']
#  bda)
#
#  tf.linalg.matmul_465 (TFOpLamb  (None, 1)           0           ['tf.__operators__.add_253[0][0]'
#  da)                                                             ]
#
#  tf.math.truediv_519 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_348[0][0]']
#  a)
#
#  tf.math.truediv_520 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_349[0][0]']
#  a)
#
#  tf.math.truediv_521 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_350[0][0]']
#  a)
#
#  concatenate_277 (Concatenate)  (None, 1104)         0           ['tf.linalg.matmul_465[0][0]',
#                                                                   'tf.math.truediv_519[0][0]',
#                                                                   'tf.math.truediv_520[0][0]',
#                                                                   'tf.math.truediv_521[0][0]',
#                                                                   'tf.__operators__.add_253[0][0]'
#                                                                  , 'tf.__operators__.add_241[0][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 295,050
# Trainable params: 295,050
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters:
25
# 1584/1584 [==============================] - 35s 22ms/step - loss: 9.1710e-05 - my_mae: 9.1710e-05 - val_loss: 5.2978e-05 - val_my_mae: 5.2978e-05
# Epoch 21/25
# 1584/1584 [==============================] - 35s 22ms/step - loss: 1.0021e-04 - my_mae: 1.0021e-04 - val_loss: 1.1463e-05 - val_my_mae: 1.1463e-05
# Epoch 22/25
# 1584/1584 [==============================] - 36s 23ms/step - loss: 1.1377e-04 - my_mae: 1.1377e-04 - val_loss: 2.7071e-05 - val_my_mae: 2.7071e-05
# Epoch 23/25
# 1584/1584 [==============================] - 36s 23ms/step - loss: 9.7756e-05 - my_mae: 9.7756e-05 - val_loss: 2.7518e-05 - val_my_mae: 2.7518e-05
# Epoch 24/25
# 1584/1584 [==============================] - 37s 23ms/step - loss: 1.0018e-04 - my_mae: 1.0018e-04 - val_loss: 1.6507e-05 - val_my_mae: 1.6507e-05
# Epoch 25/25
# 1584/1584 [==============================] - 38s 24ms/step - loss: 9.7244e-05 - my_mae: 9.7244e-05 - val_loss: 5.0222e-05 - val_my_mae: 5.0222e-05
# 248/248 [==============================] - 3s 11ms/step
# Loss out on V0:  0.010585983
# Loss constraint on V0:  1.9160505e-06
# Loss all on V0:  4.9545317e-05
# Loss out on Vf:  0.01057917
# Loss constraint on Vf:  1.9150154e-06
# Loss all on Vf:  4.949235e-05
# Distance V0 to Vf 0.000749:
# 62/62 [==============================] - 1s 11ms/step
# Loss out on V0:  0.010480203
# Loss constraint on V0:  1.9227512e-06
# Loss all on V0:  5.0273124e-05
# Loss out on Vf:  0.010473374
# Loss constraint on Vf:  1.9217139e-06
# Loss all on Vf:  5.0221704e-05
# Distance V0 to Vf 0.000375:
# train = 0.99 test = 0.99 loss-train = 0.000002 loss-test = 0.000002 iter=0
# -------train [   0    1    2 ... 9897 9898 9899]
# -------test  [  20   22   23 ... 9885 9887 9894]
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 550 relu True
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Model: "model_96"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_97 (InputLayer)          [(None, 38)]         0           []
#
#  dense_374 (Dense)              (None, 500)          19500       ['input_97[0][0]']
#
#  dropout_187 (Dropout)          (None, 500)          0           ['dense_374[0][0]']
#
#  dense_375 (Dense)              (None, 550)          275550      ['dropout_187[0][0]']
#
#  tf.linalg.matmul_468 (TFOpLamb  (None, 550)         0           ['input_97[0][0]']
#  da)
#
#  tf.math.subtract_331 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_468[0][0]',
#  da)                                                              'dense_375[0][0]']
#
#  tf.nn.relu_331 (TFOpLambda)    (None, 550)          0           ['tf.math.subtract_331[0][0]']
#
#  tf.math.divide_no_nan_248 (TFO  (None, 550)         0           ['tf.nn.relu_331[0][0]',
#  pLambda)                                                         'tf.nn.relu_331[0][0]']
#
#  tf.math.subtract_332 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_248[0][0]
#  da)                                                             ']
#
#  tf.math.multiply_866 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_248[0][0]
#  da)                                                             ',
#                                                                   'dense_375[0][0]']
#
#  tf.math.multiply_867 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_332[0][0]',
#  da)                                                              'tf.linalg.matmul_468[0][0]']
#
#  tf.math.multiply_868 (TFOpLamb  (None, 550)         0           ['dense_375[0][0]']
#  da)
#
#  tf.__operators__.add_254 (TFOp  (None, 550)         0           ['tf.math.multiply_866[0][0]',
#  Lambda)                                                          'tf.math.multiply_867[0][0]']
#
#  tf.__operators__.add_255 (TFOp  (None, 550)         0           ['tf.math.multiply_868[0][0]',
#  Lambda)                                                          'tf.__operators__.add_254[0][0]'
#                                                                  ]
#
#  tf.linalg.matmul_471 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_255[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_333 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_471[0][0]',
#  da)                                                              'input_97[0][0]']
#
# ...
#
#  tf.nn.relu_372 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_170[0][0]']
#
#  tf.linalg.matmul_542 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_541[0][0]']
#  da)
#
#  tf.math.multiply_966 (TFOpLamb  (None, 38)          0           ['tf.nn.relu_371[0][0]',
#  da)                                                              'tf.math.divide_no_nan_297[0][0]
#                                                                  ']
#
#  tf.math.divide_no_nan_298 (TFO  (None, 550)         0           ['tf.nn.relu_372[0][0]',
#  pLambda)                                                         'tf.nn.relu_372[0][0]']
#
#  tf.math.truediv_637 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_542[0][0]']
#  a)
#
#  tf.linalg.matmul_544 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_966[0][0]']
#  da)
#
#  tf.math.negative_171 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_298[0][0]
#  da)                                                             ']
#
#  tf.math.truediv_638 (TFOpLambd  (None, 550)         0           ['tf.math.truediv_637[0][0]']
#  a)
#
#  tf.math.truediv_640 (TFOpLambd  (None, 550)         0           ['tf.linalg.matmul_544[0][0]']
#  a)
#
#  tf.math.multiply_967 (TFOpLamb  (None, 550)         0           ['tf.nn.relu_372[0][0]',
#  da)                                                              'tf.math.negative_171[0][0]']
#
#  tf.__operators__.add_307 (TFOp  (None, 550)         0           ['tf.math.truediv_638[0][0]',
#  Lambda)                                                          'tf.math.truediv_640[0][0]']
#
#  tf.math.truediv_642 (TFOpLambd  (None, 550)         0           ['tf.math.multiply_967[0][0]']
#  a)
#
#  tf.__operators__.add_308 (TFOp  (None, 550)         0           ['tf.__operators__.add_307[0][0]'
#  Lambda)                                                         , 'tf.math.truediv_642[0][0]']
#
#  tf.math.multiply_968 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_308[0][0]'
#  da)                                                             ]
#
#  tf.math.multiply_969 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_371[0][0]']
#  da)
#
#  tf.math.multiply_970 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_968[0][0]']
#  da)
#
#  tf.math.subtract_373 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_969[0][0]',
#  da)                                                              'tf.math.multiply_970[0][0]']
#
#  tf.__operators__.add_309 (TFOp  (None, 550)         0           ['tf.__operators__.add_306[0][0]'
#  Lambda)                                                         , 'tf.math.subtract_373[0][0]']
#
#  tf.linalg.matmul_547 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_309[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_374 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_547[0][0]',
#  da)                                                              'input_100[0][0]']
#
#  tf.math.negative_172 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_309[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_546 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_309[0][0]'
#  da)                                                             ]
#
#  tf.nn.relu_373 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_374[0][0]']
#
#  tf.nn.relu_374 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_172[0][0]']
#
#  tf.compat.v1.norm_408 (TFOpLam  (None, 1)           0           ['tf.linalg.matmul_546[0][0]']
#  bda)
#
#  tf.compat.v1.norm_409 (TFOpLam  (None, 1)           0           ['tf.nn.relu_373[0][0]']
#  bda)
#
#  tf.compat.v1.norm_410 (TFOpLam  (None, 1)           0           ['tf.nn.relu_374[0][0]']
#  bda)
#
#  tf.linalg.matmul_545 (TFOpLamb  (None, 1)           0           ['tf.__operators__.add_309[0][0]'
#  da)                                                             ]
#
#  tf.math.truediv_643 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_408[0][0]']
#  a)
#
#  tf.math.truediv_644 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_409[0][0]']
#  a)
#
#  tf.math.truediv_645 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_410[0][0]']
#  a)
#
#  concatenate_281 (Concatenate)  (None, 1104)         0           ['tf.linalg.matmul_545[0][0]',
#                                                                   'tf.math.truediv_643[0][0]',
#                                                                   'tf.math.truediv_644[0][0]',
#                                                                   'tf.math.truediv_645[0][0]',
#                                                                   'tf.__operators__.add_309[0][0]'
#                                                                  , 'tf.__operators__.add_297[0][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 295,050
# Trainable params: 295,050
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters: 295050
# Epoch 1/25
# 1584/1584 [==============================] - 35s 21ms/step - loss: 5.9056e-04 - my_mae: 5.9056e-04 - val_loss: 7.1564e-05 - val_my_mae: 7.1564e-05
# Epoch 2/25
# 1584/1584 [==============================] - 34s 21ms/step - loss: 1.4100e-04 - my_mae: 1.4100e-04 - val_loss: 2.4672e-05 - val_my_mae: 2.4672e-05
# Epoch 3/25
# 1584/1584 [==============================] - 33s 21ms/step - loss: 1.2451e-04 - my_mae: 1.2451e-04 - val_loss: 1.6967e-05 - val_my_mae: 1.6967e-05
# Epoch 4/25
# 1584/1584 [==============================] - 33s 21ms/step - loss: 1.1166e-04 - my_mae: 1.1166e-04 - val_loss: 4.5601e-04 - val_my_mae: 4.5601e-04
# Epoch 5/25
# 1584/1584 [==============================] - 32s 20ms/step - loss: 1.1295e-04 - my_mae: 1.1295e-04 - val_loss: 2.5795e-05 - val_my_mae: 2.5795e-05
# Epoch 6/25
# 1584/1584 [==============================] - 46s 29ms/step - loss: 1.0644e-04 - my_mae: 1.0644e-04 - val_loss: 2.7447e-05 - val_my_mae: 2.7447e-05
# Epoch 7/25
# 1584/1584 [==============================] - 38s 24ms/step - loss: 9.7370e-05 - my_mae: 9.7370e-05 - val_loss: 2.5537e-05 - val_my_mae: 2.5537e-05
# Epoch 8/25
# 1584/1584 [==============================] - 35s 22ms/step - loss: 9.6991e-05 - my_mae: 9.6991e-05 - val_loss: 3.9069e-05 - val_my_mae: 3.9069e-05
# Epoch 9/25
# 1584/1584 [==============================] - 37s 23ms/step - loss: 1.0596e-04 - my_mae: 1.0596e-04 - val_loss: 1.8243e-05 - val_my_mae: 1.8243e-05
# Epoch 10/25
# 1584/1584 [==============================] - 28s 18ms/step - loss: 1.0158e-04 - my_mae: 1.0158e-04 - val_loss: 4.4870e-05 - val_my_mae: 4.4870e-05
# Epoch 11/25
# 1584/1584 [==============================] - 28s 18ms/step - loss: 9.8169e-05 - my_mae: 9.8169e-05 - val_loss: 5.8260e-05 - val_my_mae: 5.8260e-05
# Epoch 12/25
# 1584/1584 [==============================] - 27s 17ms/step - loss: 8.8370e-05 - my_mae: 8.8370e-05 - val_loss: 4.5958e-05 - val_my_mae: 4.5958e-05
# Epoch 13/25
# 310/310 [==============================] - 4s 12ms/step
# Loss out on V0:  0.007513972
# Loss constraint on V0:  1.8300486e-06
# Loss all on V0:  3.1613872e-05
# Loss out on Vf:  0.007511472
# Loss constraint on Vf:  1.8295582e-06
# Loss all on Vf:  3.1590716e-05
# Distance V0 to Vf 0.000576:
# Stats for iML1515_UB_AMN_QP CPU-time 4445.7780
# R2 = 0.9971 (+/- 0.0014) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9969 (+/- 0.0013) Constraint = 0.0000 (+/- 0.0000)
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_QP
# model scaler: 11.0
# model input dim: 38
# model output dim: 1104
# model medium bound: UB
# timestep: 4
# training set size (9900, 38) (9900, 4)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# gradient learn rate: 0.01
# gradient decay rate: 0.9
# training epochs: 25
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 35/35 [==============================] - 0s 12ms/step
# Stats for Test set CPU-time 0.4460
# R2 = 0.9971 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9971 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)

# %%
# Create, train and evaluate AMN_LP models with FBA simulated training set for iML1515
# with UB with a mechanistic layer 
# This cell takes several hours to execute

# What you can change 
seed = 1
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'iML1515_UB'
timestep = 4
# End of What you can change
  
# Create model 
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_LP',
              scaler = True,
              timestep = timestep, learn_rate=1.0e-6,
              n_hidden = 1, hidden_dim = 250,
              epochs = 25, xfold = 5, 
              verbose=True) 

ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), 
                      replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
btest = model.b_ext[ID,:]
bint = model.b_int
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0)
btrain = np.delete(model.b_ext, ID, axis=0)
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y, model.b_ext, model.b_int = Xtrain, Ytrain, btrain, bint
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=2)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
#reservoir.save(reservoirfile)
#reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    reservoir.b_ext, reservoir.b_int =  btest, bint
    X, Y = model_input(reservoir,verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_LP
# model scaler: 1.0
# model input dim: 38
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 250
# activation function: relu
# training epochs: 25
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# AMN scaler 11.0
# LP input shape (9900, 3235) (9900, 4)
# -------train [   0    1    3 ... 9897 9898 9899]
# -------test  [   2    4    6 ... 9883 9891 9893]
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 250 550 relu True
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 250 2716 linear True
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Model: "model_29"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_30 (InputLayer)          [(None, 3235)]       0           []
#
#  lambda_54 (Lambda)             (None, 38)           0           ['input_30[0][0]']
#
#  dense_82 (Dense)               (None, 250)          9750        ['lambda_54[0][0]']
#
#  dropout_41 (Dropout)           (None, 250)          0           ['dense_82[0][0]']
#
#  dense_83 (Dense)               (None, 550)          138050      ['dropout_41[0][0]']
#
#  tf.linalg.matmul_694 (TFOpLamb  (None, 550)         0           ['lambda_54[0][0]']
#  da)
#
#  tf.math.subtract_451 (TFOpLamb  (None, 550)         0           ['tf.linalg.matmul_694[0][0]',
#  da)                                                              'dense_83[0][0]']
#
#  tf.nn.relu_265 (TFOpLambda)    (None, 550)          0           ['tf.math.subtract_451[0][0]']
#
#  tf.math.divide_no_nan_143 (TFO  (None, 550)         0           ['tf.nn.relu_265[0][0]',
#  pLambda)                                                         'tf.nn.relu_265[0][0]']
#
#  tf.math.subtract_452 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_143[0][0]
#  da)                                                             ']
#
#  tf.math.multiply_741 (TFOpLamb  (None, 550)         0           ['tf.math.divide_no_nan_143[0][0]
#  da)                                                             ',
#                                                                   'dense_83[0][0]']
#
#  tf.math.multiply_742 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_452[0][0]',
#  da)                                                              'tf.linalg.matmul_694[0][0]']
#
#  tf.math.multiply_743 (TFOpLamb  (None, 550)         0           ['dense_83[0][0]']
#  da)
#
#  tf.__operators__.add_526 (TFOp  (None, 550)         0           ['tf.math.multiply_741[0][0]',
#  Lambda)                                                          'tf.math.multiply_742[0][0]']
#
#  tf.__operators__.add_527 (TFOp  (None, 550)         0           ['tf.math.multiply_743[0][0]',
#  Lambda)                                                          'tf.__operators__.add_526[0][0]'
#                                                                  ]
#
#  dense_84 (Dense)               (None, 250)          9750        ['lambda_54[0][0]']
#
#  tf.expand_dims_360 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_527[0][0]'
#  )                                                               ]
#
#  dropout_42 (Dropout)           (None, 250)          0           ['dense_84[0][0]']
#
#  tf.linalg.matmul_697 (TFOpLamb  (None, 2716, 1)     0           ['tf.expand_dims_360[0][0]']
#  da)
#
#  dense_85 (Dense)               (None, 2716)         681716      ['dropout_42[0][0]']
#
#  tf.compat.v1.squeeze_360 (TFOp  (None, 2716)        0           ['tf.linalg.matmul_697[0][0]']
#  Lambda)
#
#  tf.__operators__.add_530 (TFOp  (None, 2716)        0           ['dense_85[0][0]',
#  Lambda)                                                          'tf.compat.v1.squeeze_360[0][0]'
#                                                                  ]
#
#  lambda_56 (Lambda)             (None, 2716)         0           ['input_30[0][0]']
#
#  tf.math.subtract_454 (TFOpLamb  (None, 2716)        0           ['tf.__operators__.add_530[0][0]'
#  da)                                                             , 'lambda_56[0][0]']
#
#  tf.nn.relu_268 (TFOpLambda)    (None, 2716)         0           ['tf.math.subtract_454[0][0]']
#
#  tf.expand_dims_361 (TFOpLambda  (None, 2716, 1)     0           ['tf.nn.relu_268[0][0]']
#  )
#
#  tf.expand_dims_363 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_527[0][0]'
#  )                                                               ]
#
#  tf.linalg.matmul_698 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_361[0][0]']
#  da)
#
#  tf.linalg.matmul_700 (TFOpLamb  (None, 481, 1)      0           ['tf.expand_dims_363[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_361 (TFOp  (None, 550)         0           ['tf.linalg.matmul_698[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_363 (TFOp  (None, 481)         0           ['tf.linalg.matmul_700[0][0]']
#  Lambda)
#
#  lambda_55 (Lambda)             (None, 481)          0           ['input_30[0][0]']
#
#  tf.__operators__.add_531 (TFOp  (None, 550)         0           ['tf.compat.v1.squeeze_361[0][0]'
#  Lambda)                                                         ]
#
#  tf.math.subtract_455 (TFOpLamb  (None, 481)         0           ['tf.compat.v1.squeeze_363[0][0]'
#  da)                                                             , 'lambda_55[0][0]']
#
#  tf.expand_dims_362 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_531[0][0]'
#  )                                                               ]
#
#  tf.expand_dims_364 (TFOpLambda  (None, 481, 1)      0           ['tf.math.subtract_455[0][0]']
#  )
#
#  tf.linalg.matmul_699 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_362[0][0]']
#  da)
#
#  tf.linalg.matmul_701 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_364[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_362 (TFOp  (None, 550)         0           ['tf.linalg.matmul_699[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_364 (TFOp  (None, 550)         0           ['tf.linalg.matmul_701[0][0]']
#  Lambda)
#
#  tf.math.subtract_456 (TFOpLamb  (None, 550)         0           ['tf.compat.v1.squeeze_362[0][0]'
#  da)                                                             , 'tf.compat.v1.squeeze_364[0][0]
#                                                                  ']
#
#  tf.math.multiply_748 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_456[0][0]']
#  da)
#
#  tf.math.multiply_749 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_748[0][0]']
#  da)
#
#  tf.__operators__.add_532 (TFOp  (None, 550)         0           ['tf.__operators__.add_527[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_749[0][0]']
#
#  tf.math.subtract_457 (TFOpLamb  (None, 2716)        0           ['tf.nn.relu_268[0][0]',
#  da)                                                              'dense_85[0][0]']
#
#  tf.math.multiply_747 (TFOpLamb  (None, 2716)        0           ['tf.math.subtract_457[0][0]']
#  da)
#
#  tf.expand_dims_365 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_532[0][0]'
#  )                                                               ]
#
#  tf.math.multiply_750 (TFOpLamb  (None, 2716)        0           ['tf.math.multiply_747[0][0]']
#  da)
#
#  tf.linalg.matmul_704 (TFOpLamb  (None, 2716, 1)     0           ['tf.expand_dims_365[0][0]']
#  da)
#
#  tf.__operators__.add_533 (TFOp  (None, 2716)        0           ['dense_85[0][0]',
#  Lambda)                                                          'tf.math.multiply_750[0][0]']
#
#  tf.compat.v1.squeeze_365 (TFOp  (None, 2716)        0           ['tf.linalg.matmul_704[0][0]']
#  Lambda)
#
#  tf.__operators__.add_536 (TFOp  (None, 2716)        0           ['tf.__operators__.add_533[0][0]'
#  Lambda)                                                         , 'tf.compat.v1.squeeze_365[0][0]
#                                                                  ']
#
#  tf.math.subtract_459 (TFOpLamb  (None, 2716)        0           ['tf.__operators__.add_536[0][0]'
#  da)                                                             , 'lambda_56[0][0]']
#
#  tf.nn.relu_271 (TFOpLambda)    (None, 2716)         0           ['tf.math.subtract_459[0][0]']
#
#  tf.expand_dims_366 (TFOpLambda  (None, 2716, 1)     0           ['tf.nn.relu_271[0][0]']
#  )
#
#  tf.expand_dims_368 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_532[0][0]'
#  )                                                               ]
#
#  tf.linalg.matmul_705 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_366[0][0]']
#  da)
#
#  tf.linalg.matmul_707 (TFOpLamb  (None, 481, 1)      0           ['tf.expand_dims_368[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_366 (TFOp  (None, 550)         0           ['tf.linalg.matmul_705[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_368 (TFOp  (None, 481)         0           ['tf.linalg.matmul_707[0][0]']
#  Lambda)
#
#  tf.__operators__.add_537 (TFOp  (None, 550)         0           ['tf.compat.v1.squeeze_366[0][0]'
#  Lambda)                                                         ]
#
#  tf.math.subtract_460 (TFOpLamb  (None, 481)         0           ['tf.compat.v1.squeeze_368[0][0]'
#  da)                                                             , 'lambda_55[0][0]']
#
#  tf.expand_dims_367 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_537[0][0]'
#  )                                                               ]
#
#  tf.expand_dims_369 (TFOpLambda  (None, 481, 1)      0           ['tf.math.subtract_460[0][0]']
#  )
#
#  tf.linalg.matmul_706 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_367[0][0]']
#  da)
#
#  tf.linalg.matmul_708 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_369[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_367 (TFOp  (None, 550)         0           ['tf.linalg.matmul_706[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_369 (TFOp  (None, 550)         0           ['tf.linalg.matmul_708[0][0]']
#  Lambda)
#
#  tf.math.subtract_461 (TFOpLamb  (None, 550)         0           ['tf.compat.v1.squeeze_367[0][0]'
#  da)                                                             , 'tf.compat.v1.squeeze_369[0][0]
#                                                                  ']
#
#  tf.math.multiply_755 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_461[0][0]']
#  da)
#
#  tf.math.multiply_756 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_755[0][0]']
#  da)
#
#  tf.__operators__.add_538 (TFOp  (None, 550)         0           ['tf.__operators__.add_532[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_756[0][0]']
#
#  tf.math.subtract_462 (TFOpLamb  (None, 2716)        0           ['tf.nn.relu_271[0][0]',
#  da)                                                              'tf.__operators__.add_533[0][0]'
#                                                                  ]
#
#  tf.math.multiply_754 (TFOpLamb  (None, 2716)        0           ['tf.math.subtract_462[0][0]']
#  da)
#
#  tf.expand_dims_370 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_538[0][0]'
#  )                                                               ]
#
#  tf.math.multiply_757 (TFOpLamb  (None, 2716)        0           ['tf.math.multiply_754[0][0]']
#  da)
#
#  tf.linalg.matmul_711 (TFOpLamb  (None, 2716, 1)     0           ['tf.expand_dims_370[0][0]']
#  da)
#
#  tf.__operators__.add_539 (TFOp  (None, 2716)        0           ['tf.__operators__.add_533[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_757[0][0]']
#
#  tf.compat.v1.squeeze_370 (TFOp  (None, 2716)        0           ['tf.linalg.matmul_711[0][0]']
#  Lambda)
#
#  tf.__operators__.add_542 (TFOp  (None, 2716)        0           ['tf.__operators__.add_539[0][0]'
#  Lambda)                                                         , 'tf.compat.v1.squeeze_370[0][0]
#                                                                  ']
#
#  tf.math.subtract_464 (TFOpLamb  (None, 2716)        0           ['tf.__operators__.add_542[0][0]'
#  da)                                                             , 'lambda_56[0][0]']
#
#  tf.nn.relu_274 (TFOpLambda)    (None, 2716)         0           ['tf.math.subtract_464[0][0]']
#
#  tf.expand_dims_371 (TFOpLambda  (None, 2716, 1)     0           ['tf.nn.relu_274[0][0]']
#  )
#
#  tf.expand_dims_373 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_538[0][0]'
#  )                                                               ]
#
#  tf.linalg.matmul_712 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_371[0][0]']
#  da)
#
#  tf.linalg.matmul_714 (TFOpLamb  (None, 481, 1)      0           ['tf.expand_dims_373[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_371 (TFOp  (None, 550)         0           ['tf.linalg.matmul_712[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_373 (TFOp  (None, 481)         0           ['tf.linalg.matmul_714[0][0]']
#  Lambda)
#
#  tf.__operators__.add_543 (TFOp  (None, 550)         0           ['tf.compat.v1.squeeze_371[0][0]'
#  Lambda)                                                         ]
#
#  tf.math.subtract_465 (TFOpLamb  (None, 481)         0           ['tf.compat.v1.squeeze_373[0][0]'
#  da)                                                             , 'lambda_55[0][0]']
#
#  tf.expand_dims_372 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_543[0][0]'
#  )                                                               ]
#
#  tf.expand_dims_374 (TFOpLambda  (None, 481, 1)      0           ['tf.math.subtract_465[0][0]']
#  )
#
#  tf.linalg.matmul_713 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_372[0][0]']
#  da)
#
#  tf.linalg.matmul_715 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_374[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_372 (TFOp  (None, 550)         0           ['tf.linalg.matmul_713[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_374 (TFOp  (None, 550)         0           ['tf.linalg.matmul_715[0][0]']
#  Lambda)
#
#  tf.math.subtract_466 (TFOpLamb  (None, 550)         0           ['tf.compat.v1.squeeze_372[0][0]'
#  da)                                                             , 'tf.compat.v1.squeeze_374[0][0]
#                                                                  ']
#
#  tf.math.multiply_762 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_466[0][0]']
#  da)
#
#  tf.math.multiply_763 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_762[0][0]']
#  da)
#
#  tf.__operators__.add_544 (TFOp  (None, 550)         0           ['tf.__operators__.add_538[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_763[0][0]']
#
#  tf.math.subtract_467 (TFOpLamb  (None, 2716)        0           ['tf.nn.relu_274[0][0]',
#  da)                                                              'tf.__operators__.add_539[0][0]'
#                                                                  ]
#
#  tf.math.multiply_761 (TFOpLamb  (None, 2716)        0           ['tf.math.subtract_467[0][0]']
#  da)
#
#  tf.expand_dims_375 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_544[0][0]'
#  )                                                               ]
#
#  tf.math.multiply_764 (TFOpLamb  (None, 2716)        0           ['tf.math.multiply_761[0][0]']
#  da)
#
#  tf.linalg.matmul_718 (TFOpLamb  (None, 2716, 1)     0           ['tf.expand_dims_375[0][0]']
#  da)
#
#  tf.__operators__.add_545 (TFOp  (None, 2716)        0           ['tf.__operators__.add_539[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_764[0][0]']
#
#  tf.compat.v1.squeeze_375 (TFOp  (None, 2716)        0           ['tf.linalg.matmul_718[0][0]']
#  Lambda)
#
#  tf.__operators__.add_548 (TFOp  (None, 2716)        0           ['tf.__operators__.add_545[0][0]'
#  Lambda)                                                         , 'tf.compat.v1.squeeze_375[0][0]
#                                                                  ']
#
#  tf.math.subtract_469 (TFOpLamb  (None, 2716)        0           ['tf.__operators__.add_548[0][0]'
#  da)                                                             , 'lambda_56[0][0]']
#
#  tf.nn.relu_277 (TFOpLambda)    (None, 2716)         0           ['tf.math.subtract_469[0][0]']
#
#  tf.expand_dims_376 (TFOpLambda  (None, 2716, 1)     0           ['tf.nn.relu_277[0][0]']
#  )
#
#  tf.expand_dims_378 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_544[0][0]'
#  )                                                               ]
#
#  tf.linalg.matmul_719 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_376[0][0]']
#  da)
#
#  tf.linalg.matmul_721 (TFOpLamb  (None, 481, 1)      0           ['tf.expand_dims_378[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_376 (TFOp  (None, 550)         0           ['tf.linalg.matmul_719[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_378 (TFOp  (None, 481)         0           ['tf.linalg.matmul_721[0][0]']
#  Lambda)
#
#  tf.__operators__.add_549 (TFOp  (None, 550)         0           ['tf.compat.v1.squeeze_376[0][0]'
#  Lambda)                                                         ]
#
#  tf.math.subtract_470 (TFOpLamb  (None, 481)         0           ['tf.compat.v1.squeeze_378[0][0]'
#  da)                                                             , 'lambda_55[0][0]']
#
#  tf.expand_dims_377 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_549[0][0]'
#  )                                                               ]
#
#  tf.expand_dims_379 (TFOpLambda  (None, 481, 1)      0           ['tf.math.subtract_470[0][0]']
#  )
#
#  tf.linalg.matmul_720 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_377[0][0]']
#  da)
#
#  tf.linalg.matmul_722 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_379[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_377 (TFOp  (None, 550)         0           ['tf.linalg.matmul_720[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_379 (TFOp  (None, 550)         0           ['tf.linalg.matmul_722[0][0]']
#  Lambda)
#
#  tf.math.subtract_471 (TFOpLamb  (None, 550)         0           ['tf.compat.v1.squeeze_377[0][0]'
#  da)                                                             , 'tf.compat.v1.squeeze_379[0][0]
#                                                                  ']
#
#  tf.math.multiply_769 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_471[0][0]']
#  da)
#
#  tf.math.multiply_770 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_769[0][0]']
#  da)
#
#  tf.__operators__.add_550 (TFOp  (None, 550)         0           ['tf.__operators__.add_544[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_770[0][0]']
#
#  tf.linalg.matmul_725 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_550[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_473 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_725[0][0]',
#  da)                                                              'lambda_54[0][0]']
#
#  tf.math.negative_145 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_550[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_724 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_550[0][0]'
#  da)                                                             ]
#
#  tf.nn.relu_278 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_473[0][0]']
#
#  tf.nn.relu_279 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_145[0][0]']
#
#  tf.compat.v1.norm_375 (TFOpLam  (None, 1)           0           ['tf.linalg.matmul_724[0][0]']
#  bda)
#
#  tf.compat.v1.norm_376 (TFOpLam  (None, 1)           0           ['tf.nn.relu_278[0][0]']
#  bda)
#
#  tf.compat.v1.norm_377 (TFOpLam  (None, 1)           0           ['tf.nn.relu_279[0][0]']
#  bda)
#
#  tf.linalg.matmul_723 (TFOpLamb  (None, 1)           0           ['tf.__operators__.add_550[0][0]'
#  da)                                                             ]
#
#  tf.math.truediv_455 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_375[0][0]']
#  a)
#
#  tf.math.truediv_456 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_376[0][0]']
#  a)
#
#  tf.math.truediv_457 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_377[0][0]']
#  a)
#
#  concatenate_29 (Concatenate)   (None, 1104)         0           ['tf.linalg.matmul_723[0][0]',
#                                                                   'tf.math.truediv_455[0][0]',
#                                                                   'tf.math.truediv_456[0][0]',
#                                                                   'tf.math.truediv_457[0][0]',
#                                                                   'tf.__operators__.add_550[0][0]'
#                                                                  , 'tf.__operators__.add_527[0][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 839,266
# Trainable params: 839,266
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters: 839266
# Epoch 1/25
# 1584/1584 [==============================] - 17s 10ms/step - loss: 0.0089 - my_mae: 0.0089 - val_loss: 0.0028 - val_my_mae: 0.0028
# Epoch 2/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 0.0018 - my_mae: 0.0018 - val_loss: 0.0012 - val_my_mae: 0.0012
# Epoch 3/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 0.0012 - my_mae: 0.0012 - val_loss: 9.6324e-04 - val_my_mae: 9.6324e-04
# Epoch 4/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 0.0010 - my_mae: 0.0010 - val_loss: 7.9800e-04 - val_my_mae: 7.9800e-04
# Epoch 5/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 8.2180e-04 - my_mae: 8.2180e-04 - val_loss: 5.9536e-04 - val_my_mae: 5.9536e-04
# Epoch 6/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 6.1496e-04 - my_mae: 6.1496e-04 - val_loss: 4.0693e-04 - val_my_mae: 4.0693e-04
# Epoch 7/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 4.8543e-04 - my_mae: 4.8543e-04 - val_loss: 4.0875e-04 - val_my_mae: 4.0875e-04
# Epoch 8/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 4.0111e-04 - my_mae: 4.0111e-04 - val_loss: 2.6550e-04 - val_my_mae: 2.6550e-04
# Epoch 9/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 3.5272e-04 - my_mae: 3.5272e-04 - val_loss: 2.3113e-04 - val_my_mae: 2.3113e-04
# Epoch 10/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 3.1222e-04 - my_mae: 3.1222e-04 - val_loss: 2.1077e-04 - val_my_mae: 2.1077e-04
# Epoch 11/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 2.8137e-04 - my_mae: 2.8137e-04 - val_loss: 1.9159e-04 - val_my_mae: 1.9159e-04
# Epoch 12/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 2.5359e-04 - my_mae: 2.5359e-04 - val_loss: 1.5134e-04 - val_my_mae: 1.5134e-04
# Epoch 13/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 2.4525e-04 - my_mae: 2.4525e-04 - val_loss: 1.4393e-04 - val_my_mae: 1.4393e-04
# Epoch 14/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 2.2612e-04 - my_mae: 2.2612e-04 - val_loss: 1.2467e-04 - val_my_mae: 1.2467e-04
# Epoch 15/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 2.0607e-04 - my_mae: 2.0607e-04 - val_loss: 1.0919e-04 - val_my_mae: 1.0919e-04
# Epoch 16/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.9932e-04 - my_mae: 1.9932e-04 - val_loss: 9.9616e-05 - val_my_mae: 9.9616e-05
# Epoch 17/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 1.8993e-04 - my_mae: 1.8993e-04 - val_loss: 9.0131e-05 - val_my_mae: 9.0131e-05
# Epoch 18/25
# 1584/1584 [==============================] - 15s 10ms/step - loss: 1.8465e-04 - my_mae: 1.8465e-04 - val_loss: 9.3774e-05 - val_my_mae: 9.3774e-05
# Epoch 19/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.8025e-04 - my_mae: 1.8025e-04 - val_loss: 8.0929e-05 - val_my_mae: 8.0929e-05
# Epoch 20/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.7312e-04 - my_mae: 1.7312e-04 - val_loss: 8.7293e-05 - val_my_mae: 8.7293e-05
# Epoch 21/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.6620e-04 - my_mae: 1.6620e-04 - val_loss: 8.1397e-05 - val_my_mae: 8.1397e-05
# Epoch 22/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.7252e-04 - my_mae: 1.7252e-04 - val_loss: 7.7997e-05 - val_my_mae: 7.7997e-05
# Epoch 23/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.6452e-04 - my_mae: 1.6452e-04 - val_loss: 7.6049e-05 - val_my_mae: 7.6049e-05
# Epoch 24/25
# 1584/1584 [==============================] - 15s 9ms/step - loss: 1.6376e-04 - my_mae: 1.6376e-04 - val_loss: 8.2603e-05 - val_my_mae: 8.2603e-05
# Epoch 25/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.5819e-04 - my_mae: 1.5819e-04 - val_loss: 6.8534e-05 - val_my_mae: 6.8534e-05
# 248/248 [==============================] - 2s 8ms/step
# Loss out on V0:  0.3174945
# Loss constraint on V0:  0.001134018
# Loss all on V0:  0.035572775
# Loss out on Vf:  0.002731682
# Loss constraint on Vf:  7.916986e-05
# Loss all on Vf:  6.529844e-05
# Distance V0 to Vf 2112.292969:
# ...
#
#  tf.expand_dims_456 (TFOpLambda  (None, 2716, 1)     0           ['tf.nn.relu_337[0][0]']
#  )
#
#  tf.expand_dims_458 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_648[0][0]'
#  )                                                               ]
#
#  tf.linalg.matmul_847 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_456[0][0]']
#  da)
#
#  tf.linalg.matmul_849 (TFOpLamb  (None, 481, 1)      0           ['tf.expand_dims_458[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_456 (TFOp  (None, 550)         0           ['tf.linalg.matmul_847[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_458 (TFOp  (None, 481)         0           ['tf.linalg.matmul_849[0][0]']
#  Lambda)
#
#  tf.__operators__.add_653 (TFOp  (None, 550)         0           ['tf.compat.v1.squeeze_456[0][0]'
#  Lambda)                                                         ]
#
#  tf.math.subtract_562 (TFOpLamb  (None, 481)         0           ['tf.compat.v1.squeeze_458[0][0]'
#  da)                                                             , 'lambda_67[0][0]']
#
#  tf.expand_dims_457 (TFOpLambda  (None, 550, 1)      0           ['tf.__operators__.add_653[0][0]'
#  )                                                               ]
#
#  tf.expand_dims_459 (TFOpLambda  (None, 481, 1)      0           ['tf.math.subtract_562[0][0]']
#  )
#
#  tf.linalg.matmul_848 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_457[0][0]']
#  da)
#
#  tf.linalg.matmul_850 (TFOpLamb  (None, 550, 1)      0           ['tf.expand_dims_459[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_457 (TFOp  (None, 550)         0           ['tf.linalg.matmul_848[0][0]']
#  Lambda)
#
#  tf.compat.v1.squeeze_459 (TFOp  (None, 550)         0           ['tf.linalg.matmul_850[0][0]']
#  Lambda)
#
#  tf.math.subtract_563 (TFOpLamb  (None, 550)         0           ['tf.compat.v1.squeeze_457[0][0]'
#  da)                                                             , 'tf.compat.v1.squeeze_459[0][0]
#                                                                  ']
#
#  tf.math.multiply_905 (TFOpLamb  (None, 550)         0           ['tf.math.subtract_563[0][0]']
#  da)
#
#  tf.math.multiply_906 (TFOpLamb  (None, 550)         0           ['tf.math.multiply_905[0][0]']
#  da)
#
#  tf.__operators__.add_654 (TFOp  (None, 550)         0           ['tf.__operators__.add_648[0][0]'
#  Lambda)                                                         , 'tf.math.multiply_906[0][0]']
#
#  tf.linalg.matmul_853 (TFOpLamb  (None, 38)          0           ['tf.__operators__.add_654[0][0]'
#  da)                                                             ]
#
#  tf.math.subtract_565 (TFOpLamb  (None, 38)          0           ['tf.linalg.matmul_853[0][0]',
#  da)                                                              'lambda_66[0][0]']
#
#  tf.math.negative_165 (TFOpLamb  (None, 550)         0           ['tf.__operators__.add_654[0][0]'
#  da)                                                             ]
#
#  tf.linalg.matmul_852 (TFOpLamb  (None, 1083)        0           ['tf.__operators__.add_654[0][0]'
#  da)                                                             ]
#
#  tf.nn.relu_338 (TFOpLambda)    (None, 38)           0           ['tf.math.subtract_565[0][0]']
#
#  tf.nn.relu_339 (TFOpLambda)    (None, 550)          0           ['tf.math.negative_165[0][0]']
#
#  tf.compat.v1.norm_435 (TFOpLam  (None, 1)           0           ['tf.linalg.matmul_852[0][0]']
#  bda)
#
#  tf.compat.v1.norm_436 (TFOpLam  (None, 1)           0           ['tf.nn.relu_338[0][0]']
#  bda)
#
#  tf.compat.v1.norm_437 (TFOpLam  (None, 1)           0           ['tf.nn.relu_339[0][0]']
#  bda)
#
#  tf.linalg.matmul_851 (TFOpLamb  (None, 1)           0           ['tf.__operators__.add_654[0][0]'
#  da)                                                             ]
#
#  tf.math.truediv_515 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_435[0][0]']
#  a)
#
#  tf.math.truediv_516 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_436[0][0]']
#  a)
#
#  tf.math.truediv_517 (TFOpLambd  (None, 1)           0           ['tf.compat.v1.norm_437[0][0]']
#  a)
#
#  concatenate_33 (Concatenate)   (None, 1104)         0           ['tf.linalg.matmul_851[0][0]',
#                                                                   'tf.math.truediv_515[0][0]',
#                                                                   'tf.math.truediv_516[0][0]',
#                                                                   'tf.math.truediv_517[0][0]',
#                                                                   'tf.__operators__.add_654[0][0]'
#                                                                  , 'tf.__operators__.add_631[0][0]
#                                                                  ']
#
# ==================================================================================================
# Total params: 839,266
# Trainable params: 839,266
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters:
25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.0489e-04 - my_mae: 1.0489e-04 - val_loss: 6.6727e-06 - val_my_mae: 6.6727e-06
# Epoch 23/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.1284e-04 - my_mae: 1.1284e-04 - val_loss: 3.2706e-05 - val_my_mae: 3.2706e-05
# Epoch 24/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 1.1052e-04 - my_mae: 1.1052e-04 - val_loss: 4.0580e-05 - val_my_mae: 4.0580e-05
# Epoch 25/25
# 1584/1584 [==============================] - 14s 9ms/step - loss: 9.8001e-05 - my_mae: 9.8001e-05 - val_loss: 3.1180e-05 - val_my_mae: 3.1180e-05
# 248/248 [==============================] - 2s 8ms/step
# Loss out on V0:  0.009282817
# Loss constraint on V0:  2.3140958e-06
# Loss all on V0:  4.6745576e-05
# Loss out on Vf:  0.007045424
# Loss constraint on Vf:  2.7660517e-06
# Loss all on Vf:  2.8913653e-05
# Distance V0 to Vf 96.254944:
# 62/62 [==============================] - 1s 8ms/step
# Loss out on V0:  0.009628398
# Loss constraint on V0:  2.3586906e-06
# Loss all on V0:  5.02673e-05
# Loss out on Vf:  0.0072574434
# Loss constraint on Vf:  2.849087e-06
# Loss all on Vf:  3.1180083e-05
# Distance V0 to Vf 49.477802:
# train = 1.00 test = 1.00 loss-train = 0.000003 loss-test = 0.000003 iter=0
# 310/310 [==============================] - 3s 8ms/step
# Loss out on V0:  0.009351933
# Loss constraint on V0:  2.3230145e-06
# Loss all on V0:  4.7449917e-05
# Loss out on Vf:  0.0070878277
# Loss constraint on Vf:  2.7826588e-06
# Loss all on Vf:  2.9366938e-05
# Distance V0 to Vf 108.219795:
# Stats for iML1515_UB_AMN_LP CPU-time 1816.0224
# R2 = 0.9976 (+/- 0.0010) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9974 (+/- 0.0010) Constraint = 0.0000 (+/- 0.0000)
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_LP
# model scaler: 11.0
# model input dim: 38
# model output dim: 1104
# model medium bound: UB
# timestep: 4
# training set size (9900, 3235) (9900, 4)
# nbr hidden layer: 1
# hidden layer size: 250
# activation function: relu
# training epochs: 25
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 35/35 [==============================] - 0s 8ms/step
# Stats for Test set CPU-time 0.3390
# R2 = 0.9974 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9974 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)

# %% [markdown]
# ### AMN Wt program

# %%
# Create, train and evaluate AMN_Wt models with FBA simulated training set for E. coli core
# with UB (not working with M1 chips)

# What you can change 
seed = 10
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'e_coli_core_UB' # can change EB by UB
timestep = 4
# End of What you can change
  
# Create model 90% for training 10% for testing
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
                     objective=['BIOMASS_Ecoli_core_w_GAM'],  
                     model_type='AMN_Wt', 
                     timestep = timestep,
                     n_hidden = 1, hidden_dim = 50,
                     scaler=True,
                     train_rate=1e-2,
                     epochs=500, xfold=5,
                     verbose=True)
ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0)
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y = Xtrain, Ytrain
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=False)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
#reservoir.save(reservoirfile)
#reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    X, Y = model_input(reservoir, verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  154 154
# number of metabolites:  72
# filtered measurements size:  1
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_Wt
# model scaler: 1.0
# model input dim: 20
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (1000, 20) (1000, 1)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.01
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# nbr parameters: 13262
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.000919 loss-test = 0.000912 iter=0
# nbr parameters: 13262
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.000933 loss-test = 0.000990 iter=0
# nbr parameters: 13262
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.000908 loss-test = 0.000904 iter=0
# nbr parameters: 13262
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.99 loss-train = 0.000878 loss-test = 0.000893 iter=0
# nbr parameters: 13262
# 23/23 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# train = 0.99 test = 0.98 loss-train = 0.000996 loss-test = 0.000934 iter=0
# 29/29 [==============================] - 0s 2ms/step
# Stats for e_coli_core_UB_AMN_Wt CPU-time 1589.4198
# R2 = 0.9882 (+/- 0.0013) Constraint = 0.0009 (+/- 0.0000)
# Q2 = 0.9875 (+/- 0.0021) Constraint = 0.0009 (+/- 0.0000)
# training file: ./Dataset_model/e_coli_core_UB
# model type: AMN_Wt
# model scaler: 10.0
# model input dim: 20
# model output dim: 158
# model medium bound: UB
# timestep: 4
# training set size (720, 4, 20) (720, 4)
# nbr hidden layer: 1
# hidden layer size: 50
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.01
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 4/4 [==============================] - 0s 2ms/step
# Stats for Test set CPU-time 0.0294
# R2 = 0.9864 (+/- 0.0000) Constraint = 0.0010 (+/- 0.0000)
# Q2 = 0.9864 (+/- 0.0000) Constraint = 0.0010 (+/- 0.0000)

# %%
# Create, train and evaluate AMN_QP models with FBA simulated training set for iML1515
# with EB or UB with a mechanistic layer 
# This cell takes several hours to execute

# What you can change 
seed = 1
ratio_test = 0.1 # part of the training set removed for test
np.random.seed(seed=seed)  
trainname = 'iML1515_UB'
timestep = 4
# End of What you can change
  
# Create model 
trainingfile = DIRECTORY+'Dataset_model/'+trainname
model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_Wt',
              scaler = True,
              timestep = timestep, 
              n_hidden = 1, hidden_dim = 500,
              train_rate=1e-2,
              epochs = 100, xfold = 5, 
              verbose=True) 

ID = np.random.choice(model.X.shape[0], 
                      size=int(model.X.shape[0]*ratio_test), 
                      replace=False)
Xtest,  Ytest  = model.X[ID,:], model.Y[ID,:]
Xtrain, Ytrain = np.delete(model.X, ID, axis=0), np.delete(model.Y, ID, axis=0) 
model.printout()

# Train and evaluate
reservoirname = trainname+'_'+model.model_type
reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
start_time = time.time()
model.X, model.Y = Xtrain, Ytrain
reservoir, pred, stats, _ = train_evaluate_model(model, verbose=2)
delta_time = time.time() - start_time

# Printing cross-validation results
printout(reservoirname, stats, model, delta_time)

# Save, reload and run idependent test set
#reservoir.save(reservoirfile)
#reservoir.load(reservoirfile)
reservoir.printout()
if len(Xtest) > 0:
    start_time = time.time()
    reservoir.X, reservoir.Y = Xtest, Ytest
    X, Y = model_input(reservoir,verbose=False)
    pred, stats = evaluate_model(reservoir.model, X, Y, reservoir, verbose=False)
    delta_time = time.time() - start_time
    printout('Test set', stats, model, delta_time)
# Out:
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_Wt
# model scaler: 1.0
# model input dim: 38
# model output dim: 1
# model medium bound: UB
# timestep: 4
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# training epochs: 100
# training regression: True
# training learn rate: 0.01
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# AMN scaler 11.0
# Wt input shape (9900, 4, 38) (9900, 4)
# -------train [   0    1    3 ... 9897 9898 9899]
# -------test  [   2    4    6 ... 9883 9891 9893]
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, None, 38)]   0           []
#
#  rnn (RNN)                      (None, 550)          634238      ['input_12[0][0]']
#
#  tf.linalg.matmul_46 (TFOpLambd  (None, 38)          0           ['rnn[0][0]']
#  a)
#
#  tf.__operators__.getitem (Slic  (None, 38)          0           ['input_12[0][0]']
#  ingOpLambda)
#
#  tf.math.subtract_33 (TFOpLambd  (None, 38)          0           ['tf.linalg.matmul_46[0][0]',
#  a)                                                               'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.negative_11 (TFOpLambd  (None, 550)         0           ['rnn[0][0]']
#  a)
#
#  tf.linalg.matmul_45 (TFOpLambd  (None, 1083)        0           ['rnn[0][0]']
#  a)
#
#  tf.nn.relu_33 (TFOpLambda)     (None, 38)           0           ['tf.math.subtract_33[0][0]']
#
#  tf.nn.relu_34 (TFOpLambda)     (None, 550)          0           ['tf.math.negative_11[0][0]']
#
#  tf.compat.v1.norm_33 (TFOpLamb  (None, 1)           0           ['tf.linalg.matmul_45[0][0]']
#  da)
#
#  tf.compat.v1.norm_34 (TFOpLamb  (None, 1)           0           ['tf.nn.relu_33[0][0]']
#  da)
#
#  tf.compat.v1.norm_35 (TFOpLamb  (None, 1)           0           ['tf.nn.relu_34[0][0]']
#  da)
#
#  tf.linalg.matmul_44 (TFOpLambd  (None, 1)           0           ['rnn[0][0]']
#  a)
#
#  tf.math.truediv_33 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_33[0][0]']
#  )
#
#  tf.math.truediv_34 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_34[0][0]']
#  )
#
#  tf.math.truediv_35 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_35[0][0]']
#  )
#
#  concatenate_11 (Concatenate)   (None, 554)          0           ['tf.linalg.matmul_44[0][0]',
#                                                                   'tf.math.truediv_33[0][0]',
#                                                                   'tf.math.truediv_34[0][0]',
#                                                                   'tf.math.truediv_35[0][0]',
#                                                                   'rnn[0][0]']
#
# ==================================================================================================
# Total params: 634,238
# Trainable params: 634,238
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters: 634238
# Epoch 1/100
# 1584/1584 [==============================] - 24s 15ms/step - loss: 0.0618 - my_mae: 0.0618 - val_loss: 7.0384e-04 - val_my_mae: 7.0384e-04
# Epoch 2/100
# 1584/1584 [==============================] - 31s 19ms/step - loss: 3.4407e-04 - my_mae: 3.4407e-04 - val_loss: 3.0992e-04 - val_my_mae: 3.0992e-04
# Epoch 3/100
# 1584/1584 [==============================] - 29s 19ms/step - loss: 3.5907e-04 - my_mae: 3.5907e-04 - val_loss: 0.0010 - val_my_mae: 0.0010
# Epoch 4/100
# 1584/1584 [==============================] - 31s 20ms/step - loss: 5.6173e-04 - my_mae: 5.6173e-04 - val_loss: 2.8529e-04 - val_my_mae: 2.8529e-04
# Epoch 5/100
# 1584/1584 [==============================] - 33s 21ms/step - loss: 3.2104e-04 - my_mae: 3.2104e-04 - val_loss: 2.3713e-04 - val_my_mae: 2.3713e-04
# Epoch 6/100
# 1584/1584 [==============================] - 35s 22ms/step - loss: 1.7597e-04 - my_mae: 1.7597e-04 - val_loss: 1.0192e-04 - val_my_mae: 1.0192e-04
# Epoch 7/100
# 1584/1584 [==============================] - 37s 23ms/step - loss: 1.1052e-04 - my_mae: 1.1052e-04 - val_loss: 6.9749e-05 - val_my_mae: 6.9749e-05
# Epoch 8/100
# 1584/1584 [==============================] - 37s 23ms/step - loss: 0.0071 - my_mae: 0.0071 - val_loss: 8.8491e-05 - val_my_mae: 8.8491e-05
# Epoch 9/100
# 1584/1584 [==============================] - 41s 26ms/step - loss: 7.5914e-05 - my_mae: 7.5914e-05 - val_loss: 6.7994e-05 - val_my_mae: 6.7994e-05
# Epoch 10/100
# 1584/1584 [==============================] - 39s 25ms/step - loss: 6.9951e-05 - my_mae: 6.9951e-05 - val_loss: 6.2981e-05 - val_my_mae: 6.2981e-05
# Epoch 11/100
# 1584/1584 [==============================] - 36s 23ms/step - loss:
100
# 1584/1584 [==============================] - 39s 25ms/step - loss: 5.4782e-04 - my_mae: 5.4782e-04 - val_loss: 2.0877e-05 - val_my_mae: 2.0877e-05
# Epoch 97/100
# 1584/1584 [==============================] - 40s 25ms/step - loss: 1.9174e-05 - my_mae: 1.9174e-05 - val_loss: 1.6716e-05 - val_my_mae: 1.6716e-05
# Epoch 98/100
# 1584/1584 [==============================] - 39s 25ms/step - loss: 2.1112e-05 - my_mae: 2.1112e-05 - val_loss: 1.7607e-05 - val_my_mae: 1.7607e-05
# Epoch 99/100
# 1584/1584 [==============================] - 43s 27ms/step - loss: 2.6150e-05 - my_mae: 2.6150e-05 - val_loss: 1.6153e-05 - val_my_mae: 1.6153e-05
# Epoch 100/100
# 1584/1584 [==============================] - 42s 26ms/step - loss: 2.4731e-05 - my_mae: 2.4731e-05 - val_loss: 1.7317e-05 - val_my_mae: 1.7317e-05
# 248/248 [==============================] - 3s 13ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.0024483094
# Loss constraint on Vf:  8.880764e-06
# Loss all on Vf:  1.384544e-05
# 62/62 [==============================] - 1s 14ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.002457233
# Loss constraint on Vf:  9.002002e-06
# Loss all on Vf:  1.7316974e-05
# train = 1.00 test = 1.00 loss-train = 0.000009 loss-test = 0.000009 iter=0
# -------train [   0    1    2 ... 9897 9898 9899]
# -------test  [  20   22   23 ... 9885 9887 9894]
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, None, 38)]   0           []
#
#  rnn_1 (RNN)                    (None, 550)          634238      ['input_13[0][0]']
#
#  tf.linalg.matmul_49 (TFOpLambd  (None, 38)          0           ['rnn_1[0][0]']
#  a)
#
#  tf.__operators__.getitem_1 (Sl  (None, 38)          0           ['input_13[0][0]']
#  icingOpLambda)
#
#  tf.math.subtract_34 (TFOpLambd  (None, 38)          0           ['tf.linalg.matmul_49[0][0]',
#  a)                                                               'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.math.negative_12 (TFOpLambd  (None, 550)         0           ['rnn_1[0][0]']
#  a)
#
#  tf.linalg.matmul_48 (TFOpLambd  (None, 1083)        0           ['rnn_1[0][0]']
#  a)
#
#  tf.nn.relu_35 (TFOpLambda)     (None, 38)           0           ['tf.math.subtract_34[0][0]']
#
#  tf.nn.relu_36 (TFOpLambda)     (None, 550)          0           ['tf.math.negative_12[0][0]']
#
#  tf.compat.v1.norm_36 (TFOpLamb  (None, 1)           0           ['tf.linalg.matmul_48[0][0]']
#  da)
#
#  tf.compat.v1.norm_37 (TFOpLamb  (None, 1)           0           ['tf.nn.relu_35[0][0]']
#  da)
#
#  tf.compat.v1.norm_38 (TFOpLamb  (None, 1)           0           ['tf.nn.relu_36[0][0]']
#  da)
#
#  tf.linalg.matmul_47 (TFOpLambd  (None, 1)           0           ['rnn_1[0][0]']
#  a)
#
#  tf.math.truediv_36 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_36[0][0]']
#  )
#
#  tf.math.truediv_37 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_37[0][0]']
#  )
#
#  tf.math.truediv_38 (TFOpLambda  (None, 1)           0           ['tf.compat.v1.norm_38[0][0]']
#  )
#
#  concatenate_12 (Concatenate)   (None, 554)          0           ['tf.linalg.matmul_47[0][0]',
#                                                                   'tf.math.truediv_36[0][0]',
#                                                                   'tf.math.truediv_37[0][0]',
#                                                                   'tf.math.truediv_38[0][0]',
#                                                                   'rnn_1[0][0]']
#
# ==================================================================================================
# Total params: 634,238
# Trainable params: 634,238
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# nbr parameters: 634238
# Epoch 1/100
# 1584/1584 [==============================] - 37s 23ms/step - loss: 0.0635 - my_mae: 0.0635 - val_loss: 5.0194e-04 - val_my_mae: 5.0194e-04
# Epoch 2/100
# 1584/1584 [==============================] - 36s 23ms/step - loss: 3.4682e-04 - my_mae: 3.4682e-04 - val_loss: 5.5839e-04 - val_my_mae: 5.5839e-04
# Epoch 3/100
# 1584/1584 [==============================] - 35s 22ms/step - loss: 2.8972e-04 - my_mae: 2.8972e-04 - val_loss: 2.6762e-04 - val_my_mae: 2.6762e-04
# Epoch 4/100
# 1584/1584 [==============================] - 31s 20ms/step - loss: 2.8285e-04 - my_mae: 2.8285e-04 - val_loss: 2.1821e-04 - val_my_mae: 2.1821e-04
# Epoch 5/100
# 1584/1584 [==============================] - 30s 19ms/step - loss: 2.3597e-04 - my_mae: 2.3597e-04 - val_loss: 3.5066e-04 - val_my_mae: 3.5066e-04
# Epoch 6/100
# 1584/1584 [==============================] - 32s 20ms/step - loss: 2.3577e-04 - my_mae: 2.3577e-04 - val_loss: 1.6693e-04 - val_my_mae: 1.6693e-04
# Epoch 7/100
# 1584/1584 [==============================] - 34s 21ms/step - loss: 0.0317 - my_mae: 0.0317 - val_loss: 1.9015e-04 - val_my_mae: 1.9015e-04
# Epoch 8/100
# 1584/1584 [==============================] - 30s 19ms/step - loss: 1.7151e-04 - my_mae: 1.7151e-04 - val_loss: 1.5244e-04 - val_my_mae: 1.5244e-04
# Epoch 9/100
# 1584/1584 [==============================] - 34s 22ms/step - loss: 1.4307e-04 - my_mae: 1.4307e-04 - val_loss: 1.2472e-04 - val_my_mae: 1.2472e-04
# Epoch 10/100
# 1584/1584 [==============================] - 31s 20ms/step - loss: 1.0262e-04 - my_mae: 1.0262e-04 - val_loss: 8.0519e-05 - val_my_mae: 8.0519e-05
# Epoch 11/100
# 1584/1584 [==============================] - 31s 19ms/step - loss: 1.0529e-04 - my_mae: 1.0529e-04 - val_loss: 2.5222e-04 - val_my_mae: 2.5222e-04
# Epoch 12/100
# 1584/1584 [==============================] - 31s 20ms/step - loss: 1.2754e-04 - my_mae: 1.2754e-04 - val_loss: 6.4008e-05 - val_my_mae: 6.4008e-05
# Epoch 13/100
# 1584/1584 [==============================] - 32s 20ms/step - loss: 9.0915e-05 - my_mae: 9.0915e-05 - val_loss: 5.8106e-05 - val_my_mae: 5.8106e-05
# Epoch 14/100
# 1584/1584 [==============================] - 34s 21ms/step - loss: 2.3982e-04 - my_mae: 2.3982e-04 - val_loss: 6.5383e-05 - val_my_mae: 6.5383e-05
# Epoch 15/100
# 1584/1584 [==============================] - 30s 19ms/step - loss: 8.3086e-05 - my_mae: 8.3086e-05 - val_loss: 6.5967e-05 - val_my_mae: 6.5967e-05
# Epoch 16/100
# 1584/1584 [==============================] - 30s 19ms/step - loss: 9.2272e-05 - my_mae: 9.2272e-05 - val_loss: 5.4809e-05 - val_my_mae: 5.4809e-05
# Epoch 17/100
# 1584/1584 [==============================] - 31s 19ms/step - loss: 7.3416e-05 - my_mae: 7.3416e-05 - val_loss: 5.6787e-05 - val_my_mae: 5.6787e-05
# Epoch 18/100
# 1584/1584 [==============================] - 32s 20ms/step - loss: 8.8333e-05 - my_mae: 8.8333e-05 - val_loss: 5.5266e-05 - val_my_mae: 5.5266e-05
# Epoch 19/100
# 1584/1584 [==============================] - 35s 22ms/step - loss:
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, None, 38)]   0           []
#
#  rnn_2 (RNN)                    (None, 550)          634238      ['input_14[0][0]']
#
#  tf.linalg.matmul_52 (TFOpLambd  (None, 38)          0           ['rnn_2[0][0]']
#  a)
#
#  tf.__operators__.getitem_2 (Sl  (None, 38)          0           ['input_14[0][0]']
#  icingOpLambda)
#
#  tf.math.subtract_35 (TFOpLambd  (None, 38)          0           ['tf.linalg.matmul_52[0][0]',
#  a)                                                               'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.math.negative_13 (TFOpLambd  (None, 550)         0           ['rnn_2[0][0]']
#  a)
#
#  tf.linalg.matmul_51 (TFOpLambd  (None, 1083)        0           ['rnn_2[0][0]']
#  a)
#
#  tf.nn.relu_37 (TFOpLambda)     (None, 38)           0           ['tf.math.subtract_35[0][0]']
#
# ...
# Epoch 11/100
# 1584/1584 [==============================] - 21s 14ms/step - loss: 9.5703e-05 - my_mae: 9.5703e-05 - val_loss: 6.1335e-05 - val_my_mae: 6.1335e-05
# Epoch 12/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 8.7461e-05 - my_mae: 8.7461e-05 - val_loss: 6.6821e-05 - val_my_mae: 6.6821e-05
# Epoch 13/100
# 1584/1584 [==============================] - 21s 14ms/step - loss: 8.6821e-05 - my_mae: 8.6821e-05 - val_loss: 5.8521e-05 - val_my_mae: 5.8521e-05
# Epoch 14/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 0.0055 - my_mae: 0.0055 - val_loss: 8.2431e-05 - val_my_mae: 8.2431e-05
# Epoch 15/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 7.9713e-05 - my_mae: 7.9713e-05 - val_loss: 6.3555e-05 - val_my_mae: 6.3555e-05
# Epoch 16/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 7.3066e-05 - my_mae: 7.3066e-05 - val_loss: 5.5199e-05 - val_my_mae: 5.5199e-05
# Epoch 17/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 7.1002e-05 - my_mae: 7.1002e-05 - val_loss: 5.0766e-05 - val_my_mae: 5.0766e-05
# Epoch 18/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 7.1991e-05 - my_mae: 7.1991e-05 - val_loss: 5.7122e-05 - val_my_mae: 5.7122e-05
# Epoch 19/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 0.0031 - my_mae: 0.0031 - val_loss: 6.1059e-05 - val_my_mae: 6.1059e-05
# Epoch 20/100
# 1584/1584 [==============================] - 21s 13ms/step - loss: 6.4224e-05 - my_mae: 6.4224e-05 - val_loss: 5.4962e-05 - val_my_mae: 5.4962e-05
# Epoch 21/100
# 1584/1584 [==============================] - 23s 15ms/step - loss: 6.1150e-05 - my_mae: 6.1150e-05 - val_loss: 5.0159e-05 - val_my_mae: 5.0159e-05
# Epoch 22/100
# 1584/1584 [==============================] - 23s 14ms/step - loss: 6.5210e-05 - my_mae: 6.5210e-05 - val_loss: 4.7871e-05 - val_my_mae: 4.7871e-05
# Epoch 23/100
# 1584/1584 [==============================] - 21s 14ms/step - loss: 6.9220e-05 - my_mae: 6.9220e-05 - val_loss: 4.6392e-05 - val_my_mae: 4.6392e-05
# Epoch 24/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 6.9025e-05 - my_mae: 6.9025e-05 - val_loss: 7.9431e-05 - val_my_mae: 7.9431e-05
# Epoch 25/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 6.3596e-04 - my_mae: 6.3596e-04 - val_loss: 5.2119e-05 - val_my_mae: 5.2119e-05
# Epoch 26/100
# 1584/1584 [==============================] - 21s 13ms/step - loss: 5.7311e-05 - my_mae: 5.7311e-05 - val_loss: 4.2972e-05 - val_my_mae: 4.2972e-05
# Epoch 27/100
# 1584/1584 [==============================] - 21s 13ms/step - loss:
100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 3.1626e-05 - my_mae: 3.1626e-05 - val_loss: 1.9951e-05 - val_my_mae: 1.9951e-05
# Epoch 98/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 3.0493e-05 - my_mae: 3.0493e-05 - val_loss: 6.8976e-05 - val_my_mae: 6.8976e-05
# Epoch 99/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 2.6791e-05 - my_mae: 2.6791e-05 - val_loss: 1.4072e-05 - val_my_mae: 1.4072e-05
# Epoch 100/100
# 1584/1584 [==============================] - 22s 14ms/step - loss: 2.8417e-05 - my_mae: 2.8417e-05 - val_loss: 1.5061e-05 - val_my_mae: 1.5061e-05
# 248/248 [==============================] - 2s 7ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.002196508
# Loss constraint on Vf:  1.7028895e-05
# Loss all on Vf:  2.0464355e-05
# 62/62 [==============================] - 0s 6ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.0021058
# Loss constraint on Vf:  1.7128961e-05
# Loss all on Vf:  1.506106e-05
# train = 1.00 test = 1.00 loss-train = 0.000017 loss-test = 0.000017 iter=0
# 310/310 [==============================] - 2s 6ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.0009107686
# Loss constraint on Vf:  8.634554e-06
# Loss all on Vf:  1.2449824e-05
# Stats for iML1515_UB_AMN_Wt CPU-time 14755.6273
# R2 = 0.9993 (+/- 0.0001) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9993 (+/- 0.0004) Constraint = 0.0000 (+/- 0.0000)
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_Wt
# model scaler: 11.0
# model input dim: 38
# model output dim: 554
# model medium bound: UB
# timestep: 4
# training set size (7920, 4, 38) (7920, 4)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# training epochs: 100
# training regression: True
# training learn rate: 0.01
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 5
# training early stopping: False
# 35/35 [==============================] - 0s 6ms/step
# Stats for Test set CPU-time 0.2641
# R2 = 1.0000 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 1.0000 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)

# %% [markdown]
# ### AMN -QP, -LP or -Wt with experimental training set

# %%
# Create, train and evaluate AMN_QP models on experimental training set with UB 
# Repeat the process with different seeds
# This cell takes several hours to execute

Maxloop, Q2, PRED = 3, [], []

for Nloop in range(Maxloop):
    # What you can change 
    seed = Nloop+1
    np.random.seed(seed=seed)  
    trainname = 'iML1515_EXP_UB' 
    timestep = 4
    # End of What you can change
  
    # Create model 100% for training 0% for testing
    trainingfile = DIRECTORY+'Dataset_model/'+trainname
    model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_QP',
              scaler = True,
              timestep = timestep, learn_rate=0.001,
              n_hidden = 1, hidden_dim = 500,
              #train_rate = 1.0e-2,
              epochs = 1000, xfold = 10, 
              verbose=True) 

    # Train and evaluate
    reservoirname = trainname +'_'+model.model_type
    reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
    start_time = time.time()
    reservoir, pred, stats, _ = train_evaluate_model(model, verbose=True)
    delta_time = time.time() - start_time

    # Printing cross-validation results
    printout(reservoirname, stats, model, delta_time)
    r2 = r2_score(model.Y, pred[:,0], multioutput='variance_weighted')
    print('Iter', Nloop, 'Collated Q2', r2)
    Q2.append(r2)
    PRED.append(pred[:,0])

# Save in Result folder
Q2, PRED = np.asarray(Q2), np.asarray(PRED)
print('Averaged Q2 = %.4f (+/- %.4f)' % (np.mean(Q2), np.std(Q2)))
filename = DIRECTORY+'Result/'+reservoirname+'_Q2.csv'
np.savetxt(filename, Q2, delimiter=',')
filename = DIRECTORY+'Result/'+reservoirname+'_PRED.csv'
np.savetxt(filename, PRED, delimiter=',')

# %%
# Create, train and evaluate AMN_QP models on experimental training set with UB 
# Repeat the process with different seeds
# This cell takes several hours to execute

Maxloop, Q2, PRED = 3, [], []

for Nloop in range(Maxloop):
    # What you can change 
    seed = Nloop+1
    np.random.seed(seed=seed)  
    trainname = 'iML1515_EXP_UB' 
    timestep = 4
    # End of What you can change
  
    # Create model 100% for training 0% for testing
    trainingfile = DIRECTORY+'Dataset_model/'+trainname
    model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_LP',
              scaler = True,
              timestep = timestep, learn_rate=0.001,
              n_hidden = 1, hidden_dim = 500,
              #train_rate = 1.0e-2,
              epochs = 1000, xfold = 10, 
              verbose=True) 

    # Train and evaluate
    reservoirname = trainname +'_'+model.model_type
    reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
    start_time = time.time()
    reservoir, pred, stats, _ = train_evaluate_model(model, verbose=2)
    delta_time = time.time() - start_time

    # Printing cross-validation results
    printout(reservoirname, stats, model, delta_time)
    r2 = r2_score(model.Y, pred[:,0], multioutput='variance_weighted')
    print('Iter', Nloop, 'Collated Q2', r2)
    Q2.append(r2)
    PRED.append(pred[:,0])

# Save in Result folder
Q2, PRED = np.asarray(Q2), np.asarray(PRED)
print('Averaged Q2 = %.4f (+/- %.4f)' % (np.mean(Q2), np.std(Q2)))
filename = DIRECTORY+'Result/'+reservoirname+'_Q2.csv'
np.savetxt(filename, Q2, delimiter=',')
filename = DIRECTORY+'Result/'+reservoirname+'_PRED.csv'
np.savetxt(filename, PRED, delimiter=',')

# %%
# Create, train and evaluate AMN_Wt models on experimental training set with UB 
# Repeat the process with different seeds
# This cell takes several hours to execute

Maxloop, Q2, PRED = 3, [], []

for Nloop in range(Maxloop):
    # What you can change 
    seed = Nloop+1
    np.random.seed(seed=seed)  
    trainname = 'iML1515_EXP_UB' 
    timestep = 4
    # End of What you can change
  
    # Create model 100% for training 0% for testing
    trainingfile = DIRECTORY+'Dataset_model/'+trainname
    model = Neural_Model(trainingfile = trainingfile, 
              objective=['BIOMASS_Ec_iML1515_core_75p37M'], 
              model_type = 'AMN_Wt',
              scaler = True,
              timestep = timestep,
              n_hidden = 1, hidden_dim = 500,
              #train_rate = 1.0e-2,
              epochs = 1000, xfold = 10, 
              verbose=True) 

    # Train and evaluate
    reservoirname = trainname +'_'+model.model_type
    reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
    start_time = time.time()
    reservoir, pred, stats, _ = train_evaluate_model(model, verbose=True)
    delta_time = time.time() - start_time

    # Printing cross-validation results
    printout(reservoirname, stats, model, delta_time)
    r2 = r2_score(model.Y, pred[:,0], multioutput='variance_weighted')
    print('Iter', Nloop, 'Collated Q2', r2)
    Q2.append(r2)
    PRED.append(pred[:,0])

# Save in Result folder
Q2, PRED = np.asarray(Q2), np.asarray(PRED)
print('Averaged Q2 = %.4f (+/- %.4f)' % (np.mean(Q2), np.std(Q2)))
filename = DIRECTORY+'Result/'+reservoirname+'_Q2.csv'
np.savetxt(filename, Q2, delimiter=',')
filename = DIRECTORY+'Result/'+reservoirname+'_PRED.csv'
np.savetxt(filename, PRED, delimiter=',')

# %% [markdown]
# ## (4) Reservoir computing with experimental data set

# %%
# Run this cell first
import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    DIRECTORY = '/content/drive/My Drive/AMN-Colab/'
    sys.path.append('/content/drive/My Drive/amn')
    ! pip install cobra
    ! pip install silence_tensorflow
else:
    DIRECTORY = './'
print(os.listdir(DIRECTORY))
    
from Build_Model import *

def printout(filename, Stats, model, time): 
    # printing Stats
    print('Stats for %s CPU-time %.4f' % (filename, time))
    print('R2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.train_objective[0], Stats.train_objective[1],
           Stats.train_loss[0], Stats.train_loss[1]))
    print('Q2 = %.4f (+/- %.4f) Constraint = %.4f (+/- %.4f)' % \
          (Stats.test_objective[0], Stats.test_objective[1],
           Stats.test_loss[0], Stats.test_loss[1]))
# Out:
# ['Result', '.DS_Store', 'Dataset_model', 'Reservoir', 'old', '__pycache__', 'README.md', '.gitignore', 'Build_Dataset.ipynb', 'Build_Model.py', '.ipynb_checkpoints', 'Dataset_input', 'Build_Dataset.py', '.git', 'Build_Model.ipynb']

# %%
# Create, train and evaluate RC models on experimental training set 
# Repeat the process with different seeds
# This cell takes several hours to execute

seed = 10
Maxloop, Q2, PRED = 3, [], []  
for Nloop in range(Maxloop):
    # What you can change 
    seed = Nloop
    np.random.seed(seed=seed)  
    trainname = 'iML1515_EXP'
    reservoirname = 'iML1515_UB_AMN_QP'
    # End of What you can change
  
    # Create model 
    trainingfile = DIRECTORY+'Dataset_input/'+trainname
    reservoirfile = DIRECTORY+'Reservoir/'+reservoirname
    X, Y = read_XY(trainingfile, 38)
    model = RC_Model(reservoirfile = reservoirfile, X=X, Y=Y, 
                n_hidden_prior = 1, hidden_dim_prior = 500, activation_prior = 'relu',
                epochs = 1000, train_rate = 1.0e-4, xfold = 0,
                verbose=True) 
    model.printout()

    # Train and evaluate
    start_time = time.time()
    reservoir, pred, stats, _ = train_evaluate_model(model, verbose=True)
    delta_time = time.time() - start_time

    # Printing cross-validation results
    printout(reservoirname, stats, model, delta_time)
    r2 = r2_score(model.Y, pred[:,0], multioutput='variance_weighted')
    print('Iter', Nloop, 'Collated Q2', r2)
    Q2.append(r2)
    PRED.append(pred)

# Some printings and savings
Q2, PRED = np.asarray(Q2), np.asarray(PRED)
print(PRED.shape)
obj = PRED[:,:,0]
print('Averaged Q2 = %.4f (+/- %.4f)' % (np.mean(Q2), np.std(Q2)))
filename = DIRECTORY+'Result/'+reservoirname+'_'\
+str(model.model_type)+'_Q2.csv'
np.savetxt(filename, Q2, delimiter=',')
filename = DIRECTORY+'Result/'+reservoirname+'_'\
+str(model.model_type)+'_PRED.csv'
np.savetxt(filename, obj, delimiter=',')

# Saving input / output of the first prediction for Cobra runs
pred, obj = PRED[0], pred[:,0]
Loss_SV, Loss_Vin, Loss_Vpos = pred[:,1], pred[:,2], pred[:,3]
print('Loss SV average %.4f max %.4f' % (np.mean(Loss_SV), np.max(Loss_SV)))
print('Loss Vin average %.4f max %.4f' % (np.mean(Loss_Vin), np.max(Loss_Vin)))
print('Loss Vpos average %.4f max %.4f' % (np.mean(Loss_Vpos), np.max(Loss_Vpos)))
V = pred[:, 4:4+model.S.shape[1]]
Vin = pred[:, 4+model.S.shape[1]:]
Vin = model.res.scaler * Vin # rescale back for Cobra
XY = np.concatenate((Vin, Y), axis=1)
filename = DIRECTORY+'Result/'+reservoirname+'_'\
+str(model.model_type)+'_solution_for_Cobra.csv'
np.savetxt(filename, XY, delimiter=',')
# Out:
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# RC reservoir file: ./Reservoir/iML1515_UB_AMN_QP
# RC model type: RC_AMN
# RC scaler: 0.0
# RC model input dim: 38
# RC model output dim: 1
# RC model medium bound: UB
# training set size (110, 38) (110, 1)
# reservoir S, Pin, Pout matrices (1083, 550) (38, 550) (1, 550)
# RC training epochs: 1000
# RC training regression: True
# RC training learn rate: 0.0001
# RC training dropout: 0.25
# RC training batch size: 5
# RC training validation iter: 0
# RC training xfold: 0
# RC training early stopping: False
# --------prior network --------
# training file: None
# model type: ANN_Dense
# model scaler: 0.0
# model input dim: 10
# model output dim: 10
# model medium bound:
# timestep: 0
# no training set provided
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# --------reservoir network-----
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_QP
# model scaler: 11.0
# model input dim: 38
# model output dim: 1104
# model medium bound: UB
# timestep: 0
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 0
# training early stopping: False
# AMN scaler 0.0
# RC input shape (110, 38) (110, 4)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 10 relu True
# Prior inputs and outputs (None, 10) (None, 10)
# Res inputs added to Prior_outputs 28
# Res inputs (final) (None, 38)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 550 relu False
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Res_outputs-------------------- (None, 1104)
# SV, PinV, Vpos, V-------------- (None, 1) (None, 1) (None, 1) (None, 550)
# nbr parameters: 305560
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.0084753195
# Loss constraint on Vf:  5.3953863e-07
# Loss all on Vf:  4.445708e-05
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.0084753195
# Loss constraint on Vf:  5.3953863e-07
# Loss all on Vf:  4.445708e-05
# train = 0.98 test = 0.98 loss-train = 0.000001 loss-test = 0.000001 iter=0
# Stats for iML1515_UB_AMN_QP CPU-time 104.3438
# R2 = 0.9752 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9752 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Iter 0 Collated Q2 0.9752191448432519
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# RC reservoir file: ./Reservoir/iML1515_UB_AMN_QP
# RC model type: RC_AMN
# RC scaler: 0.0
# RC model input dim: 38
# RC model output dim: 1
# RC model medium bound: UB
# training set size (110, 38) (110, 1)
# reservoir S, Pin, Pout matrices (1083, 550) (38, 550) (1, 550)
# RC training epochs: 1000
# RC training regression: True
# RC training learn rate: 0.0001
# RC training dropout: 0.25
# RC training batch size: 5
# RC training validation iter: 0
# RC training xfold: 0
# RC training early stopping: False
# --------prior network --------
# training file: None
# model type: ANN_Dense
# model scaler: 0.0
# model input dim: 10
# model output dim: 10
# model medium bound:
# timestep: 0
# no training set provided
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# --------reservoir network-----
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_QP
# model scaler: 11.0
# model input dim: 38
# model output dim: 1104
# model medium bound: UB
# timestep: 0
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 0
# training early stopping: False
# AMN scaler 0.0
# RC input shape (110, 38) (110, 4)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 10 relu True
# Prior inputs and outputs (None, 10) (None, 10)
# Res inputs added to Prior_outputs 28
# Res inputs (final) (None, 38)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 550 relu False
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Res_outputs-------------------- (None, 1104)
# SV, PinV, Vpos, V-------------- (None, 1) (None, 1) (None, 1) (None, 550)
# nbr parameters: 305560
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.008912701
# Loss constraint on Vf:  5.3859395e-07
# Loss all on Vf:  4.6406967e-05
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.008912701
# Loss constraint on Vf:  5.3859395e-07
# Loss all on Vf:  4.6406967e-05
# train = 0.97 test = 0.97 loss-train = 0.000001 loss-test = 0.000001 iter=0
# Stats for iML1515_UB_AMN_QP CPU-time 97.2189
# R2 = 0.9741 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9741 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Iter 1 Collated Q2 0.9741218740170711
# number of reactions:  550 550
# number of metabolites:  1083
# filtered measurements size:  1
# RC reservoir file: ./Reservoir/iML1515_UB_AMN_QP
# RC model type: RC_AMN
# RC scaler: 0.0
# RC model input dim: 38
# RC model output dim: 1
# RC model medium bound: UB
# training set size (110, 38) (110, 1)
# reservoir S, Pin, Pout matrices (1083, 550) (38, 550) (1, 550)
# RC training epochs: 1000
# RC training regression: True
# RC training learn rate: 0.0001
# RC training dropout: 0.25
# RC training batch size: 5
# RC training validation iter: 0
# RC training xfold: 0
# RC training early stopping: False
# --------prior network --------
# training file: None
# model type: ANN_Dense
# model scaler: 0.0
# model input dim: 10
# model output dim: 10
# model medium bound:
# timestep: 0
# no training set provided
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# --------reservoir network-----
# training file: ./Dataset_model/iML1515_UB
# model type: AMN_QP
# model scaler: 11.0
# model input dim: 38
# model output dim: 1104
# model medium bound: UB
# timestep: 0
# training set size (11000, 38) (11000, 1)
# nbr hidden layer: 1
# hidden layer size: 500
# activation function: relu
# training epochs: 500
# training regression: True
# training learn rate: 0.001
# training dropout: 0.25
# training batch size: 5
# training validation iter: 0
# training xfold: 0
# training early stopping: False
# AMN scaler 0.0
# RC input shape (110, 38) (110, 4)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 10 relu True
# Prior inputs and outputs (None, 10) (None, 10)
# Res inputs added to Prior_outputs 28
# Res inputs (final) (None, 38)
# Dense layer n_hidden, hidden_dim, output_dim, activation, trainable: 1 500 550 relu False
# AMN output shapes for PoutV, SV, PinV, Vpos, V, outputs (None, 1) (None, 1) (None, 1) (None, 1) (None, 550) (None, 1104)
# Res_outputs-------------------- (None, 1104)
# SV, PinV, Vpos, V-------------- (None, 1) (None, 1) (None, 1) (None, 550)
# nbr parameters: 305560
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.00819272
# Loss constraint on Vf:  5.45585e-07
# Loss all on Vf:  4.3854223e-05
# 4/4 [==============================] - 0s 2ms/step
# Loss out on V0:  -1
# Loss constraint on V0:  -1
# Loss all on V0:  -1
# Loss out on Vf:  0.00819272
# Loss constraint on Vf:  5.45585e-07
# Loss all on Vf:  4.3854223e-05
# train = 0.98 test = 0.98 loss-train = 0.000001 loss-test = 0.000001 iter=0
# Stats for iML1515_UB_AMN_QP CPU-time 90.2241
# R2 = 0.9756 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Q2 = 0.9756 (+/- 0.0000) Constraint = 0.0000 (+/- 0.0000)
# Iter 2 Collated Q2 0.9755608195779709
# (3, 110, 592)
# Averaged Q2 = 0.9750 (+/- 0.0006)
# Loss SV average 0.0012 max 0.0022
# Loss Vin average 0.0000 max 0.0000
# Loss Vpos average 0.0000 max 0.0000
