# %% [markdown]
# # Install conda on your Colab environment

# %% [markdown]
# Ignore this first cell if you are running the notebook in a local environment.
#
# One can still run it locally but it will have no effect.

# %%
# Run this cell first - it will install a conda distribution (mamba)
# on your Drive then restart the kernel automatically 
# (don't worry about the crashing/restarting kernel messages)
# It HAS to be runned FIRST everytime you use the notebook in colab

import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    # !pip install -q condacolab
    import condacolab
    condacolab.install()

# %% [markdown]
# # Set up your Colab or local environment
# # Then import libraries

# %% [markdown]
# Run this cell in both cases of use (local or Colab)

# %%
import os
import sys
RunningInCOLAB  = 'google.colab' in str(get_ipython())

if RunningInCOLAB:
    
    # Check everything is fine with conda in Colab
    import condacolab
    condacolab.check()
    
    # Mount your drive environment in the colab runtime
    from google.colab import drive
    drive.mount('/content/drive',force_remount=True)
    
    # Change this variable to your path on Google Drive to which the repo has been cloned
    # If you followed the colab notebook 'repo_cloning.ipynb', nothing to change here
    repo_path_in_drive = '/content/drive/My Drive/Github/amn_release/'
    # Change directory to your repo cloned in your drive
    DIRECTORY = repo_path_in_drive
    os.chdir(repo_path_in_drive)
    # Copy the environment given in the environment_amn_light.yml
    # !mamba env update -n base -f environment_amn_light.yml
    
    # This is one of the few Colab-compatible font
    font = 'Liberation Sans'
    
else:
    
    # In this case the local root of the repo is our working directory
    DIRECTORY = './'
    font = 'arial'

# printing the working directory files. One can check you see the same folders and files as in the git webpage.
print(os.listdir(DIRECTORY))

from Library.Build_Dataset import *
# Out:
# ['README.md', 'Duplicate_Model.ipynb', 'Build_Model_Dense.ipynb', 'Dataset_experimental', 'Tutorial.ipynb', '.ipynb_checkpoints', '.git', 'Build_Model_RC.ipynb', 'environment_amn_light.yml', 'Build_Experimental.ipynb', 'Reservoir', 'Build_Model_MM.ipynb', 'Dataset_model', 'Figures.ipynb', 'Result', 'Figures', '.gitignore', 'LICENSE', 'Build_Model_ANN.ipynb', 'Build_Dataset.ipynb', 'Dataset_input', 'Functions', 'environment_amn.yml', 'Build_Model_AMN.ipynb', '.DS_Store']

# %% [markdown]
# # Generate Training Sets with FBA simulation or experimental data file

# %% [markdown]
# Below are provided several examples to generate training sets using different metabolic models, or experimental datafiles.
#
# We also provide a way to run cobrapy with provided inputs, such as the reservoir computing predictions (see figure 5 of the research paper).

# %% [markdown]
# ## Examples of FBA simulation training set generation

# %% [markdown]
# Using *E. coli* core which is a model of the central metabolic network common in most E. coli strains.

# %%
# Generate training set with E coli core model with FBA simulation

# What you can change
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
cobraname =  'e_coli_core_duplicated'  # name of the model 
mediumname = 'e_coli_core' # name of the medium file 
mediumbound = 'UB' # Exact bound (EB) or upper bound (UB)
method = 'pFBA' # FBA, pFBA or EXP
size  = 50 # training set size
reduce = False # Set at True if you want to reduce the model
# End of What you can change

# Run cobra
cobrafile  = DIRECTORY+'Dataset_input/'+cobraname
mediumfile = DIRECTORY+'Dataset_input/'+mediumname
parameter = TrainingSet(cobraname=cobrafile, 
                        mediumname=mediumfile, mediumbound=mediumbound, 
                        method=method,objective=[],
                        measure=[])
# Note: Leaving objective and mesaure as empty lists sets the default
# objective reaction of the SBML model as the objective reaction
# and the measure (Y) as this objective reaction.
parameter.get(sample_size=size)

# Saving file
trainingfile  = DIRECTORY+'Dataset_model/'+mediumname+'_'+parameter.mediumbound+'_'+str(size)
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
parameter.printout()
# Out:
# model file name: ./Dataset_model/e_coli_core_UB_50
# reduced model: False
# medium file name: ./Dataset_input/e_coli_core
# medium bound: UB
# list of reactions in objective: ['BIOMASS_Ecoli_core_w_GAM']
# method: pFBA
# trainingsize: 50
# list of medium reactions: 20
# list of medium levels: 20
# list of medium values: 20
# ratio of variable medium turned on: 0.5
# list of measured reactions: 154
# Stoichiometric matrix (72, 154)
# Boundary matrix from reactions to medium: (20, 154)
# Measurement matrix from reaction to measures: (154, 154)
# Reaction to metabolite matrix: (72, 154)
# Metabolite to reaction matrix: (154, 72)
# Training set X: (50, 20)
# Training set Y: (50, 154)
# S_int matrix (67, 154)
# S_ext matrix (154, 298)
# Q matrix (154, 67)
# P matrix (154, 154)
# b_int vector (67,)
# b_ext vector (50, 298)
# Sb matrix (154, 72)
# c vector (154,)

# %% [markdown]
# Using iML1515, alongside an experimental file that is guiding the generation of the training set (instead of the usual 'mediumname' we have a 'expname' file which contains all experimental media compositions, in order to obtain a training sets of all biologically relevant flux distributions according to these compositions. Note that we reduce the model in this next cell.

# %%
# Generate training set with E coli iML1515 with FBA simulation 
# constrained by experimental file: metabolites in medium are not drawn at
# random but are the same than in the provided training experimental file
# This cell may take several hours to execute! Avoid running this in Colab
    
# What you can change
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
cobraname =  'iML1515_duplicated' # name of the model 
mediumname = 'iML1515' # name of the medium file 
mediumbound = 'UB' # Exact bound (EB) or upper bound (UB)
expname = 'iML1515_EXP' # name of the experimental dataset for constraints
method = 'pFBA' # FBA, pFBA or EXP
size, size_i  = 110, 100 # expname training set size, training set size per item in expname
reduce = True # Set at True if you want to reduce the model
verbose = True
# End of What you can change

# Get X from experimental data set
cobrafile = DIRECTORY+'Dataset_input/'+cobraname
expfile  = DIRECTORY+'Dataset_input/'+expname
parameter = TrainingSet(cobraname=cobrafile, 
                        mediumname=expfile, 
                        mediumbound=mediumbound, 
                        mediumsize=38, 
                        method='EXP',verbose=False)
X = parameter.X.copy()

# Get other parameters from medium file
mediumfile = DIRECTORY+'Dataset_input/'+mediumname
parameter = TrainingSet(cobraname=cobrafile, 
                        mediumname=mediumfile, 
                        mediumbound=mediumbound, 
                        method=method, verbose=False)

# Create varmed the list of variable medium based on experimental file
varmed = {}
for i in range(X.shape[0]):
    varmed[i] = []
    for j in range(X.shape[1]):
        if parameter.levmed[j] > 1 and X[i,j] > 0:
            varmed[i].append(parameter.medium[j])
varmed = list(varmed.values())

# Get a Cobra training set constrained by varmed
for i in range(X.shape[0]): 
    parameter.get(sample_size=size_i, varmed=varmed[i], verbose=True) 

# Saving file
trainingfile  = DIRECTORY+'Dataset_model/'+mediumname+'_'+parameter.mediumbound
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
print(trainingfile)
parameter.printout()
# Out:
# sample: 0
# pass (varmed, obj): ['EX_gal_e_i'] 0.09339486031638548
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09339486031638464
# sample: 1
# pass (varmed, obj): ['EX_gal_e_i'] 0.09864436780341955
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09864436780341955
# sample: 2
# pass (varmed, obj): ['EX_gal_e_i'] 0.1397443454891211
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1397443454891211
# sample: 3
# pass (varmed, obj): ['EX_gal_e_i'] 0.10975066942808978
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10975066942808978
# sample: 4
# pass (varmed, obj): ['EX_gal_e_i'] 0.16057328719817235
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817235
# sample: 5
# pass (varmed, obj): ['EX_gal_e_i'] 0.16390591787162176
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16390591787162176
# sample: 6
# pass (varmed, obj): ['EX_gal_e_i'] 0.1105838270964515
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1105838270964515
# sample: 7
# pass (varmed, obj): ['EX_gal_e_i'] 0.09246924227558798
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09246924227558798
# sample: 8
# pass (varmed, obj): ['EX_gal_e_i'] 0.14724276450438079
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14724276450438079
# sample: 9
# pass (varmed, obj): ['EX_gal_e_i'] 0.08496195449550034
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08496195449550034
# sample: 10
# pass (varmed, obj): ['EX_gal_e_i'] 0.11974856144843322
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11974856144843322
# sample: 11
# pass (varmed, obj): ['EX_gal_e_i'] 0.1164159307749857
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1164159307749857
# sample: 12
# pass (varmed, obj): ['EX_gal_e_i'] 0.0995089109042385
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.0995089109042385
# sample: 13
# pass (varmed, obj): ['EX_gal_e_i'] 0.09518619540014188
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09518619540014188
# sample: 14
# pass (varmed, obj): ['EX_gal_e_i'] 0.1314127688055028
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1314127688055028
# sample: 15
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 16
# pass (varmed, obj): ['EX_gal_e_i'] 0.13807803015239856
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13807803015239856
# sample: 17
# pass (varmed, obj): ['EX_gal_e_i'] 0.11391645776989881
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11391645776989881
# sample: 18
# pass (varmed, obj): ['EX_gal_e_i'] 0.14640960683601958
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14640960683601958
# sample: 19
# pass (varmed, obj): ['EX_gal_e_i'] 0.15140855284618943
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15140855284618943
# sample: 20
# pass (varmed, obj): ['EX_gal_e_i'] 0.12724698046369184
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12724698046369184
# sample: 21
# pass (varmed, obj): ['EX_gal_e_i'] 0.12891329580041705
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12891329580041705
# sample: 22
# pass (varmed, obj): ['EX_gal_e_i'] 0.1314127688055028
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1314127688055028
# sample: 23
# pass (varmed, obj): ['EX_gal_e_i'] 0.15057539517782886
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15057539517782886
# sample: 24
# pass (varmed, obj): ['EX_gal_e_i'] 0.14391013383093226
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14391013383093226
# sample: 25
# pass (varmed, obj): ['EX_gal_e_i'] 0.09691528160178117
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09691528160178117
# sample: 26
# pass (varmed, obj): ['EX_gal_e_i'] 0.10725119642300343
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10725119642300343
# sample: 27
# pass (varmed, obj): ['EX_gal_e_i'] 0.09691528160178117
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09691528160178117
# sample: 28
# pass (varmed, obj): ['EX_gal_e_i'] 0.16307276020325834
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16307276020325834
# sample: 29
# pass (varmed, obj): ['EX_gal_e_i'] 0.158073814193087
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.158073814193087
# sample: 30
# pass (varmed, obj): ['EX_gal_e_i'] 0.11141698476481343
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11141698476481343
# sample: 31
# pass (varmed, obj): ['EX_gal_e_i'] 0.11141698476481343
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11141698476481343
# sample: 32
# pass (varmed, obj): ['EX_gal_e_i'] 0.16057328719817235
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817235
# sample: 33
# pass (varmed, obj): ['EX_gal_e_i'] 0.09605073850096212
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09605073850096212
# sample: 34
# pass (varmed, obj): ['EX_gal_e_i'] 0.1405775031574841
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1405775031574841
# sample: 35
# pass (varmed, obj): ['EX_gal_e_i'] 0.1122501424331756
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1122501424331756
# sample: 36
# pass (varmed, obj): ['EX_gal_e_i'] 0.13391224181058842
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13391224181058842
# sample: 37
# pass (varmed, obj): ['EX_gal_e_i'] 0.1164159307749857
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1164159307749857
# sample: 38
# pass (varmed, obj): ['EX_gal_e_i'] 0.1089175117597271
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1089175117597271
# sample: 39
# pass (varmed, obj): ['EX_gal_e_i'] 0.10123799710587578
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10123799710587578
# sample: 40
# pass (varmed, obj): ['EX_gal_e_i'] 0.16390591787162176
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16390591787162176
# sample: 41
# pass (varmed, obj): ['EX_gal_e_i'] 0.15057539517782886
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15057539517782886
# sample: 42
# pass (varmed, obj): ['EX_gal_e_i'] 0.10469616950915
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10469616950915
# sample: 43
# pass (varmed, obj): ['EX_gal_e_i'] 0.10556071260996859
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10556071260996859
# sample: 44
# pass (varmed, obj): ['EX_gal_e_i'] 0.1647390755399819
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1647390755399819
# sample: 45
# pass (varmed, obj): ['EX_gal_e_i'] 0.09518619540014188
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09518619540014188
# sample: 46
# pass (varmed, obj): ['EX_gal_e_i'] 0.10975066942808978
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10975066942808978
# sample: 47
# pass (varmed, obj): ['EX_gal_e_i'] 0.14807592217274107
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14807592217274107
# sample: 48
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 49
# pass (varmed, obj): ['EX_gal_e_i'] 0.09339486031638464
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09339486031638464
# sample: 50
# pass (varmed, obj): ['EX_gal_e_i'] 0.09864436780341955
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09864436780341955
# sample: 51
# pass (varmed, obj): ['EX_gal_e_i'] 0.10123799710587578
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10123799710587578
# sample: 52
# pass (varmed, obj): ['EX_gal_e_i'] 0.15307486818291516
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15307486818291516
# sample: 53
# pass (varmed, obj): ['EX_gal_e_i'] 0.14557644916765577
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916765577
# sample: 54
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 55
# pass (varmed, obj): ['EX_gal_e_i'] 0.09518619540014188
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09518619540014188
# sample: 56
# pass (varmed, obj): ['EX_gal_e_i'] 0.10037345400505505
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10037345400505505
# sample: 57
# pass (varmed, obj): ['EX_gal_e_i'] 0.12474750745860717
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12474750745860717
# sample: 58
# pass (varmed, obj): ['EX_gal_e_i'] 0.09154362423479143
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09154362423479143
# sample: 59
# pass (varmed, obj): ['EX_gal_e_i'] 0.14890907984110527
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14890907984110527
# sample: 60
# pass (varmed, obj): ['EX_gal_e_i'] 0.10975066942808978
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10975066942808978
# sample: 61
# pass (varmed, obj): ['EX_gal_e_i'] 0.11391645776989881
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11391645776989881
# sample: 62
# pass (varmed, obj): ['EX_gal_e_i'] 0.15640749885636288
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15640749885636288
# sample: 63
# pass (varmed, obj): ['EX_gal_e_i'] 0.16640539087670697
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16640539087670697
# sample: 64
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 65
# pass (varmed, obj): ['EX_gal_e_i'] 0.12308119212188161
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12308119212188161
# sample: 66
# pass (varmed, obj): ['EX_gal_e_i'] 0.08969238815319773
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08969238815319773
# sample: 67
# pass (varmed, obj): ['EX_gal_e_i'] 0.08876677011240106
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08876677011240106
# sample: 68
# pass (varmed, obj): ['EX_gal_e_i'] 0.14557644916765577
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916765577
# sample: 69
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 70
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 71
# pass (varmed, obj): ['EX_gal_e_i'] 0.128080138132054
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.128080138132054
# sample: 72
# pass (varmed, obj): ['EX_gal_e_i'] 0.1314127688055028
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1314127688055028
# sample: 73
# pass (varmed, obj): ['EX_gal_e_i'] 0.11474961543826206
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11474961543826206
# sample: 74
# pass (varmed, obj): ['EX_gal_e_i'] 0.09864436780341955
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09864436780341955
# sample: 75
# pass (varmed, obj): ['EX_gal_e_i'] 0.15057539517782886
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15057539517782886
# sample: 76
# pass (varmed, obj): ['EX_gal_e_i'] 0.15974012952981093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15974012952981093
# sample: 77
# pass (varmed, obj): ['EX_gal_e_i'] 0.09864436780341955
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09864436780341955
# sample: 78
# pass (varmed, obj): ['EX_gal_e_i'] 0.09061800619399438
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09061800619399438
# sample: 79
# pass (varmed, obj): ['EX_gal_e_i'] 0.1572406565247245
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1572406565247245
# sample: 80
# pass (varmed, obj): ['EX_gal_e_i'] 0.10469616950915
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10469616950915
# sample: 81
# pass (varmed, obj): ['EX_gal_e_i'] 0.09518619540014188
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09518619540014188
# sample: 82
# pass (varmed, obj): ['EX_gal_e_i'] 0.09605073850096212
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09605073850096212
# sample: 83
# pass (varmed, obj): ['EX_gal_e_i'] 0.16307276020325834
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16307276020325834
# sample: 84
# pass (varmed, obj): ['EX_gal_e_i'] 0.16640539087670697
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16640539087670697
# sample: 85
# pass (varmed, obj): ['EX_gal_e_i'] 0.13807803015239856
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13807803015239856
# sample: 86
# pass (varmed, obj): ['EX_gal_e_i'] 0.13391224181058842
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13391224181058842
# sample: 87
# pass (varmed, obj): ['EX_gal_e_i'] 0.1522417105145523
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1522417105145523
# sample: 88
# pass (varmed, obj): ['EX_gal_e_i'] 0.12141487678515771
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12141487678515771
# sample: 89
# pass (varmed, obj): ['EX_gal_e_i'] 0.13391224181058842
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13391224181058842
# sample: 90
# pass (varmed, obj): ['EX_gal_e_i'] 0.16723854854506998
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16723854854506998
# sample: 91
# pass (varmed, obj): ['EX_gal_e_i'] 0.128080138132054
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.128080138132054
# sample: 92
# pass (varmed, obj): ['EX_gal_e_i'] 0.12391434979024492
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12391434979024492
# sample: 93
# pass (varmed, obj): ['EX_gal_e_i'] 0.11974856144843322
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11974856144843322
# sample: 94
# pass (varmed, obj): ['EX_gal_e_i'] 0.16057328719817235
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817235
# sample: 95
# pass (varmed, obj): ['EX_gal_e_i'] 0.14724276450438079
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14724276450438079
# sample: 96
# pass (varmed, obj): ['EX_gal_e_i'] 0.11724908844334811
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11724908844334811
# sample: 97
# pass (varmed, obj): ['EX_gal_e_i'] 0.08496195449550034
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08496195449550034
# sample: 98
# pass (varmed, obj): ['EX_gal_e_i'] 0.10123799710587578
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10123799710587578
# sample: 99
# pass (varmed, obj): ['EX_gal_e_i'] 0.10556071260996859
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10556071260996859
# sample: 0
# pass (varmed, obj): ['EX_fru_e_i'] 0.08825253786751423
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08825253786751423
# sample: 1
# pass (varmed, obj): ['EX_fru_e_i'] 0.11413096595719598
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11413096595719598
# sample: 2
# pass (varmed, obj): ['EX_fru_e_i'] 0.10142594125816191
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10142594125816191
# sample: 3
# pass (varmed, obj): ['EX_fru_e_i'] 0.16652441340072707
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16652441340072707
# sample: 4
# pass (varmed, obj): ['EX_fru_e_i'] 0.16462005301589996
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16462005301589996
# sample: 5
# pass (varmed, obj): ['EX_fru_e_i'] 0.09947132207373582
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09947132207373582
# sample: 6
# pass (varmed, obj): ['EX_fru_e_i'] 0.1351024670510793
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1351024670510793
# sample: 7
# pass (varmed, obj): ['EX_fru_e_i'] 0.1617635124386591
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1617635124386591
# sample: 8
# pass (varmed, obj): ['EX_fru_e_i'] 0.1024032508503752
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1024032508503752
# sample: 9
# pass (varmed, obj): ['EX_fru_e_i'] 0.13415028685866587
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13415028685866587
# sample: 10
# pass (varmed, obj): ['EX_fru_e_i'] 0.13700682743590656
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13700682743590656
# sample: 11
# pass (varmed, obj): ['EX_fru_e_i'] 0.11022172758807977
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11022172758807977
# sample: 12
# pass (varmed, obj): ['EX_fru_e_i'] 0.13224592647383865
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13224592647383865
# sample: 13
# pass (varmed, obj): ['EX_fru_e_i'] 0.1024032508503752
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1024032508503752
# sample: 14
# pass (varmed, obj): ['EX_fru_e_i'] 0.11701104339522164
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11701104339522164
# sample: 15
# pass (varmed, obj): ['EX_fru_e_i'] 0.1636678728234863
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1636678728234863
# sample: 16
# pass (varmed, obj): ['EX_fru_e_i'] 0.16271569263107274
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16271569263107274
# sample: 17
# pass (varmed, obj): ['EX_fru_e_i'] 0.12558066512694382
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12558066512694382
# sample: 18
# pass (varmed, obj): ['EX_fru_e_i'] 0.17223749455520837
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17223749455520837
# sample: 19
# pass (varmed, obj): ['EX_fru_e_i'] 0.09750871827548105
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09750871827548105
# sample: 20
# pass (varmed, obj): ['EX_fru_e_i'] 0.11510668301039455
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11510668301039455
# sample: 21
# pass (varmed, obj): ['EX_fru_e_i'] 0.1636678728234863
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1636678728234863
# sample: 22
# pass (varmed, obj): ['EX_fru_e_i'] 0.1024032508503752
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1024032508503752
# sample: 23
# pass (varmed, obj): ['EX_fru_e_i'] 0.10142594125816191
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10142594125816191
# sample: 24
# pass (varmed, obj): ['EX_fru_e_i'] 0.08506449124965845
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08506449124965845
# sample: 25
# pass (varmed, obj): ['EX_fru_e_i'] 0.11605886320280825
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11605886320280825
# sample: 26
# pass (varmed, obj): ['EX_fru_e_i'] 0.15605043128417784
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15605043128417784
# sample: 27
# pass (varmed, obj): ['EX_fru_e_i'] 0.1474808095524556
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1474808095524556
# sample: 28
# pass (varmed, obj): ['EX_fru_e_i'] 0.12272412454970308
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12272412454970308
# sample: 29
# pass (varmed, obj): ['EX_fru_e_i'] 0.1072897988114404
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1072897988114404
# sample: 30
# pass (varmed, obj): ['EX_fru_e_i'] 0.1779505757096897
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1779505757096897
# sample: 31
# pass (varmed, obj): ['EX_fru_e_i'] 0.14938516993728268
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14938516993728268
# sample: 32
# pass (varmed, obj): ['EX_fru_e_i'] 0.15033735012969654
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15033735012969654
# sample: 33
# pass (varmed, obj): ['EX_fru_e_i'] 0.14557644916762844
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916762844
# sample: 34
# pass (varmed, obj): ['EX_fru_e_i'] 0.17699839551727622
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17699839551727622
# sample: 35
# pass (varmed, obj): ['EX_fru_e_i'] 0.11217634677250589
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11217634677250589
# sample: 36
# pass (varmed, obj): ['EX_fru_e_i'] 0.16462005301589996
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16462005301589996
# sample: 37
# pass (varmed, obj): ['EX_fru_e_i'] 0.14557644916762844
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916762844
# sample: 38
# pass (varmed, obj): ['EX_fru_e_i'] 0.15985915205383183
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15985915205383183
# sample: 39
# pass (varmed, obj): ['EX_fru_e_i'] 0.13224592647383865
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13224592647383865
# sample: 40
# pass (varmed, obj): ['EX_fru_e_i'] 0.17509403513244887
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17509403513244887
# sample: 41
# pass (varmed, obj): ['EX_fru_e_i'] 0.15795479166900492
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15795479166900492
# sample: 42
# pass (varmed, obj): ['EX_fru_e_i'] 0.16842877378555418
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16842877378555418
# sample: 43
# pass (varmed, obj): ['EX_fru_e_i'] 0.12177194435728933
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12177194435728933
# sample: 44
# pass (varmed, obj): ['EX_fru_e_i'] 0.09648025378570689
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09648025378570689
# sample: 45
# pass (varmed, obj): ['EX_fru_e_i'] 0.10631248921922748
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10631248921922748
# sample: 46
# pass (varmed, obj): ['EX_fru_e_i'] 0.11796322358763542
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11796322358763542
# sample: 47
# pass (varmed, obj): ['EX_fru_e_i'] 0.17699839551727622
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17699839551727622
# sample: 48
# pass (varmed, obj): ['EX_fru_e_i'] 0.12748502551177093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12748502551177093
# sample: 49
# pass (varmed, obj): ['EX_fru_e_i'] 0.1703331341703814
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1703331341703814
# sample: 50
# pass (varmed, obj): ['EX_fru_e_i'] 0.1779505757096897
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1779505757096897
# sample: 51
# pass (varmed, obj): ['EX_fru_e_i'] 0.15605043128417784
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15605043128417784
# sample: 52
# pass (varmed, obj): ['EX_fru_e_i'] 0.1246284849345301
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1246284849345301
# sample: 53
# pass (varmed, obj): ['EX_fru_e_i'] 0.12748502551177093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12748502551177093
# sample: 54
# pass (varmed, obj): ['EX_fru_e_i'] 0.17223749455520837
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17223749455520837
# sample: 55
# pass (varmed, obj): ['EX_fru_e_i'] 0.15414607089935053
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15414607089935053
# sample: 56
# pass (varmed, obj): ['EX_fru_e_i'] 0.09339486031638494
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09339486031638494
# sample: 57
# pass (varmed, obj): ['EX_fru_e_i'] 0.1674765935931405
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1674765935931405
# sample: 58
# pass (varmed, obj): ['EX_fru_e_i'] 0.15509825109176426
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15509825109176426
# sample: 59
# pass (varmed, obj): ['EX_fru_e_i'] 0.11315365636471895
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11315365636471895
# sample: 60
# pass (varmed, obj): ['EX_fru_e_i'] 0.11510668301039455
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11510668301039455
# sample: 61
# pass (varmed, obj): ['EX_fru_e_i'] 0.17128531436279476
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17128531436279476
# sample: 62
# pass (varmed, obj): ['EX_fru_e_i'] 0.11022172758807977
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11022172758807977
# sample: 63
# pass (varmed, obj): ['EX_fru_e_i'] 0.16081133224624564
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16081133224624564
# sample: 64
# pass (varmed, obj): ['EX_fru_e_i'] 0.1636678728234863
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1636678728234863
# sample: 65
# pass (varmed, obj): ['EX_fru_e_i'] 0.1674765935931405
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1674765935931405
# sample: 66
# pass (varmed, obj): ['EX_fru_e_i'] 0.14557644916762844
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916762844
# sample: 67
# pass (varmed, obj): ['EX_fru_e_i'] 0.09849401248152294
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09849401248152294
# sample: 68
# pass (varmed, obj): ['EX_fru_e_i'] 0.12558066512694382
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12558066512694382
# sample: 69
# pass (varmed, obj): ['EX_fru_e_i'] 0.11796322358763542
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11796322358763542
# sample: 70
# pass (varmed, obj): ['EX_fru_e_i'] 0.08928100235728857
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08928100235728857
# sample: 71
# pass (varmed, obj): ['EX_fru_e_i'] 0.1693809539779677
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1693809539779677
# sample: 72
# pass (varmed, obj): ['EX_fru_e_i'] 0.17604621532486261
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17604621532486261
# sample: 73
# pass (varmed, obj): ['EX_fru_e_i'] 0.11315365636471895
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11315365636471895
# sample: 74
# pass (varmed, obj): ['EX_fru_e_i'] 0.12367630474211658
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12367630474211658
# sample: 75
# pass (varmed, obj): ['EX_fru_e_i'] 0.1731896747476218
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1731896747476218
# sample: 76
# pass (varmed, obj): ['EX_fru_e_i'] 0.09442332480615909
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09442332480615909
# sample: 77
# pass (varmed, obj): ['EX_fru_e_i'] 0.09236639582661046
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09236639582661046
# sample: 78
# pass (varmed, obj): ['EX_fru_e_i'] 0.1072897988114404
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1072897988114404
# sample: 79
# pass (varmed, obj): ['EX_fru_e_i'] 0.11701104339522164
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11701104339522164
# sample: 80
# pass (varmed, obj): ['EX_fru_e_i'] 0.08825253786751423
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08825253786751423
# sample: 81
# pass (varmed, obj): ['EX_fru_e_i'] 0.09442332480615909
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09442332480615909
# sample: 82
# pass (varmed, obj): ['EX_fru_e_i'] 0.13605464724349298
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13605464724349298
# sample: 83
# pass (varmed, obj): ['EX_fru_e_i'] 0.1589069718614185
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1589069718614185
# sample: 84
# pass (varmed, obj): ['EX_fru_e_i'] 0.15128953032211004
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15128953032211004
# sample: 85
# pass (varmed, obj): ['EX_fru_e_i'] 0.11510668301039455
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11510668301039455
# sample: 86
# pass (varmed, obj): ['EX_fru_e_i'] 0.15319389070693723
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15319389070693723
# sample: 87
# pass (varmed, obj): ['EX_fru_e_i'] 0.15700261147659134
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15700261147659134
# sample: 88
# pass (varmed, obj): ['EX_fru_e_i'] 0.11510668301039455
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11510668301039455
# sample: 89
# pass (varmed, obj): ['EX_fru_e_i'] 0.09442332480615909
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09442332480615909
# sample: 90
# pass (varmed, obj): ['EX_fru_e_i'] 0.08722407337774048
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08722407337774048
# sample: 91
# pass (varmed, obj): ['EX_fru_e_i'] 0.14843298974486935
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14843298974486935
# sample: 92
# pass (varmed, obj): ['EX_fru_e_i'] 0.09849401248152294
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09849401248152294
# sample: 93
# pass (varmed, obj): ['EX_fru_e_i'] 0.15795479166900492
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15795479166900492
# sample: 94
# pass (varmed, obj): ['EX_fru_e_i'] 0.13605464724349298
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13605464724349298
# sample: 95
# pass (varmed, obj): ['EX_fru_e_i'] 0.09030946684706227
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09030946684706227
# sample: 96
# pass (varmed, obj): ['EX_fru_e_i'] 0.17509403513244887
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17509403513244887
# sample: 97
# pass (varmed, obj): ['EX_fru_e_i'] 0.16652441340072707
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16652441340072707
# sample: 98
# pass (varmed, obj): ['EX_fru_e_i'] 0.13224592647383865
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13224592647383865
# sample: 99
# pass (varmed, obj): ['EX_fru_e_i'] 0.14557644916762844
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14557644916762844
# sample: 0
# pass (varmed, obj): ['EX_malt_e_i'] 0.15724065652472488
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15724065652472488
# sample: 1
# pass (varmed, obj): ['EX_malt_e_i'] 0.1439101338309348
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1439101338309348
# sample: 2
# pass (varmed, obj): ['EX_malt_e_i'] 0.15390802585127697
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15390802585127697
# sample: 3
# pass (varmed, obj): ['EX_malt_e_i'] 0.16390591787162082
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16390591787162082
# sample: 4
# pass (varmed, obj): ['EX_malt_e_i'] 0.14057750315748688
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14057750315748688
# sample: 5
# pass (varmed, obj): ['EX_malt_e_i'] 0.24388905403437686
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24388905403437686
# sample: 6
# pass (varmed, obj): ['EX_malt_e_i'] 0.23055853134058316
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23055853134058316
# sample: 7
# pass (varmed, obj): ['EX_malt_e_i'] 0.18390170191230965
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18390170191230965
# sample: 8
# pass (varmed, obj): ['EX_malt_e_i'] 0.20223117061627507
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.20223117061627507
# sample: 9
# pass (varmed, obj): ['EX_malt_e_i'] 0.16223960253489747
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16223960253489747
# sample: 10
# pass (varmed, obj): ['EX_malt_e_i'] 0.11724908844334776
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11724908844334776
# sample: 11
# pass (varmed, obj): ['EX_malt_e_i'] 0.1705711792185175
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1705711792185175
# sample: 12
# pass (varmed, obj): ['EX_malt_e_i'] 0.16057328719817315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817315
# sample: 13
# pass (varmed, obj): ['EX_malt_e_i'] 0.08825253786751432
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08825253786751432
# sample: 14
# pass (varmed, obj): ['EX_malt_e_i'] 0.1922332785959289
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1922332785959289
# sample: 15
# pass (varmed, obj): ['EX_malt_e_i'] 0.2155616933100662
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2155616933100662
# sample: 16
# pass (varmed, obj): ['EX_malt_e_i'] 0.11724908844334776
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11724908844334776
# sample: 17
# pass (varmed, obj): ['EX_malt_e_i'] 0.13224592647386404
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13224592647386404
# sample: 18
# pass (varmed, obj): ['EX_malt_e_i'] 0.22555958533041112
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22555958533041112
# sample: 19
# pass (varmed, obj): ['EX_malt_e_i'] 0.1489090798411056
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1489090798411056
# sample: 20
# pass (varmed, obj): ['EX_malt_e_i'] 0.20556380128972232
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.20556380128972232
# sample: 21
# pass (varmed, obj): ['EX_malt_e_i'] 0.23389116201403282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23389116201403282
# sample: 22
# pass (varmed, obj): ['EX_malt_e_i'] 0.1122501424331745
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1122501424331745
# sample: 23
# pass (varmed, obj): ['EX_malt_e_i'] 0.178902755902138
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.178902755902138
# sample: 24
# pass (varmed, obj): ['EX_malt_e_i'] 0.09725330440265967
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09725330440265967
# sample: 25
# pass (varmed, obj): ['EX_malt_e_i'] 0.16057328719817315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817315
# sample: 26
# pass (varmed, obj): ['EX_malt_e_i'] 0.10225225041283023
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10225225041283023
# sample: 27
# pass (varmed, obj): ['EX_malt_e_i'] 0.1705711792185175
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1705711792185175
# sample: 28
# pass (varmed, obj): ['EX_malt_e_i'] 0.08619560888796657
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08619560888796657
# sample: 29
# pass (varmed, obj): ['EX_malt_e_i'] 0.16057328719817315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817315
# sample: 30
# pass (varmed, obj): ['EX_malt_e_i'] 0.20056485527955095
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.20056485527955095
# sample: 31
# pass (varmed, obj): ['EX_malt_e_i'] 0.11058382709645066
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11058382709645066
# sample: 32
# pass (varmed, obj): ['EX_malt_e_i'] 0.09383299750321136
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09383299750321136
# sample: 33
# pass (varmed, obj): ['EX_malt_e_i'] 0.09725330440265967
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09725330440265967
# sample: 34
# pass (varmed, obj): ['EX_malt_e_i'] 0.15724065652472488
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15724065652472488
# sample: 35
# pass (varmed, obj): ['EX_malt_e_i'] 0.2088964319631702
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2088964319631702
# sample: 36
# pass (varmed, obj): ['EX_malt_e_i'] 0.16057328719817315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16057328719817315
# sample: 37
# pass (varmed, obj): ['EX_malt_e_i'] 0.23722379268748056
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23722379268748056
# sample: 38
# pass (varmed, obj): ['EX_malt_e_i'] 0.1505753951778281
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1505753951778281
# sample: 39
# pass (varmed, obj): ['EX_malt_e_i'] 0.12058171911679567
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12058171911679567
# sample: 40
# pass (varmed, obj): ['EX_malt_e_i'] 0.10225225041283023
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10225225041283023
# sample: 41
# pass (varmed, obj): ['EX_malt_e_i'] 0.15390802585127697
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15390802585127697
# sample: 42
# pass (varmed, obj): ['EX_malt_e_i'] 0.1139164577698997
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1139164577698997
# sample: 43
# pass (varmed, obj): ['EX_malt_e_i'] 0.21222906263661898
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21222906263661898
# sample: 44
# pass (varmed, obj): ['EX_malt_e_i'] 0.15224171051455315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15224171051455315
# sample: 45
# pass (varmed, obj): ['EX_malt_e_i'] 0.18390170191230965
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18390170191230965
# sample: 46
# pass (varmed, obj): ['EX_malt_e_i'] 0.22222695465696282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22222695465696282
# sample: 47
# pass (varmed, obj): ['EX_malt_e_i'] 0.15224171051455315
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15224171051455315
# sample: 48
# pass (varmed, obj): ['EX_malt_e_i'] 0.16890486388179277
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16890486388179277
# sample: 49
# pass (varmed, obj): ['EX_malt_e_i'] 0.24888800004454842
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24888800004454842
# sample: 50
# pass (varmed, obj): ['EX_malt_e_i'] 0.10558488108627875
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10558488108627875
# sample: 51
# pass (varmed, obj): ['EX_malt_e_i'] 0.2172280086467895
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2172280086467895
# sample: 52
# pass (varmed, obj): ['EX_malt_e_i'] 0.21889432398351447
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21889432398351447
# sample: 53
# pass (varmed, obj): ['EX_malt_e_i'] 0.1222480344535204
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1222480344535204
# sample: 54
# pass (varmed, obj): ['EX_malt_e_i'] 0.20223117061627507
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.20223117061627507
# sample: 55
# pass (varmed, obj): ['EX_malt_e_i'] 0.16723854854506995
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16723854854506995
# sample: 56
# pass (varmed, obj): ['EX_malt_e_i'] 0.18723433258575756
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18723433258575756
# sample: 57
# pass (varmed, obj): ['EX_malt_e_i'] 0.18390170191230965
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18390170191230965
# sample: 58
# pass (varmed, obj): ['EX_malt_e_i'] 0.10891751175972784
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10891751175972784
# sample: 59
# pass (varmed, obj): ['EX_malt_e_i'] 0.09202873364063294
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09202873364063294
# sample: 60
# pass (varmed, obj): ['EX_malt_e_i'] 0.13891118782076126
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13891118782076126
# sample: 61
# pass (varmed, obj): ['EX_malt_e_i'] 0.21389537797334282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21389537797334282
# sample: 62
# pass (varmed, obj): ['EX_malt_e_i'] 0.23222484667730856
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23222484667730856
# sample: 63
# pass (varmed, obj): ['EX_malt_e_i'] 0.11558277310662303
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11558277310662303
# sample: 64
# pass (varmed, obj): ['EX_malt_e_i'] 0.13557855714731437
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13557855714731437
# sample: 65
# pass (varmed, obj): ['EX_malt_e_i'] 0.20223117061627507
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.20223117061627507
# sample: 66
# pass (varmed, obj): ['EX_malt_e_i'] 0.1705711792185175
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1705711792185175
# sample: 67
# pass (varmed, obj): ['EX_malt_e_i'] 0.17223749455524168
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17223749455524168
# sample: 68
# pass (varmed, obj): ['EX_malt_e_i'] 0.12058171911679567
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12058171911679567
# sample: 69
# pass (varmed, obj): ['EX_malt_e_i'] 0.09558698906593611
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09558698906593611
# sample: 70
# pass (varmed, obj): ['EX_malt_e_i'] 0.2038974859529982
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2038974859529982
# sample: 71
# pass (varmed, obj): ['EX_malt_e_i'] 0.18890064792248282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18890064792248282
# sample: 72
# pass (varmed, obj): ['EX_malt_e_i'] 0.1139164577698997
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1139164577698997
# sample: 73
# pass (varmed, obj): ['EX_malt_e_i'] 0.21056274729989286
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21056274729989286
# sample: 74
# pass (varmed, obj): ['EX_malt_e_i'] 0.09383299750321136
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09383299750321136
# sample: 75
# pass (varmed, obj): ['EX_malt_e_i'] 0.12391434979024342
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12391434979024342
# sample: 76
# pass (varmed, obj): ['EX_malt_e_i'] 0.1189154037800723
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1189154037800723
# sample: 77
# pass (varmed, obj): ['EX_malt_e_i'] 0.2288922160038591
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2288922160038591
# sample: 78
# pass (varmed, obj): ['EX_malt_e_i'] 0.2088964319631702
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2088964319631702
# sample: 79
# pass (varmed, obj): ['EX_malt_e_i'] 0.1455764491676582
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1455764491676582
# sample: 80
# pass (varmed, obj): ['EX_malt_e_i'] 0.1455764491676582
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1455764491676582
# sample: 81
# pass (varmed, obj): ['EX_malt_e_i'] 0.10558488108627875
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10558488108627875
# sample: 82
# pass (varmed, obj): ['EX_malt_e_i'] 0.1555743411880007
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1555743411880007
# sample: 83
# pass (varmed, obj): ['EX_malt_e_i'] 0.17723644056541402
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17723644056541402
# sample: 84
# pass (varmed, obj): ['EX_malt_e_i'] 0.2238932699936877
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2238932699936877
# sample: 85
# pass (varmed, obj): ['EX_malt_e_i'] 0.1189154037800723
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1189154037800723
# sample: 86
# pass (varmed, obj): ['EX_malt_e_i'] 0.1555743411880007
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1555743411880007
# sample: 87
# pass (varmed, obj): ['EX_malt_e_i'] 0.22222695465696282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22222695465696282
# sample: 88
# pass (varmed, obj): ['EX_malt_e_i'] 0.18890064792248282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18890064792248282
# sample: 89
# pass (varmed, obj): ['EX_malt_e_i'] 0.10391856574955427
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10391856574955427
# sample: 90
# pass (varmed, obj): ['EX_malt_e_i'] 0.14724276450438264
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14724276450438264
# sample: 91
# pass (varmed, obj): ['EX_malt_e_i'] 0.08619560888796657
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08619560888796657
# sample: 92
# pass (varmed, obj): ['EX_malt_e_i'] 0.13724487248403552
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13724487248403552
# sample: 93
# pass (varmed, obj): ['EX_malt_e_i'] 0.19056696325920736
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19056696325920736
# sample: 94
# pass (varmed, obj): ['EX_malt_e_i'] 0.2288922160038591
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2288922160038591
# sample: 95
# pass (varmed, obj): ['EX_malt_e_i'] 0.14057750315748688
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14057750315748688
# sample: 96
# pass (varmed, obj): ['EX_malt_e_i'] 0.22222695465696282
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22222695465696282
# sample: 97
# pass (varmed, obj): ['EX_malt_e_i'] 0.10891751175972784
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10891751175972784
# sample: 98
# pass (varmed, obj): ['EX_malt_e_i'] 0.19889853994282766
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19889853994282766
# sample: 99
# pass (varmed, obj): ['EX_malt_e_i'] 0.13891118782076126
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13891118782076126
# sample: 0
# pass (varmed, obj): ['EX_melib_e_i'] 0.1366497598637776
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1366497598637776
# sample: 1
# pass (varmed, obj): ['EX_melib_e_i'] 0.23567649987480702
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23567649987480702
# sample: 2
# pass (varmed, obj): ['EX_melib_e_i'] 0.14593351673981123
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14593351673981123
# sample: 3
# pass (varmed, obj): ['EX_melib_e_i'] 0.14438622392713873
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14438622392713873
# sample: 4
# pass (varmed, obj): ['EX_melib_e_i'] 0.2093725220593785
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2093725220593785
# sample: 5
# pass (varmed, obj): ['EX_melib_e_i'] 0.17842666580592986
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17842666580592986
# sample: 6
# pass (varmed, obj): ['EX_melib_e_i'] 0.11808224611170959
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11808224611170959
# sample: 7
# pass (varmed, obj): ['EX_melib_e_i'] 0.1351024670511057
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1351024670511057
# sample: 8
# pass (varmed, obj): ['EX_melib_e_i'] 0.22484545018610222
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22484545018610222
# sample: 9
# pass (varmed, obj): ['EX_melib_e_i'] 0.0860927624389885
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.0860927624389885
# sample: 10
# pass (varmed, obj): ['EX_melib_e_i'] 0.23567649987480702
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23567649987480702
# sample: 11
# pass (varmed, obj): ['EX_melib_e_i'] 0.1258187101750719
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1258187101750719
# sample: 12
# pass (varmed, obj): ['EX_melib_e_i'] 0.18461583705661952
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18461583705661952
# sample: 13
# pass (varmed, obj): ['EX_melib_e_i'] 0.17842666580592986
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17842666580592986
# sample: 14
# pass (varmed, obj): ['EX_melib_e_i'] 0.08988617030382048
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08988617030382048
# sample: 15
# pass (varmed, obj): ['EX_melib_e_i'] 0.13355517423843266
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13355517423843266
# sample: 16
# pass (varmed, obj): ['EX_melib_e_i'] 0.11344036767369321
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11344036767369321
# sample: 17
# pass (varmed, obj): ['EX_melib_e_i'] 0.17842666580592986
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17842666580592986
# sample: 18
# pass (varmed, obj): ['EX_melib_e_i'] 0.19544688674532673
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19544688674532673
# sample: 19
# pass (varmed, obj): ['EX_melib_e_i'] 0.18461583705661952
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18461583705661952
# sample: 20
# pass (varmed, obj): ['EX_melib_e_i'] 0.22020357174808386
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22020357174808386
# sample: 21
# pass (varmed, obj): ['EX_melib_e_i'] 0.13200788142576012
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13200788142576012
# sample: 22
# pass (varmed, obj): ['EX_melib_e_i'] 0.1969941795579994
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1969941795579994
# sample: 23
# pass (varmed, obj): ['EX_melib_e_i'] 0.2294873286241179
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2294873286241179
# sample: 24
# pass (varmed, obj): ['EX_melib_e_i'] 0.11653495329903822
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11653495329903822
# sample: 25
# pass (varmed, obj): ['EX_melib_e_i'] 0.0860927624389885
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.0860927624389885
# sample: 26
# pass (varmed, obj): ['EX_melib_e_i'] 0.09796743954696835
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.09796743954696835
# sample: 27
# pass (varmed, obj): ['EX_melib_e_i'] 0.23103462143679168
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.23103462143679168
# sample: 28
# pass (varmed, obj): ['EX_melib_e_i'] 0.1521226879905007
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1521226879905007
# sample: 29
# pass (varmed, obj): ['EX_melib_e_i'] 0.22175086456075577
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22175086456075577
# sample: 30
# pass (varmed, obj): ['EX_melib_e_i'] 0.17533208018058635
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.17533208018058635
# sample: 31
# pass (varmed, obj): ['EX_melib_e_i'] 0.2109198148720511
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2109198148720511
# sample: 32
# pass (varmed, obj): ['EX_melib_e_i'] 0.08988617030382048
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.08988617030382048
# sample: 33
# pass (varmed, obj): ['EX_melib_e_i'] 0.13974434548912193
# ...
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.273942241357437
# sample: 21
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.2751324665979542
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2751324665979542
# sample: 22
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i'] 0.15224171051455426
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15224171051455426
# sample: 23
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.1596806182677867
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1596806182677867
# sample: 24
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.3063758791615305
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3063758791615305
# sample: 25
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.2941760704462291
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2941760704462291
# sample: 26
# pass (varmed, obj): ['EX_succ_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i'] 0.2596595384712307
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2596595384712307
# sample: 27
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i'] 0.3182781315667024
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3182781315667024
# sample: 28
# pass (varmed, obj): ['EX_succ_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.2010409453757592
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2010409453757592
# sample: 29
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.1254616426029171
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1254616426029171
# sample: 30
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.19925560751498328
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19925560751498328
# sample: 31
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.1596806182677867
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1596806182677867
# sample: 32
# pass (varmed, obj): ['EX_fru_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.29863941509816866
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.29863941509816866
# sample: 33
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.26769355884472196
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.26769355884472196
# sample: 34
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.14123212703977012
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14123212703977012
# sample: 35
# pass (varmed, obj): ['EX_fru_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.3343461723136844
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3343461723136844
# sample: 36
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.19538737548330226
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19538737548330226
# sample: 37
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.2763226918384712
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2763226918384712
# sample: 38
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.2810835928005401
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2810835928005401
# sample: 39
# pass (varmed, obj): ['EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i'] 0.16473907553998454
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16473907553998454
# sample: 40
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i'] 0.18289001045787165
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18289001045787165
# sample: 41
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.24656706082554175
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24656706082554175
# sample: 42
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.12813964939408068
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12813964939408068
# sample: 43
# pass (varmed, obj): ['EX_succ_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i'] 0.13766145131821825
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13766145131821825
# sample: 44
# pass (varmed, obj): ['EX_fru_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.32095613835786624
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.32095613835786624
# sample: 45
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.2742397976675662
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2742397976675662
# sample: 46
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.1742608774641221
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1742608774641221
# sample: 47
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.2807860364904109
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2807860364904109
# sample: 48
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.2679911151548511
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2679911151548511
# sample: 49
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.1385541202486063
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1385541202486063
# sample: 50
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.18140222890722538
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18140222890722538
# sample: 51
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i'] 0.1995531638251125
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1995531638251125
# sample: 52
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.19925560751498314
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19925560751498314
# sample: 53
# pass (varmed, obj): ['EX_fru_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.3102441111932114
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3102441111932114
# sample: 54
# pass (varmed, obj): ['EX_succ_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.32512192669967654
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.32512192669967654
# sample: 55
# pass (varmed, obj): ['EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i'] 0.11326183388761604
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11326183388761604
# sample: 56
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i'] 0.28197626173092805
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.28197626173092805
# sample: 57
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.16860730757166537
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.16860730757166537
# sample: 58
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.13498344452705474
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13498344452705474
# sample: 59
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.18854358035032834
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18854358035032834
# sample: 60
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i'] 0.1578952804070107
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1578952804070107
# sample: 61
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i'] 0.27959581124989374
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.27959581124989374
# sample: 62
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i'] 0.15759772409688164
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15759772409688164
# sample: 63
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.2438890540343778
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2438890540343778
# sample: 64
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.12010562902058962
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.12010562902058962
# sample: 65
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.30340031606023776
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.30340031606023776
# sample: 66
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.15789528040701065
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15789528040701065
# sample: 67
# pass (varmed, obj): ['EX_succ_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.24805484237618805
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24805484237618805
# sample: 68
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.22395278125571524
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22395278125571524
# sample: 69
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.24626950451541244
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24626950451541244
# sample: 70
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.22186988708480984
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22186988708480984
# sample: 71
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.22246499970506825
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.22246499970506825
# sample: 72
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i'] 0.2209772181544219
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2209772181544219
# sample: 73
# pass (varmed, obj): ['EX_fru_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i'] 0.24448416665463651
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24448416665463651
# sample: 74
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.19241181238200902
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.19241181238200902
# sample: 75
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.28882005686390255
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.28882005686390255
# sample: 76
# pass (varmed, obj): ['EX_succ_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.21056274729989646
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21056274729989646
# sample: 77
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.11623739698890882
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11623739698890882
# sample: 78
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.11593984067877951
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11593984067877951
# sample: 79
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.24894751130657616
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24894751130657616
# sample: 80
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.24299638510399027
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.24299638510399027
# sample: 81
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.14896859110313165
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.14896859110313165
# sample: 82
# pass (varmed, obj): ['EX_succ_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i'] 0.18556801724903557
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.18556801724903557
# sample: 83
# pass (varmed, obj): ['EX_fru_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.2825713743511866
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2825713743511866
# sample: 84
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.10820337661541798
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10820337661541798
# sample: 85
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i'] 0.13885167655873565
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.13885167655873565
# sample: 86
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.21175297254041384
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.21175297254041384
# sample: 87
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_succ_e_i', 'EX_pyr_e_i'] 0.10909604554580557
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.10909604554580557
# sample: 88
# pass (varmed, obj): ['EX_fru_e_i', 'EX_succ_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i'] 0.2513279617876103
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2513279617876103
# sample: 89
# pass (varmed, obj): ['EX_fru_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i'] 0.3087563296425649
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3087563296425649
# sample: 90
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.31857568787683194
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.31857568787683194
# sample: 91
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i'] 0.1207007416408485
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1207007416408485
# sample: 92
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i'] 0.3411899674466584
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.3411899674466584
# sample: 93
# pass (varmed, obj): ['EX_fru_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i', 'EX_pyr_e_i'] 0.11534472805852093
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.11534472805852093
# sample: 94
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_lac__D_e_i', 'EX_fru_e_i'] 0.2712642345662735
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2712642345662735
# sample: 95
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.29417607044622923
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.29417607044622923
# sample: 96
# pass (varmed, obj): ['EX_pyr_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_lac__D_e_i'] 0.2965565209272636
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2965565209272636
# sample: 97
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_pyr_e_i', 'EX_fru_e_i', 'EX_succ_e_i'] 0.15491971730571766
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.15491971730571766
# sample: 98
# pass (varmed, obj): ['EX_lac__D_e_i', 'EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i'] 0.1941971502427851
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.1941971502427851
# sample: 99
# pass (varmed, obj): ['EX_succ_e_i', 'EX_fru_e_i', 'EX_pyr_e_i', 'EX_lac__D_e_i'] 0.2763226918384715
# primal objectif = ['BIOMASS_Ec_iML1515_core_75p37M'] pFBA 0.2763226918384715
# reduced numbers of metabolites and reactions: 1083 550
# ./Dataset_model/iML1515_UB
# model file name: ./Dataset_model/iML1515_UB
# reduced model: True
# medium file name: ./Dataset_input/iML1515
# medium bound: UB
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: pFBA
# trainingsize: 11000
# list of medium reactions: 38
# list of medium levels: 38
# list of medium values: 38
# ratio of variable medium turned on: 0.0
# list of measured reactions: 550
# Stoichiometric matrix (1083, 550)
# Boundary matrix from reactions to medium: (38, 550)
# Measurement matrix from reaction to measures: (550, 550)
# Reaction to metabolite matrix: (1083, 550)
# Metabolite to reaction matrix: (550, 1083)
# Training set X: (11000, 38)
# Training set Y: (11000, 550)
# S_int matrix (481, 550)
# S_ext matrix (550, 2716)
# Q matrix (550, 481)
# P matrix (550, 550)
# b_int vector (481,)
# b_ext vector (11000, 2716)
# Sb matrix (550, 1083)
# c vector (550,)

# %% [markdown]
# ## Examples of experimental or manual training set generation

# %% [markdown]
# This cell provides a way to generate a training set with the same object (parameter) as simulated training sets using Cobra, but only using the experimental data. In this cell, we do not run cobra to generate the training set but instead directly use the experimental data.

# %%
# Generate training set for E coli iML1515 experimental file 

# What you can change
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
cobraname = 'iML1515_EXP'  # name of the model here a reduced iML1515 model
mediumbound = 'UB' # a must exact bounds unknown
mediumname = 'iML1515_EXP' # name of experimental file 
method    = 'EXP' # FBA, pFBA or EXP
reduce = False # Set at True if you want to reduce the model
# End of What you can change

# Get data
cobrafile = DIRECTORY+'Dataset_input/'+cobraname
mediumfile  = DIRECTORY+'Dataset_input/'+mediumname
parameter = TrainingSet(cobraname=cobrafile, 
                        mediumname=mediumfile, mediumbound=mediumbound, mediumsize=38, 
                        method=method,verbose=False)

# Saving file
trainingfile  = DIRECTORY+'Dataset_model/'+mediumname+'_'+parameter.mediumbound
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
parameter.printout()
# Out:
# model file name: ./Dataset_model/iML1515_EXP_reduced_UB
# reduced model: False
# medium file name: ./Dataset_input/iML1515_EXP_reduced
# medium bound: UB
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: EXP
# trainingsize: 110
# list of medium reactions: 38
# list of medium levels: 0
# list of medium values: 0
# ratio of variable medium turned on: 0
# list of measured reactions: 543
# Stoichiometric matrix (1080, 543)
# Boundary matrix from reactions to medium: (38, 543)
# Measurement matrix from reaction to measures: (543, 543)
# Reaction to metabolite matrix: (1080, 543)
# Metabolite to reaction matrix: (543, 1080)
# Training set X: (110, 38)
# Training set Y: (110, 1)
# S_int matrix (478, 543)
# S_ext matrix (543, 2703)
# Q matrix (543, 478)
# P matrix (543, 543)
# b_int vector (478,)
# b_ext vector (110, 2703)
# Sb matrix (543, 1080)
# c vector (543,)

# %% [markdown]
# ## Running Cobra on a provided dataset set

# %% [markdown]
# This cell has a completely different purpose than the rest of the notebook. It serves as a cell running Cobrapy with  provided values as inputs. These inputs are extracted from Reservoir Computing, you can see an example in the notebook `Build_Model_RC.ipynb`

# %%
# This cell run FBA on a provided training and compute R2 between
# provided objective and calculated objective
# R2 = 1 when the training set was generated by FBA, but may be different than 1
# when the training set is an experimental one
# For exprimental training set medium input fluxes can be scaled by a value

from sklearn.metrics import r2_score

# What you can change 
seed = 10
np.random.seed(seed=seed)  
cobraname = 'iML1515_EXP'  # name of the model 
mediumbound = 'UB' # a must, exact bounds unknown
# mediumname = 'iML1515_EXP' # name of experimental file, for out-of-the-box FBA
# mediumname = 'iML1515_UB_AMN_QP_RC_AMN_solution_for_Cobra_train' # for running Cobra with RC training points as inputs
mediumname = 'iML1515_UB_AMN_QP_RC_AMN_solution_for_Cobra_pred' # for running Cobra with RC predictions as inputs
method = 'EXP' # FBA, pFBA or EXP
# End of What you can change

# Get data
cobrafile =  DIRECTORY+'Dataset_input/'+cobraname
mediumfile = DIRECTORY+'Dataset_input/'+mediumname
parameter = TrainingSet(cobraname=cobrafile, 
                        mediumname=mediumfile, mediumbound=mediumbound, mediumsize=38, 
                        method=method,verbose=False)
scaler_list = [2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.7, 2.8, 2.9, 3.0] # test different scalers
scaler_list = [2.4] # best scaler for out-of-the box FBA
scaler_list = [1] # for running Cobra with RC training inputs, see mediumname

# regression cobra vs. true values
L = parameter.X.shape[0]
for scaler in scaler_list:
    Y = {}
    for i in range(L):
        inf = {r.id: 0 for r in parameter.model.reactions}
        for j in range(len(parameter.medium)):
            #print(j, parameter.medium[j],parameter.X[i,j], len(parameter.model.reactions))
            eps = 1.0e-4 if parameter.X[i,j] < 1.0e-4 else 0
            inf[parameter.medium[j]] = scaler * parameter.X[i,j] + eps
        out,Y[i] = run_cobra(parameter.model, parameter.objective, inf, method='pFBA', verbose=False)
        print("%d %.4f %.4f" % (i, parameter.Y[i], Y[i]))

    Y = list(Y.values())
    r2 = r2_score(parameter.Y[0:L], Y[0:L], multioutput='variance_weighted')
    print('scaler %.2f R2 %.4f ' % (scaler, r2))
# Out:
# 0 0.1696 0.2041
# 1 0.1340 0.1503
# 2 0.1886 0.1996
# 3 0.1990 0.1580
# 4 0.0720 0.1089
# 5 0.0924 0.0839
# 6 0.0881 0.0852
# 7 0.0900 0.1311
# 8 0.1989 0.1737
# 9 0.1054 0.0839
# 10 0.2681 0.2577
# 11 0.1576 0.1124
# 12 0.1209 0.1699
# 13 0.2729 0.2433
# 14 0.2945 0.2854
# 15 0.2386 0.2434
# 16 0.2531 0.2012
# 17 0.2606 0.2869
# 18 0.2816 0.2001
# 19 0.1351 0.1724
# 20 0.1449 0.1716
# 21 0.2409 0.2750
# 22 0.2437 0.2655
# 23 0.1059 0.1018
# 24 0.1082 0.1249
# 25 0.2451 0.3241
# 26 0.3099 0.2835
# 27 0.2000 0.2761
# 28 0.2077 0.2065
# 29 0.3837 0.2881
# 30 0.2247 0.2361
# 31 0.3520 0.3883
# 32 0.2255 0.2113
# 33 0.1340 0.1275
# 34 0.2397 0.1937
# 35 0.3654 0.3591
# 36 0.1863 0.2036
# 37 0.1612 0.3016
# 38 0.3442 0.3725
# 39 0.2964 0.3434
# 40 0.4135 0.4223
# 41 0.2561 0.2930
# 42 0.3949 0.4262
# 43 0.4205 0.3552
# 44 0.3050 0.3002
# 45 0.2315 0.1863
# 46 0.2708 0.2802
# 47 0.3351 0.2890
# 48 0.2785 0.2193
# 49 0.0765 0.1460
# 50 0.0704 0.0852
# 51 0.2095 0.2374
# 52 0.1135 0.1447
# 53 0.2193 0.2378
# 54 0.3316 0.2954
# 55 0.1368 0.0852
# 56 0.1362 0.1624
# 57 0.1074 0.1310
# 58 0.2277 0.2304
# 59 0.2021 0.1857
# 60 0.2275 0.2556
# 61 0.2131 0.2381
# 62 0.2624 0.1664
# 63 0.1862 0.1927
# 64 0.1688 0.1601
# 65 0.3621 0.3342
# 66 0.2549 0.2729
# 67 0.2429 0.2482
# 68 0.1936 0.2041
# 69 0.3361 0.2877
# 70 0.3688 0.3595
# 71 0.1765 0.1633
# 72 0.1585 0.1598
# 73 0.1538 0.1223
# 74 0.1887 0.2376
# 75 0.1655 0.1685
# 76 0.1706 0.1886
# 77 0.2155 0.2277
# 78 0.1549 0.1475
# 79 0.3022 0.2437
# 80 0.2706 0.3258
# 81 0.2405 0.2862
# 82 0.3362 0.3224
# 83 0.3027 0.3153
# 84 0.1924 0.1962
# 85 0.1674 0.2376
# 86 0.3255 0.3423
# 87 0.2519 0.2115
# 88 0.3355 0.3524
# 89 0.2919 0.3697
# 90 0.3048 0.2948
# 91 0.2370 0.1991
# 92 0.2977 0.2574
# 93 0.2461 0.2092
# 94 0.2310 0.2310
# 95 0.2037 0.1549
# 96 0.3402 0.3220
# 97 0.2041 0.2509
# 98 0.1665 0.1695
# 99 0.1320 0.1840
# 100 0.2731 0.2520
# 101 0.3785 0.3830
# 102 0.2321 0.2698
# 103 0.3675 0.3648
# 104 0.2712 0.2512
# 105 0.2610 0.1883
# 106 0.2469 0.2162
# 107 0.3929 0.3917
# 108 0.3630 0.3987
# 109 0.1949 0.2346
# scaler 1.00 R2 0.7864
